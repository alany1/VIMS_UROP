# %%
from IPython.core.display import HTML
import numpy as np
import matplotlib
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from pylab import *
import pysis
import os
import scipy.optimize as sco
import time
import ast
from tkinter import *
from PIL import Image, ImageTk
# %matplotlib qt
#argparse (User input)

file = open('cube_data.txt','a')
file.write('test')
file.close()
#pyqt (tkinter alternative)

#continue python implementation, array
#SQL and pgadmin
#correct best fits
#look into parallelization
#think about best implementations for speed/data volume (multi step vs one big database, etc)
#try no fits, time
#argparse and pyqt

#estimate for fitting pixels in every cube


#filter: real amp at channel 69-70 > .01 (too dark)
#pgadmin
#virtual machines

# %%
def gaussian(x,mean,sigma,A):
    
    return A*np.exp( -((x-mean)**2.) / (2.*sigma**2.) )

def powerlaw(x,a, k, c):
    
    return a*x**k + c
vims_wave = np.loadtxt('/home/alanyu/Dropbox (MIT)/VIMS_UROP/vims_wave.txt')

# %%
def analyze_cube(cube,nav,x,y):
    """
    Given cube data (cube) and navigation information (nav) with dimensions x and y, returns:
    
    1) max/min 2 micron amplitude
    2) max/min sigma
    3) max/min mean 
    4) max/min incidence
    5) max/min emission
    6) max/min phase
    7) max/min lat
    8) max/min lon
    """
        
    maxes = {}
    mins = {}
    dimensions = (x,y)
    count=0
    band_channels = [29,30,31,32,47,48,49,50,51,52,53,54,55,84,85,86,87,88,89,90] + [i for i in range(160,181)] 
    
    for i in range(x):
        for j in range(y):
            #incidence and emission < 70
            if nav[6,i,j] < -90 or nav[2,i,j]<70 or nav[3,i,j]>90:
                count+=1
                continue
            else:
                try:
                    #Fit power law
                    p_fit, p_cov = sco.curve_fit(powerlaw, vims_wave[band_channels], cube[band_channels, i,j], p0 = (.005,-2,0), maxfev = 10000)
                    p = powerlaw(vims_wave, *p_fit)

                    #Subtract power law
                    new_data = cube[:,i,j] - p

                    #Fit gaussian
                    fit,cov = sco.curve_fit(gaussian, vims_wave[64:85],new_data[64:85], \
                                        p0=(2.08,.125,.1), maxfev=100000)

                    plaw[i,j] = p_fit[0]
                    plaw2[i,j] = p_fit[1]
                    plaw3[i,j] = p_fit[2]
                    
                except:
                    #If powerlaw fit fails, directly fit gaussian
                    try:
                        fit,cov = sco.curve_fit(gaussian, vims_wave[64:85],cube[64:85,i,j], p0=(2.08,.125,.1), maxfev=1000000)
                    except:
#                         print('in')
                        break
                
                max_real_amp = np.max(cube[64:85,i,j])
                if maxes.get('max_real_amplitude',None) is None or maxes['max_real_amplitude'] < max_real_amp:
                    maxes['max_real_amplitude'] = max_real_amp
                if maxes.get('max_mean',None) is None or maxes['max_mean']< fit[0]:
                    maxes['max_mean']=fit[0]
                if maxes.get('max_sigma',None) is None or maxes['max_sigma'] <  fit[1]:
                    maxes['max_sigma'] = fit[1]
                if maxes.get('max_amplitude',None) is None or maxes['max_amplitude'] < fit[2]:
                    maxes['max_amplitude'] = fit[2]
                    
                if maxes.get('max_incidence',None) is None or maxes['max_incidence'] < nav[3,i,j]:
                    maxes['max_incidence'] = nav[3,i,j]
                if maxes.get('max_emission',None) is None or maxes['max_emission'] < nav[2,i,j]:
                    maxes['max_emission'] = nav[2,i,j]
                if maxes.get('max_phase',None) is None or maxes['max_phase'] < nav[1,i,j]:
                    maxes['max_phase'] = nav[1,i,j]
                if maxes.get('max_lat',None) is None or maxes['max_lat'] < nav[6,i,j]:
                    maxes['max_lat'] = nav[6,i,j]
                if maxes.get('max_lon',None) is None or maxes['max_lon'] < nav[7,i,j]:
                    maxes['max_lon'] = nav[7,i,j]
                    
                    
                min_real_amp = max_real_amp
                if mins.get('min_real_amplitude',None) is None or mins['min_real_amplitude'] > min_real_amp:
                    mins['min_real_amplitude'] = min_real_amp
                if mins.get('min_mean',None) is None or mins['min_mean']> fit[0]:
                    mins['min_mean']=fit[0]
                if mins.get('min_sigma',None) is None or mins['min_sigma'] >  fit[1]:
                    mins['min_sigma'] = fit[1]
                if mins.get('min_amplitude',None) is None or mins['min_amplitude'] > fit[2]:
                    mins['min_amplitude'] = fit[2]
                    
                if mins.get('min_incidence',None) is None or mins['min_incidence'] > nav[3,i,j]:
                    mins['min_incidence'] = nav[3,i,j]
                if mins.get('min_emission',None) is None or mins['min_emission'] > nav[2,i,j]:
                    mins['min_emission'] = nav[2,i,j]
                if mins.get('min_phase',None) is None or mins['min_phase'] > nav[1,i,j]:
                    mins['min_phase'] = nav[1,i,j]
                if mins.get('min_lat',None) is None or mins['min_lat'] > nav[6,i,j]:
                    mins['min_lat'] = nav[6,i,j]
                if mins.get('min_lon',None) is None or mins['min_lon'] > nav[7,i,j]:
                    mins['min_lon'] = nav[7,i,j]
                    
            
    #print(count)
    return (maxes,mins)

# %%
def analyze_cube(cube,nav,x,y):
    """
    Given cube data (cube) and navigation information (nav) with dimensions x and y, returns:
    
    1) max/min 2 micron amplitude
    2) max/min sigma
    3) max/min mean 
    4) max/min incidence
    5) max/min emission
    6) max/min phase
    7) max/min lat
    8) max/min lon
    """
        
    maxes = {}
    mins = {}
    dimensions = (x,y)
    count=0
    band_channels = [29,30,31,32,47,48,49,50,51,52,53,54,55,84,85,86,87,88,89,90] + [i for i in range(160,181)] 
    
    for i in range(x):
        for j in range(y):
            #incidence and emission < 70
            if nav[6,i,j] < -90 or nav[2,i,j]<70 or nav[3,i,j]>90:
                count+=1
                continue
            else:
                
                    
                if maxes.get('max_incidence',None) is None or maxes['max_incidence'] < nav[3,i,j]:
                    maxes['max_incidence'] = nav[3,i,j]
                if maxes.get('max_emission',None) is None or maxes['max_emission'] < nav[2,i,j]:
                    maxes['max_emission'] = nav[2,i,j]
                if maxes.get('max_phase',None) is None or maxes['max_phase'] < nav[1,i,j]:
                    maxes['max_phase'] = nav[1,i,j]
                if maxes.get('max_lat',None) is None or maxes['max_lat'] < nav[6,i,j]:
                    maxes['max_lat'] = nav[6,i,j]
                if maxes.get('max_lon',None) is None or maxes['max_lon'] < nav[7,i,j]:
                    maxes['max_lon'] = nav[7,i,j]
                    
                
                    
                if mins.get('min_incidence',None) is None or mins['min_incidence'] > nav[3,i,j]:
                    mins['min_incidence'] = nav[3,i,j]
                if mins.get('min_emission',None) is None or mins['min_emission'] > nav[2,i,j]:
                    mins['min_emission'] = nav[2,i,j]
                if mins.get('min_phase',None) is None or mins['min_phase'] > nav[1,i,j]:
                    mins['min_phase'] = nav[1,i,j]
                if mins.get('min_lat',None) is None or mins['min_lat'] > nav[6,i,j]:
                    mins['min_lat'] = nav[6,i,j]
                if mins.get('min_lon',None) is None or mins['min_lon'] > nav[7,i,j]:
                    mins['min_lon'] = nav[7,i,j]
                    
            
    #print(count)
    return (maxes,mins)

# %%
nav = pysis.CubeFile('/home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2016127T223449_2016130T200342/CM_1841286170_1_ir_nav.cub').data
data = pysis.CubeFile('/home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2016127T223449_2016130T200342/CM_1841286170_1_ir.cub').data
lbl = pysis.CubeFile('/home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2016127T223449_2016130T200342/CM_1841286170_1_ir.cub').label
analyze_cube(data,nav,lbl['IsisCube']['Instrument']['SwathLength'],lbl['IsisCube']['Instrument']['SwathWidth'])
# Out:
# ({'max_incidence': 88.992134,
#   'max_emission': 87.98578,
#   'max_phase': 120.82383,
#   'max_lat': 76.94431,
#   'max_lon': 359.5261},
#  {'min_incidence': 32.880913,
#   'min_emission': 70.05934,
#   'min_phase': 120.20317,
#   'min_lat': 25.466824,
#   'min_lon': 0.24249664})

# %%
def create_cube_parser(master_directory):
    '''
    Parameters:
    
    master_directory (str): Path to folder with all viewing geometries.
    
    Creates text file with information about each cube (assuming max resolution < 100km): 
    
    1) folder 
    2) name 
    3) max/min 2 micron amplitude
    4) max/min sigma
    5) max/min mean
    6) dimensions
    7) max/min incidence
    8) max/min emission
    9) max/min phase
    10) max/min lat
    11) max/min lon
    
    '''
    count = 0
    #file = open('cube_data.txt','w')
    skipped=set()
    viewing_geometries = os.listdir(master_directory)
    #print(viewing_geometries)
    for folder in viewing_geometries:
        file = open('test.txt','a')
        print(f'Folder: {folder}')
        #file.write(f'{folder}\n')
        if folder == '.DS_Store':
            continue
        files = os.listdir(f'{master_directory}/{folder}')
        #print(files)
        for cube in files:
            
            #print(cube)
            if cube[0:2] != 'CM' or 'nav' in cube or 'BKGD' in cube:
                continue
            count+=1    
            nav = pysis.CubeFile(f'{master_directory}/{folder}/{cube[:-4]}_nav.cub').data
            
            if np.max(nav[8])>100000:
                skipped.add((cube,'resolution'))
                continue
            
            print(f'Working on: {cube}')
            
            
                  
#             name = cube
            
#             data = pysis.CubeFile(f'{master_directory}/{folder}/{cube}').data
            
#             lbl = pysis.CubeFile(f'{master_directory}/{folder}/{cube}').label
            
#             desc = {'view':folder,'name':cube,'dimensions':(lbl['IsisCube']['Instrument']['SwathLength'],
#                                     lbl['IsisCube']['Instrument']['SwathWidth'])}
            
            #maxes,mins = analyze_cube(data,nav,lbl['IsisCube']['Instrument']['SwathLength'],lbl['IsisCube']['Instrument']['SwathWidth'])
            
            #if maxes is empty, no meaningful data found
            
#             if len(maxes)==0:
#                 skipped.add((cube,'lacking data'))
#                 continue
            
            
#             desc.update(maxes)
#             desc.update(mins)
                  
            #file.write(f'{desc} \n')
        file.close()    
    #file.close()
    print(count)
    return skipped

# %%
create_cube_parser('/home/alanyu/Dropbox (MIT)/VIMS_UROP/data')
# Out:
# Folder: 2009189T194600_2009189T235739
# Working on: CM_1625786407_1_ir.cub
# Working on: CM_1625776676_1_ir.cub
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/pvl/parser.py in parse_aggregation_block(self, tokens)
#     327             try:
# --> 328                 agg.append(*self.parse_aggregation_block(tokens))
#     329             except ValueError:
#
# ~/anaconda3/lib/python3.8/site-packages/pvl/parser.py in parse_aggregation_block(self, tokens)
#     320         """
# --> 321         (begin, block_name) = self.parse_begin_aggregation_statement(tokens)
#     322
#
# ~/anaconda3/lib/python3.8/site-packages/pvl/parser.py in parse_begin_aggregation_statement(self, tokens)
#     388                 tokens.send(begin)
# --> 389                 raise ValueError(
#     390                     "Expecting a Begin-Aggegation-Statement, but "
#
# ValueError: Expecting a Begin-Aggegation-Statement, but found: TargetPosition
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/pvl/decoder.py in decode_datetime(self, value)
#     229             # datetime.date objects will always be naive, so just return:
# --> 230             return for_try_except(
#     231                 ValueError,
#
# ~/anaconda3/lib/python3.8/site-packages/pvl/decoder.py in for_try_except(exception, function, *iterable)
#      45
# ---> 46     raise exception
#      47
#
# ValueError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-d27d455bd447> in <module>
# ----> 1 create_cube_parser('/home/alanyu/Dropbox (MIT)/VIMS_UROP/data')
#
# <ipython-input-12-ec6a2d15551b> in create_cube_parser(master_directory)
#      53             data = pysis.CubeFile(f'{master_directory}/{folder}/{cube}').data
#      54
# ---> 55             lbl = pysis.CubeFile(f'{master_directory}/{folder}/{cube}').label
#      56
#      57             desc = {'view':folder,'name':cube,'dimensions':(lbl['IsisCube']['Instrument']['SwathLength'],
#
# ~/anaconda3/lib/python3.8/site-packages/pysis/cubefile.py in __init__(self, stream_or_fname, filename)
#      58
#      59         #: The parsed label header in dictionary form.
# ---> 60         self.label = self._parse_label(stream)
#      61
#      62         #: A numpy array representing the image data.
#
# ~/anaconda3/lib/python3.8/site-packages/pysis/cubefile.py in _parse_label(self, stream)
#     231
#     232     def _parse_label(self, stream):
# --> 233         return pvl.load(stream)
#     234
#     235     def _parse_data(self, stream):
#
# ~/anaconda3/lib/python3.8/site-packages/pvl/__init__.py in load(path, parser, grammar, decoder, **kwargs)
#      59     decodable text.
#      60     """
# ---> 61     return loads(
#      62         get_text_from(path),
#      63         parser=parser,
#
# ~/anaconda3/lib/python3.8/site-packages/pvl/__init__.py in loads(s, parser, grammar, decoder, **kwargs)
#     199         raise TypeError("The parser must be an instance of pvl.PVLParser.")
#     200
# --> 201     return parser.parse(s)
#     202
#     203
#
# ~/anaconda3/lib/python3.8/site-packages/pvl/parser.py in parse(self, s)
#     829         self.doc = nodash
#     830
# --> 831         return super().parse(nodash)
#     832
#     833     def parse_module_post_hook(
#
# ~/anaconda3/lib/python3.8/site-packages/pvl/parser.py in parse(self, s)
#     205         self.doc = s
#     206         tokens = self.lexer(s, g=self.grammar, d=self.decoder)
# --> 207         module = self.parse_module(tokens)
#     208         module.errors = sorted(self.errors)
#     209         return module
#
# ~/anaconda3/lib/python3.8/site-packages/pvl/parser.py in parse_module(self, tokens)
#     254                     # print(f'next token: {t}, {t.pos}')
#     255                     # tokens.send(t)
# --> 256                     parsed = p(tokens)
#     257                     # print(f'parsed: {parsed}')
#     258                     if parsed is None:  # because parse_end_statement returned
#
# ~/anaconda3/lib/python3.8/site-packages/pvl/parser.py in parse_aggregation_block(self, tokens)
#     326             self.parse_WSC_until(None, tokens)
#     327             try:
# --> 328                 agg.append(*self.parse_aggregation_block(tokens))
#     329             except ValueError:
#     330                 try:
#
# ~/anaconda3/lib/python3.8/site-packages/pvl/parser.py in parse_aggregation_block(self, tokens)
#     329             except ValueError:
#     330                 try:
# --> 331                     agg.append(*self.parse_assignment_statement(tokens))
#     332                     # print(f'agg: {agg}')
#     333                     # t = next(tokens)
#
# ~/anaconda3/lib/python3.8/site-packages/pvl/parser.py in parse_assignment_statement(self, tokens)
#     896         """
#     897         try:
# --> 898             return super().parse_assignment_statement(tokens)
#     899         except ParseError as err:
#     900             if err.token is not None:
#
# ~/anaconda3/lib/python3.8/site-packages/pvl/parser.py in parse_assignment_statement(self, tokens)
#     527         try:
#     528             # print(f'parameter name: {parameter_name}')
# --> 529             value = self.parse_value(tokens)
#     530         except StopIteration:
#     531             raise ParseError(
#
# ~/anaconda3/lib/python3.8/site-packages/pvl/parser.py in parse_value(self, tokens)
#     674         try:
#     675             t = next(tokens)
# --> 676             value = self.decoder.decode_simple_value(t)
#     677         except ValueError:
#     678             tokens.send(t)
#
# ~/anaconda3/lib/python3.8/site-packages/pvl/decoder.py in decode_simple_value(self, value)
#      91         ):
#      92             try:
# ---> 93                 return d(value)
#      94             except ValueError:
#      95                 pass
#
# ~/anaconda3/lib/python3.8/site-packages/pvl/decoder.py in decode_datetime(self, value)
#     415
#     416         try:
# --> 417             return super().decode_datetime(value)
#     418         except ValueError:
#     419             try:
#
# ~/anaconda3/lib/python3.8/site-packages/pvl/decoder.py in decode_datetime(self, value)
#     316
#     317         try:
# --> 318             return super().decode_datetime(value)
#     319         except ValueError:
#     320             # if there is a +HH:MM or a -HH:MM suffix that
#
# ~/anaconda3/lib/python3.8/site-packages/pvl/decoder.py in decode_datetime(self, value)
#     238             d = None
#     239             try:
# --> 240                 d = for_try_except(
#     241                     ValueError,
#     242                     datetime.strptime,
#
# ~/anaconda3/lib/python3.8/site-packages/pvl/decoder.py in for_try_except(exception, function, *iterable)
#      40     for tup in zip(*iterable):
#      41         try:
# ---> 42             return function(*tup)
#      43         except exception:
#      44             pass
#
# ~/anaconda3/lib/python3.8/_strptime.py in _strptime_datetime(cls, data_string, format)
#     566     """Return a class cls instance based on the input string and the
#     567     format string."""
# --> 568     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     569     tzname, gmtoff = tt[-2:]
#     570     args = tt[:6] + (fraction,)
#
# ~/anaconda3/lib/python3.8/_strptime.py in _strptime(data_string, format)
#     347     found = format_regex.match(data_string)
#     348     if not found:
# --> 349         raise ValueError("time data %r does not match format %r" %
#     350                          (data_string, format))
#     351     if len(data_string) != found.end():
#
# KeyboardInterrupt:

# %%
def read_database(file_name):
    data = {}
    
    file = open(file_name,'r')
    while True:
        try:
            temp = ast.literal_eval(file.readline())
            name = temp['name']
            del(temp['name'])
            data.update({name:temp})
        except Exception as e:
            #print(e)
            break
            
    file.close()
    
    return data

# %%
# d=read_database('test.txt')
# #print(d) 
a='2016127T223449_2016130T200342'
b='2009189T194600_2009189T235739'
c='2005359T100445_2005360T101919'
# vals=[(x,d[x]) for x in d if d[x]['max_amplitude']>1]
# vals
orig = read_database('test.txt')
new = read_database('compare.txt')

[x for x in orig if x not in new and orig[x]['view']==b and orig[x]['dimensions']!=(64,4)]
#len([x for x in new if x not in orig])
#[x for x in vals if x['view'] == a or x['view']==b or x['view']==c]
#[x for x in d if d[x]['view']=='2016127T223449_2016130T200342' and d[x]['max_real_amplitude'] == 0.30726528]
#array 
#each pixel
#better fits
#core, parallel
# Out:
# ['CM_1625776676_1_ir.cub',
#  'CM_1625777418_1_ir.cub',
#  'CM_1625777215_1_ir.cub',
#  'CM_1625778429_1_ir.cub',
#  'CM_1625778564_12_ir.cub',
#  'CM_1625788353_1_ir.cub',
#  'CM_1625776406_1_ir.cub',
#  'CM_1625785908_1_ir.cub',
#  'CM_1625778092_1_ir.cub',
#  'CM_1625778227_1_ir.cub',
#  'CM_1625776946_1_ir.cub',
#  'CM_1625785412_1_ir.cub',
#  'CM_1625777081_1_ir.cub',
#  'CM_1625782922_1_ir.cub',
#  'CM_1625776541_1_ir.cub',
#  'CM_1625776811_1_ir.cub',
#  'CM_1625776069_1_ir.cub',
#  'CM_1625778362_1_ir.cub',
#  'CM_1625782424_1_ir.cub',
#  'CM_1625778025_1_ir.cub',
#  'CM_1625777283_1_ir.cub',
#  'CM_1625777350_1_ir.cub',
#  'CM_1625776271_1_ir.cub',
#  'CM_1625776878_1_ir.cub',
#  'CM_1625776136_1_ir.cub',
#  'CM_1625778294_1_ir.cub',
#  'CM_1625776204_1_ir.cub',
#  'CM_1625787354_1_ir.cub',
#  'CM_1625778160_1_ir.cub',
#  'CM_1625776339_1_ir.cub',
#  'CM_1625783398_1_ir.cub',
#  'CM_1625776474_1_ir.cub',
#  'CM_1625777148_1_ir.cub',
#  'CM_1625776743_1_ir.cub',
#  'CM_1625777013_1_ir.cub',
#  'CM_1625778497_1_ir.cub',
#  'CM_1625776001_1_ir.cub',
#  'CM_1625776608_1_ir.cub']

# %%
def search(database):
    parameters = input('Enter parameters as tuples separated by whitespace. Use None to specify no filter for that parameter. \nOrdering: Real Amplitude, Mean, Sigma, Gaussian Amplitude, Incidence, Emission, Phase, Latitude, Longitude.')
    parameters = [eval(x) for x in parameters]#['None', 'None', 'None','None','None','None','None','None', '(180,360)']]
    #print(parameters)
    #return parameters
    assert len(parameters) == 10, 'Incorrect number of parameters specified'
    code = {0:'real_amplitude',1:'mean',2:'sigma',3:'amplitude',4:'incidence',5:'emission',6:'phase',7:'lat',8:'lon'}
    out = {}
    for cube in database:
        for i in range(len(parameters)):
            if parameters[i] is not None and (database[cube][f'min_{code[i]}']<parameters[i][0] or \
                                              database[cube][f'max_{code[i]}']>parameters[i][1]):
                break
        else:
             out.update({cube:database[cube]})
                
    return out

# %%
# %timeit create_cube_parser('/home/alanyu/Dropbox (MIT)/VIMS_UROP/test')
#With fitting
#one directory: 2005359T100445_2005360T101919
#19.2 s ± 1.64 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

#No fitting, but with loops
#16.9 s ± 566 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

#control: just looping through and loading files, no analysis
#15.8 s ± 380 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# Out:
# Folder: 2005359T100445_2005360T101919
# Working on: CM_1514277149_1_ir.cub
# Working on: CM_1514280779_1_ir.cub
# Working on: CM_1514282576_1_ir.cub
# Working on: CM_1514280052_1_ir.cub
# Working on: CM_1514278619_1_ir.cub
# Working on: CM_1514280412_1_ir.cub
# Working on: CM_1514284191_1_ir.cub
# Working on: CM_1514281143_1_ir.cub
# Working on: CM_1514282941_1_ir.cub
# Working on: CM_1514277901_1_ir.cub
# 11
# Folder: 2005359T100445_2005360T101919
# Working on: CM_1514277149_1_ir.cub
# Working on: CM_1514280779_1_ir.cub
# Working on: CM_1514282576_1_ir.cub
# Working on: CM_1514280052_1_ir.cub
# Working on: CM_1514278619_1_ir.cub
# Working on: CM_1514280412_1_ir.cub
# Working on: CM_1514284191_1_ir.cub
# Working on: CM_1514281143_1_ir.cub
# Working on: CM_1514282941_1_ir.cub
# Working on: CM_1514277901_1_ir.cub
# 11
# Folder: 2005359T100445_2005360T101919
# Working on: CM_1514277149_1_ir.cub
# Working on: CM_1514280779_1_ir.cub
# Working on: CM_1514282576_1_ir.cub
# Working on: CM_1514280052_1_ir.cub
# Working on: CM_1514278619_1_ir.cub
# Working on: CM_1514280412_1_ir.cub
# Working on: CM_1514284191_1_ir.cub
# Working on: CM_1514281143_1_ir.cub
# Working on: CM_1514282941_1_ir.cub
# Working on: CM_1514277901_1_ir.cub
# 11
# Folder: 2005359T100445_2005360T101919
# Working on: CM_1514277149_1_ir.cub
# Working on: CM_1514280779_1_ir.cub
# Working on: CM_1514282576_1_ir.cub
# Working on: CM_1514280052_1_ir.cub
# Working on: CM_1514278619_1_ir.cub
# Working on: CM_1514280412_1_ir.cub
# Working on: CM_1514284191_1_ir.cub
# Working on: CM_1514281143_1_ir.cub
# Working on: CM_1514282941_1_ir.cub
# Working on: CM_1514277901_1_ir.cub
# 11
# Folder: 2005359T100445_2005360T101919
# Working on: CM_1514277149_1_ir.cub
# Working on: CM_1514280779_1_ir.cub
# Working on: CM_1514282576_1_ir.cub
# Working on: CM_1514280052_1_ir.cub
# Working on: CM_1514278619_1_ir.cub
# Working on: CM_1514280412_1_ir.cub
# Working on: CM_1514284191_1_ir.cub
# Working on: CM_1514281143_1_ir.cub
# Working on: CM_1514282941_1_ir.cub
# Working on: CM_1514277901_1_ir.cub
# 11
# Folder: 2005359T100445_2005360T101919
# Working on: CM_1514277149_1_ir.cub
# Working on: CM_1514280779_1_ir.cub
# Working on: CM_1514282576_1_ir.cub
# Working on: CM_1514280052_1_ir.cub
# Working on: CM_1514278619_1_ir.cub
# Working on: CM_1514280412_1_ir.cub
# Working on: CM_1514284191_1_ir.cub
# Working on: CM_1514281143_1_ir.cub
# Working on: CM_1514282941_1_ir.cub
# Working on: CM_1514277901_1_ir.cub
# 11
# Folder: 2005359T100445_2005360T101919
# Working on: CM_1514277149_1_ir.cub
# Working on: CM_1514280779_1_ir.cub
# Working on: CM_1514282576_1_ir.cub
# Working on: CM_1514280052_1_ir.cub
# Working on: CM_1514278619_1_ir.cub
# Working on: CM_1514280412_1_ir.cub
# Working on: CM_1514284191_1_ir.cub
# Working on: CM_1514281143_1_ir.cub
# Working on: CM_1514282941_1_ir.cub
# Working on: CM_1514277901_1_ir.cub
# 11
# Folder: 2005359T100445_2005360T101919
# Working on: CM_1514277149_1_ir.cub
# Working on: CM_1514280779_1_ir.cub
# Working on: CM_1514282576_1_ir.cub
# Working on: CM_1514280052_1_ir.cub
# Working on: CM_1514278619_1_ir.cub
# Working on: CM_1514280412_1_ir.cub
# Working on: CM_1514284191_1_ir.cub
# Working on: CM_1514281143_1_ir.cub
# Working on: CM_1514282941_1_ir.cub
# Working on: CM_1514277901_1_ir.cub
# 11
# 5.21 s ± 316 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
d
# Out:
# {'CM_1838530943_1_ir.cub': {'view': '2016096T054156_2016097T040514',
#   'dimensions': (64, 46),
#   'max_real_amplitude': 0.4440777,
#   'max_mean': 30.7460228728227,
#   'max_sigma': 5.604866381344292,
#   'max_amplitude': 1.9206460834707575e+39,
#   'max_incidence': 167.5496,
#   'max_emission': 89.46845,
#   'max_phase': 128.90904,
#   'max_lat': 89.19383,
#   'max_lon': 354.01587,
#   'min_real_amplitude': 6.1433246e-05,
#   'min_mean': -52.59100393397263,
#   'min_sigma': -2.5958860532514874,
#   'min_amplitude': -9.375792693159017e+33,
#   'min_incidence': 44.918026,
#   'min_emission': 0.15046662,
#   'min_phase': 127.5899,
#   'min_lat': -32.07777,
#   'min_lon': 8.737222},
#  'CM_1838530418_1_ir.cub': {'view': '2016096T054156_2016097T040514',
#   'dimensions': (64, 46),
#   'max_real_amplitude': 0.42949194,
#   'max_mean': 48.60917219645894,
#   'max_sigma': 32.25339150060372,
#   'max_amplitude': 1.479864995563398e+76,
#   'max_incidence': 166.21419,
#   'max_emission': 87.67787,
#   'max_phase': 128.9562,
#   'max_lat': 89.248634,
#   'max_lon': 351.10638,
#   'min_real_amplitude': -9.5762756e-05,
#   'min_mean': -76.91677303850848,
#   'min_sigma': -5.28344121494414,
#   'min_amplitude': -9.361469695448854e+30,
#   'min_incidence': 43.058796,
#   'min_emission': 0.12151135,
#   'min_phase': 127.61966,
#   'min_lat': -28.064299,
#   'min_lon': 5.433727},
#  'CM_1838527237_1_ir.cub': {'view': '2016096T054156_2016097T040514',
#   'dimensions': (64, 64),
#   'max_real_amplitude': 0.4288267,
#   'max_mean': 58.47834682185065,
#   'max_sigma': 46.53112581743432,
#   'max_amplitude': 1.5124907166008831e+85,
#   'max_incidence': 179.11174,
#   'max_emission': 89.56167,
#   'max_phase': 129.07297,
#   'max_lat': 87.94532,
#   'max_lon': 355.84244,
#   'min_real_amplitude': 5.6470388e-05,
#   'min_mean': -52.65696837688063,
#   'min_sigma': -3.0107091581716823,
#   'min_amplitude': -1.2565798779034326e+37,
#   'min_incidence': 41.986073,
#   'min_emission': 0.08524313,
#   'min_phase': 127.49744,
#   'min_lat': -63.925045,
#   'min_lon': 2.1116881},
#  'CM_1514284191_1_ir.cub': {'view': '2005359T100445_2005360T101919',
#   'dimensions': (64, 64),
#   'max_real_amplitude': 0.14126359,
#   'max_mean': 2.0484601982732005,
#   'max_sigma': 0.12031350621500297,
#   'max_amplitude': 0.1432869105084046,
#   'max_incidence': 113.35764,
#   'max_emission': 89.16023,
#   'max_phase': 29.049898,
#   'max_lat': 85.412674,
#   'max_lon': 359.98105,
#   'min_real_amplitude': 0.015097359,
#   'min_mean': 2.022770167139634,
#   'min_sigma': 0.042521211838699446,
#   'min_amplitude': 0.015466071232006683,
#   'min_incidence': 0.62315613,
#   'min_emission': 0.2967481,
#   'min_phase': 27.386423,
#   'min_lat': -83.479675,
#   'min_lon': 0.07974226},
#  'CM_1514282576_1_ir.cub': {'view': '2005359T100445_2005360T101919',
#   'dimensions': (64, 64),
#   'max_real_amplitude': 0.14242601,
#   'max_mean': 2.0410764959190493,
#   'max_sigma': 0.10222792592567842,
#   'max_amplitude': 0.14259113260539905,
#   'max_incidence': 97.54358,
#   'max_emission': 89.53215,
#   'max_phase': 29.202414,
#   'max_lat': 63.36391,
#   'max_lon': 359.8693,
#   'min_real_amplitude': 0.034005303,
#   'min_mean': 2.0273138680592586,
#   'min_sigma': 0.04244436089883243,
#   'min_amplitude': 0.03263259142324397,
#   'min_incidence': 0.60112566,
#   'min_emission': 0.8965425,
#   'min_phase': 27.734465,
#   'min_lat': -77.93272,
#   'min_lon': 0.021914952},
#  'CM_1514282941_1_ir.cub': {'view': '2005359T100445_2005360T101919',
#   'dimensions': (64, 64),
#   'max_real_amplitude': 0.14427735,
#   'max_mean': 2.041015370311275,
#   'max_sigma': 0.1000416479486547,
#   'max_amplitude': 0.14403772315044355,
#   'max_incidence': 96.43027,
#   'max_emission': 88.824,
#   'max_phase': 29.18114,
#   'max_lat': 62.441803,
#   'max_lon': 359.8741,
#   'min_real_amplitude': 0.03702382,
#   'min_mean': 2.028652174170674,
#   'min_sigma': 0.04192244279452843,
#   'min_amplitude': 0.03531469021396889,
#   'min_incidence': 0.45188135,
#   'min_emission': 0.7602199,
#   'min_phase': 27.716923,
#   'min_lat': -75.955666,
#   'min_lon': 0.10877033},
#  'CM_1514277901_1_ir.cub': {'view': '2005359T100445_2005360T101919',
#   'dimensions': (64, 64),
#   'max_real_amplitude': 0.14126335,
#   'max_mean': 2.040383985428361,
#   'max_sigma': 0.11082897025580044,
#   'max_amplitude': 0.14152435599335444,
#   'max_incidence': 113.85077,
#   'max_emission': 88.658424,
#   'max_phase': 29.508783,
#   'max_lat': 76.25104,
#   'max_lon': 359.9125,
#   'min_real_amplitude': 0.01690499,
#   'min_mean': 2.028427824123273,
#   'min_sigma': 0.04249435781025313,
#   'min_amplitude': 0.016957582265182198,
#   'min_incidence': 0.6046906,
#   'min_emission': 1.0896239,
#   'min_phase': 28.14308,
#   'min_lat': -80.144066,
#   'min_lon': 0.12244993},
#  'CM_1514281143_1_ir.cub': {'view': '2005359T100445_2005360T101919',
#   'dimensions': (64, 64),
#   'max_real_amplitude': 0.14263956,
#   'max_mean': 2.040405884528871,
#   'max_sigma': 0.10240855324765809,
#   'max_amplitude': 0.14444424521809296,
#   'max_incidence': 99.923195,
#   'max_emission': 89.56431,
#   'max_phase': 29.267885,
#   'max_lat': 65.747086,
#   'max_lon': 359.9812,
#   'min_real_amplitude': 0.028945645,
#   'min_mean': 2.0313943333434743,
#   'min_sigma': 0.04254957103139811,
#   'min_amplitude': 0.029124752106954477,
#   'min_incidence': 1.1092395,
#   'min_emission': 0.7489744,
#   'min_phase': 27.770727,
#   'min_lat': -83.5026,
#   'min_lon': 0.031011518},
#  'CM_1514278619_1_ir.cub': {'view': '2005359T100445_2005360T101919',
#   'dimensions': (64, 64),
#   'max_real_amplitude': 0.14353074,
#   'max_mean': 2.040294996069835,
#   'max_sigma': 0.10851154523124139,
#   'max_amplitude': 0.14452619495252444,
#   'max_incidence': 110.02357,
#   'max_emission': 89.251305,
#   'max_phase': 29.446371,
#   'max_lat': 77.53968,
#   'max_lon': 359.87973,
#   'min_real_amplitude': 0.020894669,
#   'min_mean': 2.0313914958015946,
#   'min_sigma': 0.042521582462656395,
#   'min_amplitude': 0.02116414717959958,
#   'min_incidence': 0.34112307,
#   'min_emission': 0.52137977,
#   'min_phase': 28.01663,
#   'min_lat': -82.395195,
#   'min_lon': 0.007362854},
#  'CM_1514280412_1_ir.cub': {'view': '2005359T100445_2005360T101919',
#   'dimensions': (64, 64),
#   'max_real_amplitude': 0.14305525,
#   'max_mean': 2.0409281821649885,
#   'max_sigma': 0.11163263955867134,
#   'max_amplitude': 0.1435336836511709,
#   'max_incidence': 113.152,
#   'max_emission': 89.457245,
#   'max_phase': 29.371422,
#   'max_lat': 72.664276,
#   'max_lon': 359.98837,
#   'min_real_amplitude': 0.018988237,
#   'min_mean': 2.0312652518287426,
#   'min_sigma': 0.04243637105653639,
#   'min_amplitude': 0.01753119571057735,
#   'min_incidence': 0.9067172,
#   'min_emission': 1.1230701,
#   'min_phase': 27.953093,
#   'min_lat': -75.30604,
#   'min_lon': 0.16170393},
#  'CM_1514280052_1_ir.cub': {'view': '2005359T100445_2005360T101919',
#   'dimensions': (64, 64),
#   'max_real_amplitude': 0.14254878,
#   'max_mean': 2.0412303037378408,
#   'max_sigma': 0.10910244863374734,
#   'max_amplitude': 0.1429771930286251,
#   'max_incidence': 108.61863,
#   'max_emission': 87.73299,
#   'max_phase': 29.378065,
#   'max_lat': 74.06877,
#   'max_lon': 359.9099,
#   'min_real_amplitude': 0.020257121,
#   'min_mean': 2.030246309393123,
#   'min_sigma': 0.042223518820954375,
#   'min_amplitude': 0.020387804736551822,
#   'min_incidence': 0.8379593,
#   'min_emission': 0.9518899,
#   'min_phase': 27.986525,
#   'min_lat': -77.16776,
#   'min_lon': 0.06087477},
#  'CM_1844017866_1_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (64, 2),
#   'max_real_amplitude': 0.15581545,
#   'max_mean': 2.032682205143012,
#   'max_sigma': 0.0860030642941676,
#   'max_amplitude': 0.15561448818904525,
#   'max_incidence': 80.41926,
#   'max_emission': 52.47181,
#   'max_phase': 116.281265,
#   'max_lat': 75.10471,
#   'max_lon': 227.70117,
#   'min_real_amplitude': 0.064098306,
#   'min_mean': 2.028805308713731,
#   'min_sigma': 0.07534385370169948,
#   'min_amplitude': 0.06569747842032929,
#   'min_incidence': 70.7378,
#   'min_emission': 36.65218,
#   'min_phase': 116.00903,
#   'min_lat': 59.76885,
#   'min_lon': 80.33702},
#  'CM_1844017356_1_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (64, 2),
#   'max_real_amplitude': 0.22663993,
#   'max_mean': 2.03154218687594,
#   'max_sigma': 0.08399714092933555,
#   'max_amplitude': 0.22404151653773077,
#   'max_incidence': 69.64509,
#   'max_emission': 64.18774,
#   'max_phase': 116.6643,
#   'max_lat': 86.01255,
#   'max_lon': 253.71548,
#   'min_real_amplitude': 0.10745689,
#   'min_mean': 2.027931065972358,
#   'min_sigma': 0.06981430070528065,
#   'min_amplitude': 0.11135130303603201,
#   'min_incidence': 58.10717,
#   'min_emission': 47.839752,
#   'min_phase': 116.38781,
#   'min_lat': 61.166286,
#   'min_lon': 54.600075},
#  'CM_1844024466_1_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (30, 22),
#   'max_real_amplitude': 0.26863787,
#   'max_mean': 2.049289109959893,
#   'max_sigma': 0.08606914798253675,
#   'max_amplitude': 0.26396803567012694,
#   'max_incidence': 86.24114,
#   'max_emission': 86.07027,
#   'max_phase': 115.75304,
#   'max_lat': 89.96786,
#   'max_lon': 359.98093,
#   'min_real_amplitude': 0.052381586,
#   'min_mean': 2.0274174428209233,
#   'min_sigma': 0.06420896888957825,
#   'min_amplitude': 0.05075109027953737,
#   'min_incidence': 31.387592,
#   'min_emission': 28.89532,
#   'min_phase': 115.12952,
#   'min_lat': 54.352104,
#   'min_lon': 0.30450124},
#  'CM_1844023908_1_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (28, 60),
#   'max_real_amplitude': 0.26990288,
#   'max_mean': 2.0322543886863063,
#   'max_sigma': 0.1288989518926457,
#   'max_amplitude': 0.26419704417472745,
#   'max_incidence': 98.89308,
#   'max_emission': 88.75805,
#   'max_phase': 115.762314,
#   'max_lat': 84.53504,
#   'max_lon': 359.74002,
#   'min_real_amplitude': 0.010918911,
#   'min_mean': 2.0240398238234074,
#   'min_sigma': 0.06795377593802777,
#   'min_amplitude': 0.009982019425584847,
#   'min_incidence': 35.160435,
#   'min_emission': 28.760859,
#   'min_phase': 114.801476,
#   'min_lat': 34.901474,
#   'min_lon': 0.0925173},
#  'CM_1844022476_1_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (32, 64),
#   'max_real_amplitude': 0.35641807,
#   'max_mean': 2.035044050848435,
#   'max_sigma': 0.10662961974940924,
#   'max_amplitude': 0.34367259388340893,
#   'max_incidence': 98.3817,
#   'max_emission': 88.48702,
#   'max_phase': 116.006836,
#   'max_lat': 89.5284,
#   'max_lon': 359.55197,
#   'min_real_amplitude': 0.012153833,
#   'min_mean': 2.0159293363402906,
#   'min_sigma': 0.052961527038403525,
#   'min_amplitude': 0.011633031094727029,
#   'min_incidence': 27.797688,
#   'min_emission': 24.916416,
#   'min_phase': 114.821106,
#   'min_lat': 29.844736,
#   'min_lon': 0.8053088},
#  'CM_1844018304_1_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (64, 2),
#   'max_real_amplitude': 0.086818464,
#   'max_mean': 2.03092784376215,
#   'max_sigma': 0.0938413976178798,
#   'max_amplitude': 0.08776076014136668,
#   'max_incidence': 89.170876,
#   'max_emission': 44.886227,
#   'max_phase': 115.95657,
#   'max_lat': 66.25535,
#   'max_lon': 212.48091,
#   'min_real_amplitude': 0.03061444,
#   'min_mean': 2.026256664532007,
#   'min_sigma': 0.085075057029143,
#   'min_amplitude': 0.03036266652777072,
#   'min_incidence': 79.991486,
#   'min_emission': 27.60969,
#   'min_phase': 115.68745,
#   'min_lat': 54.855564,
#   'min_lon': 94.661095},
#  'CM_1844016215_1_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (64, 2),
#   'max_real_amplitude': 0.061358724,
#   'max_mean': 2.031081088263966,
#   'max_sigma': 0.09692609764501663,
#   'max_amplitude': 0.06218176162782062,
#   'max_incidence': 91.61021,
#   'max_emission': 38.79984,
#   'max_phase': 116.300354,
#   'max_lat': 63.64516,
#   'max_lon': 201.95335,
#   'min_real_amplitude': 0.023128835,
#   'min_mean': 2.0261816711445877,
#   'min_sigma': 0.08699823284025847,
#   'min_amplitude': 0.023394954910835562,
#   'min_incidence': 84.23186,
#   'min_emission': 25.525211,
#   'min_phase': 116.01612,
#   'min_lat': 56.039482,
#   'min_lon': 105.13595},
#  'CM_1844018085_1_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (64, 2),
#   'max_real_amplitude': 0.11934984,
#   'max_mean': 2.035601832570031,
#   'max_sigma': 0.08827682182837086,
#   'max_amplitude': 0.1202686597109238,
#   'max_incidence': 84.8158,
#   'max_emission': 48.45081,
#   'max_phase': 116.118645,
#   'max_lat': 70.63816,
#   'max_lon': 219.31526,
#   'min_real_amplitude': 0.04774865,
#   'min_mean': 2.0269591253945016,
#   'min_sigma': 0.07715488548270967,
#   'min_amplitude': 0.048464930335214894,
#   'min_incidence': 75.46886,
#   'min_emission': 32.094234,
#   'min_phase': 115.847565,
#   'min_lat': 57.58792,
#   'min_lon': 88.25547},
#  'CM_1844026758_1_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (28, 60),
#   'max_real_amplitude': 0.22737344,
#   'max_mean': 2.259691099829667,
#   'max_sigma': 0.25972954638296325,
#   'max_amplitude': 0.22762961552272568,
#   'max_incidence': 117.129005,
#   'max_emission': 88.38158,
#   'max_phase': 115.280495,
#   'max_lat': 70.364586,
#   'max_lon': 130.29393,
#   'min_real_amplitude': 0.00050719734,
#   'min_mean': 1.710449813343119,
#   'min_sigma': 0.008142137032749892,
#   'min_amplitude': 0.00032318249938650327,
#   'min_incidence': 48.72085,
#   'min_emission': 23.550688,
#   'min_phase': 114.2544,
#   'min_lat': 13.765196,
#   'min_lon': 19.08882},
#  'CM_1844016846_1_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (64, 2),
#   'max_real_amplitude': 0.27777043,
#   'max_mean': 2.0293345176577184,
#   'max_sigma': 0.08658039042171795,
#   'max_amplitude': 0.28121881964892986,
#   'max_incidence': 56.962597,
#   'max_emission': 87.60493,
#   'max_phase': 117.04863,
#   'max_lat': 82.592255,
#   'max_lon': 359.33606,
#   'min_real_amplitude': 0.18325813,
#   'min_mean': 2.0277087869059565,
#   'min_sigma': 0.06936712332247642,
#   'min_amplitude': 0.18140288518318032,
#   'min_incidence': 35.33084,
#   'min_emission': 60.867054,
#   'min_phase': 116.77288,
#   'min_lat': 48.372032,
#   'min_lon': 0.08450602},
#  'CM_1844018450_1_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (64, 2),
#   'max_real_amplitude': 0.06988751,
#   'max_mean': 2.031477406274543,
#   'max_sigma': 0.10518425000686069,
#   'max_amplitude': 0.07036239384436016,
#   'max_incidence': 92.00664,
#   'max_emission': 42.796204,
#   'max_phase': 115.85,
#   'max_lat': 63.392994,
#   'max_lon': 208.73784,
#   'min_real_amplitude': 0.021095823,
#   'min_mean': 2.0180358499019815,
#   'min_sigma': 0.08771338779646243,
#   'min_amplitude': 0.020916295452781654,
#   'min_incidence': 82.87987,
#   'min_emission': 24.656855,
#   'min_phase': 115.582306,
#   'min_lat': 52.829376,
#   'min_lon': 98.03591},
#  'CM_1844031020_1_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (28, 28),
#   'max_real_amplitude': 0.27331114,
#   'max_mean': 2.0483744474833405,
#   'max_sigma': 0.1351438840066189,
#   'max_amplitude': 0.26730992074010007,
#   'max_incidence': 108.4474,
#   'max_emission': 89.69771,
#   'max_phase': 115.13837,
#   'max_lat': 86.94407,
#   'max_lon': 356.95905,
#   'min_real_amplitude': 0.001823816,
#   'min_mean': 1.9879395942982454,
#   'min_sigma': 0.06742556960334067,
#   'min_amplitude': 0.0014000425718283082,
#   'min_incidence': 40.43782,
#   'min_emission': 9.266751,
#   'min_phase': 114.36452,
#   'min_lat': 24.653097,
#   'min_lon': 0.01596429},
#  'CM_1844016992_1_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (64, 2),
#   'max_real_amplitude': 0.3234553,
#   'max_mean': 2.029746791238959,
#   'max_sigma': 0.08281421683225676,
#   'max_amplitude': 0.30966537134658034,
#   'max_incidence': 60.90454,
#   'max_emission': 77.34417,
#   'max_phase': 116.940956,
#   'max_lat': 86.4816,
#   'max_lon': 358.21387,
#   'min_real_amplitude': 0.15476458,
#   'min_mean': 2.026286133432081,
#   'min_sigma': 0.056786125548768177,
#   'min_amplitude': 0.15460518039877647,
#   'min_incidence': 45.088696,
#   'min_emission': 56.861126,
#   'min_phase': 116.66181,
#   'min_lat': 55.44744,
#   'min_lon': 4.5584636},
#  'CM_1844028226_1_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (24, 20),
#   'max_real_amplitude': 0.26219338,
#   'max_mean': 2.031420702676528,
#   'max_sigma': 0.09720832583216706,
#   'max_amplitude': 0.2567466590696925,
#   'max_incidence': 93.93778,
#   'max_emission': 86.428246,
#   'max_phase': 115.37775,
#   'max_lat': 89.434135,
#   'max_lon': 359.56677,
#   'min_real_amplitude': 0.018693471,
#   'min_mean': 2.027480399943362,
#   'min_sigma': 0.06612736733532978,
#   'min_amplitude': 0.018069811725026395,
#   'min_incidence': 33.844322,
#   'min_emission': 21.712982,
#   'min_phase': 114.738365,
#   'min_lat': 49.726055,
#   'min_lon': 1.3331479},
#  'CM_1844027291_1_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (30, 22),
#   'max_real_amplitude': 0.25216436,
#   'max_mean': 2.0312064790821203,
#   'max_sigma': 0.08999790926520024,
#   'max_amplitude': 0.24862570857527325,
#   'max_incidence': 88.08463,
#   'max_emission': 88.36791,
#   'max_phase': 115.40285,
#   'max_lat': 88.01758,
#   'max_lon': 185.68608,
#   'min_real_amplitude': 0.039703257,
#   'min_mean': 2.02752911468327,
#   'min_sigma': 0.06858133955653228,
#   'min_amplitude': 0.039910241420915954,
#   'min_incidence': 39.83648,
#   'min_emission': 27.045687,
#   'min_phase': 114.89706,
#   'min_lat': 44.826073,
#   'min_lon': 0.3749572},
#  'CM_1844017137_1_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (64, 2),
#   'max_real_amplitude': 0.25124317,
#   'max_mean': 2.0313298598297527,
#   'max_sigma': 0.08134966932172473,
#   'max_amplitude': 0.2536228913680972,
#   'max_incidence': 64.511505,
#   'max_emission': 71.11109,
#   'max_phase': 116.83098,
#   'max_lat': 89.83608,
#   'max_lon': 337.57672,
#   'min_real_amplitude': 0.13411747,
#   'min_mean': 2.0279433581771436,
#   'min_sigma': 0.06560424017083308,
#   'min_amplitude': 0.13607572551597055,
#   'min_incidence': 51.119633,
#   'min_emission': 53.119728,
#   'min_phase': 116.5527,
#   'min_lat': 58.884842,
#   'min_lon': 8.424683},
#  'CM_1844017283_1_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (64, 2),
#   'max_real_amplitude': 0.24031761,
#   'max_mean': 2.031307039634979,
#   'max_sigma': 0.08244235833279345,
#   'max_amplitude': 0.23653385192746548,
#   'max_incidence': 67.89452,
#   'max_emission': 66.202805,
#   'max_phase': 116.71882,
#   'max_lat': 87.77565,
#   'max_lon': 257.96402,
#   'min_real_amplitude': 0.11988426,
#   'min_mean': 2.027792745121806,
#   'min_sigma': 0.06979995950367285,
#   'min_amplitude': 0.12229189244400616,
#   'min_incidence': 56.02516,
#   'min_emission': 49.61675,
#   'min_phase': 116.443375,
#   'min_lat': 60.730656,
#   'min_lon': 50.088657},
#  'CM_1844016142_1_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (64, 2),
#   'max_real_amplitude': 0.06831444,
#   'max_mean': 2.0322012152470768,
#   'max_sigma': 0.09626596347053204,
#   'max_amplitude': 0.06872455341506037,
#   'max_incidence': 90.48178,
#   'max_emission': 39.733738,
#   'max_phase': 116.35756,
#   'max_lat': 64.80837,
#   'max_lon': 203.42043,
#   'min_real_amplitude': 0.027176892,
#   'min_mean': 2.0211258432299997,
#   'min_sigma': 0.0836764829186575,
#   'min_amplitude': 0.027242506653548812,
#   'min_incidence': 83.050476,
#   'min_emission': 26.742304,
#   'min_phase': 116.072784,
#   'min_lat': 56.951008,
#   'min_lon': 103.90033},
#  'CM_1844017210_1_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (64, 2),
#   'max_real_amplitude': 0.24847269,
#   'max_mean': 2.0316065578449503,
#   'max_sigma': 0.08228514728003146,
#   'max_amplitude': 0.24849259430313453,
#   'max_incidence': 66.282425,
#   'max_emission': 68.51807,
#   'max_phase': 116.77509,
#   'max_lat': 89.45255,
#   'max_lon': 262.5593,
#   'min_real_amplitude': 0.12883393,
#   'min_mean': 2.0276113352191496,
#   'min_sigma': 0.06605809619699524,
#   'min_amplitude': 0.13130897174405737,
#   'min_incidence': 53.680172,
#   'min_emission': 51.296726,
#   'min_phase': 116.49628,
#   'min_lat': 59.993294,
#   'min_lon': 45.716015},
#  'CM_1844016773_1_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (64, 2),
#   'max_real_amplitude': 0.2723814,
#   'max_mean': 2.030015132978091,
#   'max_sigma': 0.08641093691588084,
#   'max_amplitude': 0.27715965650301155,
#   'max_incidence': 54.810112,
#   'max_emission': 84.84117,
#   'max_phase': 117.093315,
#   'max_lat': 80.36666,
#   'max_lon': 358.1944,
#   'min_real_amplitude': 0.20393994,
#   'min_mean': 2.0277625141350764,
#   'min_sigma': 0.0690252055652252,
#   'min_amplitude': 0.20008543822592453,
#   'min_incidence': 36.405746,
#   'min_emission': 63.15127,
#   'min_phase': 116.827194,
#   'min_lat': 51.445076,
#   'min_lon': 0.22565958},
#  'CM_1844024868_1_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (28, 60),
#   'max_real_amplitude': 0.25607812,
#   'max_mean': 2.047562511075177,
#   'max_sigma': 0.1807684611213576,
#   'max_amplitude': 0.25578890754796985,
#   'max_incidence': 105.28637,
#   'max_emission': 87.093056,
#   'max_phase': 115.592316,
#   'max_lat': 78.91148,
#   'max_lon': 141.7344,
#   'min_real_amplitude': 0.0040922873,
#   'min_mean': 1.9065733739284705,
#   'min_sigma': 0.07362608578226183,
#   'min_amplitude': 0.0034576513915243884,
#   'min_incidence': 39.485523,
#   'min_emission': 26.88277,
#   'min_phase': 114.589584,
#   'min_lat': 27.580633,
#   'min_lon': 3.6468935},
#  'CM_1844017794_1_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (64, 2),
#   'max_real_amplitude': 0.1673411,
#   'max_mean': 2.030973228499988,
#   'max_sigma': 0.08601457468556066,
#   'max_amplitude': 0.1663734649295962,
#   'max_incidence': 78.9256,
#   'max_emission': 53.951824,
#   'max_phase': 116.3365,
#   'max_lat': 76.521545,
#   'max_lon': 230.93808,
#   'min_real_amplitude': 0.070798606,
#   'min_mean': 2.028351143545001,
#   'min_sigma': 0.07551705655638696,
#   'min_amplitude': 0.07206885167156635,
#   'min_incidence': 69.06126,
#   'min_emission': 38.170383,
#   'min_phase': 116.063255,
#   'min_lat': 60.368534,
#   'min_lon': 77.248924},
#  'CM_1844029162_1_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (24, 20),
#   'max_real_amplitude': 0.26183194,
#   'max_mean': 2.0339549493841553,
#   'max_sigma': 0.09820707780827392,
#   'max_amplitude': 0.25624984162765974,
#   'max_incidence': 94.478134,
#   'max_emission': 88.62578,
#   'max_phase': 115.28914,
#   'max_lat': 89.16097,
#   'max_lon': 359.70917,
#   'min_real_amplitude': 0.017448941,
#   'min_mean': 2.027100703912062,
#   'min_sigma': 0.06754296429138497,
#   'min_amplitude': 0.016250752794371548,
#   'min_incidence': 37.208996,
#   'min_emission': 21.224302,
#   'min_phase': 114.68475,
#   'min_lat': 45.250423,
#   'min_lon': 2.1895945},
#  'CM_1844027693_1_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (26, 32),
#   'max_real_amplitude': 0.28960404,
#   'max_mean': 2.031999926845563,
#   'max_sigma': 0.12541320352729876,
#   'max_amplitude': 0.27930584310933665,
#   'max_incidence': 104.528175,
#   'max_emission': 85.183525,
#   'max_phase': 115.44521,
#   'max_lat': 89.64336,
#   'max_lon': 359.98233,
#   'min_real_amplitude': 0.0038173245,
#   'min_mean': 1.9921476291692506,
#   'min_sigma': 0.06239634857774809,
#   'min_amplitude': 0.003380696173094737,
#   'min_incidence': 35.107834,
#   'min_emission': 21.788939,
#   'min_phase': 114.53668,
#   'min_lat': 32.158432,
#   'min_lon': 1.3491528},
#  'CM_1844017939_1_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (64, 2),
#   'max_real_amplitude': 0.14513609,
#   'max_mean': 2.0319556572831114,
#   'max_sigma': 0.09583323056359981,
#   'max_amplitude': 0.14450496258442408,
#   'max_incidence': 81.93244,
#   'max_emission': 51.09447,
#   'max_phase': 116.22662,
#   'max_lat': 73.55922,
#   'max_lon': 224.74124,
#   'min_real_amplitude': 0.057549912,
#   'min_mean': 2.015584660417489,
#   'min_sigma': 0.07596728715284276,
#   'min_amplitude': 0.05886088082859383,
#   'min_incidence': 72.3481,
#   'min_emission': 35.09614,
#   'min_phase': 115.954575,
#   'min_lat': 59.073917,
#   'min_lon': 83.24663},
#  'CM_1844017065_1_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (64, 2),
#   'max_real_amplitude': 0.26192257,
#   'max_mean': 2.0310528489063455,
#   'max_sigma': 0.08137563823283792,
#   'max_amplitude': 0.26385237921843474,
#   'max_incidence': 62.75117,
#   'max_emission': 73.88141,
#   'max_phase': 116.885216,
#   'max_lat': 88.39735,
#   'max_lon': 349.10992,
#   'min_real_amplitude': 0.14617004,
#   'min_mean': 2.0275392373749965,
#   'min_sigma': 0.06761563235044578,
#   'min_amplitude': 0.14670549274833908,
#   'min_incidence': 48.4087,
#   'min_emission': 54.881634,
#   'min_phase': 116.60847,
#   'min_lat': 57.493656,
#   'min_lon': 1.3461951},
#  'CM_1844035988_1_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (64, 34),
#   'max_real_amplitude': 0.2498281,
#   'max_mean': 2.0820748909456546,
#   'max_sigma': 0.3529384017869775,
#   'max_amplitude': 0.2464064617775207,
#   'max_incidence': 114.69814,
#   'max_emission': 88.205055,
#   'max_phase': 115.01102,
#   'max_lat': 89.242256,
#   'max_lon': 359.14502,
#   'min_real_amplitude': 0.0005635845,
#   'min_mean': 1.7372560033233755,
#   'min_sigma': 0.012263748124493755,
#   'min_amplitude': 0.00028729845750988996,
#   'min_incidence': 27.858604,
#   'min_emission': 0.35061035,
#   'min_phase': 114.10601,
#   'min_lat': 4.7405386,
#   'min_lon': 0.8469273},
#  'CM_1844017721_1_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (64, 2),
#   'max_real_amplitude': 0.17973255,
#   'max_mean': 2.0315035465215616,
#   'max_sigma': 0.08507166532386311,
#   'max_amplitude': 0.17825638659980733,
#   'max_incidence': 77.43844,
#   'max_emission': 55.49175,
#   'max_phase': 116.39154,
#   'max_lat': 78.08144,
#   'max_lon': 234.35971,
#   'min_real_amplitude': 0.079038806,
#   'min_mean': 2.028318700181882,
#   'min_sigma': 0.07593638696417285,
#   'min_amplitude': 0.08093530465575086,
#   'min_incidence': 67.35245,
#   'min_emission': 39.767284,
#   'min_phase': 116.117195,
#   'min_lat': 60.85784,
#   'min_lon': 73.98006},
#  'CM_1844037474_1_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (64, 34),
#   'max_real_amplitude': 0.24832803,
#   'max_mean': 2.2738517751063014,
#   'max_sigma': 0.17356311593261287,
#   'max_amplitude': 0.24402207996410966,
#   'max_incidence': 116.17453,
#   'max_emission': 87.88701,
#   'max_phase': 114.94259,
#   'max_lat': 89.02463,
#   'max_lon': 359.40634,
#   'min_real_amplitude': 0.00046744413,
#   'min_mean': 1.8749771275724283,
#   'min_sigma': 0.0028370727320069867,
#   'min_amplitude': 0.0003158922796580258,
#   'min_incidence': 27.649889,
#   'min_emission': 1.1058038,
#   'min_phase': 114.065384,
#   'min_lat': 6.538716,
#   'min_lon': 0.72477627},
#  'CM_1844022903_1_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (28, 60),
#   'max_real_amplitude': 0.2789519,
#   'max_mean': 2.0338696614556206,
#   'max_sigma': 0.10428736738497435,
#   'max_amplitude': 0.2723242233462853,
#   'max_incidence': 91.546715,
#   'max_emission': 89.27892,
#   'max_phase': 115.93987,
#   'max_lat': 89.29424,
#   'max_lon': 359.2387,
#   'min_real_amplitude': 0.028073898,
#   'min_mean': 2.026474039860544,
#   'min_sigma': 0.0656749359906471,
#   'min_amplitude': 0.027791421069639336,
#   'min_incidence': 28.582016,
#   'min_emission': 30.609552,
#   'min_phase': 115.07038,
#   'min_lat': 43.51654,
#   'min_lon': 0.04084482},
#  'CM_1844030097_1_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (28, 28),
#   'max_real_amplitude': 0.26902074,
#   'max_mean': 2.0443987866393045,
#   'max_sigma': 0.1350972594736272,
#   'max_amplitude': 0.26373165523696324,
#   'max_incidence': 107.74338,
#   'max_emission': 87.25877,
#   'max_phase': 115.20966,
#   'max_lat': 89.68329,
#   'max_lon': 359.71002,
#   'min_real_amplitude': 0.002098802,
#   'min_mean': 1.9768825507902337,
#   'min_sigma': 0.06681509946985542,
#   'min_amplitude': 0.0015845475663289175,
#   'min_incidence': 39.099533,
#   'min_emission': 10.570883,
#   'min_phase': 114.41076,
#   'min_lat': 29.080202,
#   'min_lon': 0.06282235},
#  'CM_1844016700_1_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (64, 2),
#   'max_real_amplitude': 0.26929623,
#   'max_mean': 2.0292319475933454,
#   'max_sigma': 0.08685933857466852,
#   'max_amplitude': 0.27443449596496544,
#   'max_incidence': 52.513344,
#   'max_emission': 87.648285,
#   'max_phase': 117.137886,
#   'max_lat': 78.13465,
#   'max_lon': 359.1661,
#   'min_real_amplitude': 0.21560682,
#   'min_mean': 2.0280786358487086,
#   'min_sigma': 0.06844421975342611,
#   'min_amplitude': 0.21346709569907962,
#   'min_incidence': 34.4505,
#   'min_emission': 65.440704,
#   'min_phase': 116.88368,
#   'min_lat': 50.069607,
#   'min_lon': 0.09660273},
#  'CM_1844023503_1_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (30, 22),
#   'max_real_amplitude': 0.37790304,
#   'max_mean': 2.031057372959358,
#   'max_sigma': 0.08463417554505269,
#   'max_amplitude': 0.36591306429592774,
#   'max_incidence': 85.39757,
#   'max_emission': 87.648636,
#   'max_phase': 115.88104,
#   'max_lat': 89.80835,
#   'max_lon': 358.00232,
#   'min_real_amplitude': 0.05594907,
#   'min_mean': 2.02667950481327,
#   'min_sigma': 0.05143971872519098,
#   'min_amplitude': 0.056973352026911776,
#   'min_incidence': 28.294174,
#   'min_emission': 29.98524,
#   'min_phase': 115.22928,
#   'min_lat': 54.484604,
#   'min_lon': 0.9426005},
#  'CM_1844016919_1_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (64, 2),
#   'max_real_amplitude': 0.27705473,
#   'max_mean': 2.0294540122989932,
#   'max_sigma': 0.08425592620090834,
#   'max_amplitude': 0.2820439543947636,
#   'max_incidence': 59.00572,
#   'max_emission': 82.15079,
#   'max_phase': 116.997025,
#   'max_lat': 84.531235,
#   'max_lon': 356.3737,
#   'min_real_amplitude': 0.16836512,
#   'min_mean': 2.0275043293692314,
#   'min_sigma': 0.06555643413180173,
#   'min_amplitude': 0.16758538666841602,
#   'min_incidence': 40.61812,
#   'min_emission': 58.84607,
#   'min_phase': 116.71626,
#   'min_lat': 52.150326,
#   'min_lon': 1.0708386},
#  'CM_1844018231_1_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (64, 2),
#   'max_real_amplitude': 0.09943719,
#   'max_mean': 2.0310718614925145,
#   'max_sigma': 0.09226275827748841,
#   'max_amplitude': 0.10039168690092139,
#   'max_incidence': 87.7209,
#   'max_emission': 46.086956,
#   'max_phase': 116.01097,
#   'max_lat': 67.75026,
#   'max_lon': 214.7045,
#   'min_real_amplitude': 0.035779875,
#   'min_mean': 2.027832165444907,
#   'min_sigma': 0.08220943099977325,
#   'min_amplitude': 0.03580870963230815,
#   'min_incidence': 78.47097,
#   'min_emission': 29.143501,
#   'min_phase': 115.74167,
#   'min_lat': 55.7855,
#   'min_lon': 92.64722},
#  'CM_1844025813_1_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (28, 60),
#   'max_real_amplitude': 0.24493498,
#   'max_mean': 90.4409040033909,
#   'max_sigma': 7.812988030847335,
#   'max_amplitude': 2.6647317941593646e+25,
#   'max_incidence': 111.30206,
#   'max_emission': 88.48202,
#   'max_phase': 115.43453,
#   'max_lat': 74.328766,
#   'max_lon': 135.06102,
#   'min_real_amplitude': 0.0013017793,
#   'min_mean': 2.0049702011441464,
#   'min_sigma': 0.02076169436153279,
#   'min_amplitude': 0.0008995648113561956,
#   'min_incidence': 42.790997,
#   'min_emission': 25.164608,
#   'min_phase': 114.40919,
#   'min_lat': 20.89714,
#   'min_lon': 10.622121},
#  'CM_1844017648_1_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (64, 2),
#   'max_real_amplitude': 0.18839714,
#   'max_mean': 2.031627823983942,
#   'max_sigma': 0.08487348219346177,
#   'max_amplitude': 0.18741672065005646,
#   'max_incidence': 75.924675,
#   'max_emission': 56.986183,
#   'max_phase': 116.44464,
#   'max_lat': 79.659,
#   'max_lon': 237.74294,
#   'min_real_amplitude': 0.084222116,
#   'min_mean': 2.0280545554025955,
#   'min_sigma': 0.07435903350424834,
#   'min_amplitude': 0.08687362758526662,
#   'min_incidence': 65.700386,
#   'min_emission': 41.3783,
#   'min_phase': 116.171776,
#   'min_lat': 61.261894,
#   'min_lon': 70.46559},
#  'CM_1844016481_1_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (64, 2),
#   'max_real_amplitude': 0.25648722,
#   'max_mean': 2.029173128484193,
#   'max_sigma': 0.08649268484275291,
#   'max_amplitude': 0.26287055812367893,
#   'max_incidence': 44.150867,
#   'max_emission': 86.76538,
#   'max_phase': 117.26387,
#   'max_lat': 69.81298,
#   'max_lon': 359.40195,
#   'min_real_amplitude': 0.23939821,
#   'min_mean': 2.028304390517846,
#   'min_sigma': 0.07707265753172812,
#   'min_amplitude': 0.23916750046810242,
#   'min_incidence': 30.886513,
#   'min_emission': 73.91078,
#   'min_phase': 117.09262,
#   'min_lat': 54.66359,
#   'min_lon': 0.08358163},
#  'CM_1844041608_1_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (64, 28),
#   'max_real_amplitude': 0.25276116,
#   'max_mean': 2.0425503907096654,
#   'max_sigma': 0.29171287587846517,
#   'max_amplitude': 0.2444186901824319,
#   'max_incidence': 109.21536,
#   'max_emission': 88.667816,
#   'max_phase': 114.838615,
#   'max_lat': 89.47353,
#   'max_lon': 357.18982,
#   'min_real_amplitude': 0.0014656308,
#   'min_mean': 1.8604859576666282,
#   'min_sigma': 0.007772744085740793,
#   'min_amplitude': 0.0009484529635425649,
#   'min_incidence': 30.898634,
#   'min_emission': 5.4935007,
#   'min_phase': 114.14245,
#   'min_lat': 9.105942,
#   'min_lon': 2.3225255},
#  'CM_1844031957_1_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (28, 28),
#   'max_real_amplitude': 0.27836445,
#   'max_mean': 2.0496890173828337,
#   'max_sigma': 0.1348989800737653,
#   'max_amplitude': 0.27302509964366894,
#   'max_incidence': 109.301834,
#   'max_emission': 85.98376,
#   'max_phase': 115.10065,
#   'max_lat': 83.91675,
#   'max_lon': 358.8091,
#   'min_real_amplitude': 0.001431413,
#   'min_mean': 1.9833899925078122,
#   'min_sigma': 0.06765631552331296,
#   'min_amplitude': 0.0011057688303792387,
#   'min_incidence': 44.27279,
#   'min_emission': 7.855391,
#   'min_phase': 114.24977,
#   'min_lat': 20.479168,
#   'min_lon': 2.1581814},
#  'CM_1844018012_1_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (64, 2),
#   'max_real_amplitude': 0.13201882,
#   'max_mean': 2.0313926427443123,
#   'max_sigma': 0.08806756515195557,
#   'max_amplitude': 0.1317372581879429,
#   'max_incidence': 83.38577,
#   'max_emission': 49.746674,
#   'max_phase': 116.172554,
#   'max_lat': 72.149994,
#   'max_lon': 221.93814,
#   'min_real_amplitude': 0.052365046,
#   'min_mean': 2.028457658300034,
#   'min_sigma': 0.07809926875491743,
#   'min_amplitude': 0.05283166935378912,
#   'min_incidence': 73.922966,
#   'min_emission': 33.673862,
#   'min_phase': 115.90195,
#   'min_lat': 58.36429,
#   'min_lon': 85.8126},
#  'CM_1844016288_1_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (64, 2),
#   'max_real_amplitude': 0.07184752,
#   'max_mean': 2.0407782946886863,
#   'max_sigma': 0.10688306552810631,
#   'max_amplitude': 0.05473327074011168,
#   'max_incidence': 92.80698,
#   'max_emission': 37.935802,
#   'max_phase': 116.24347,
#   'max_lat': 62.506886,
#   'max_lon': 200.65736,
#   'min_real_amplitude': 0.019903962,
#   'min_mean': 2.0254068695547516,
#   'min_sigma': 0.08283064244989888,
#   'min_amplitude': 0.01964714797606335,
#   'min_incidence': 85.39513,
#   'min_emission': 24.330578,
#   'min_phase': 115.959496,
#   'min_lat': 55.076435,
#   'min_lon': 106.33354},
#  'CM_1844016554_1_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (64, 2),
#   'max_real_amplitude': 0.2658462,
#   'max_mean': 2.0295865251740914,
#   'max_sigma': 0.08705237493476672,
#   'max_amplitude': 0.2655545195023701,
#   'max_incidence': 47.30919,
#   'max_emission': 87.36844,
#   'max_phase': 117.22638,
#   'max_lat': 72.97745,
#   'max_lon': 359.18066,
#   'min_real_amplitude': 0.23164842,
#   'min_mean': 2.0274274144694875,
#   'min_sigma': 0.07154935835789399,
#   'min_amplitude': 0.23037270722819234,
#   'min_incidence': 31.157919,
#   'min_emission': 70.71267,
#   'min_phase': 117.01994,
#   'min_lat': 52.78565,
#   'min_lon': 0.061645143},
#  'CM_1844018377_1_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (64, 2),
#   'max_real_amplitude': 0.09485014,
#   'max_mean': 2.035360071755296,
#   'max_sigma': 0.10133237163581074,
#   'max_amplitude': 0.07936528441317518,
#   'max_incidence': 90.59641,
#   'max_emission': 43.739906,
#   'max_phase': 115.90217,
#   'max_lat': 64.841354,
#   'max_lon': 210.41472,
#   'min_real_amplitude': 0.025016336,
#   'min_mean': 2.027357111178975,
#   'min_sigma': 0.07841860614148707,
#   'min_amplitude': 0.025309606806470507,
#   'min_incidence': 81.49587,
#   'min_emission': 26.123959,
#   'min_phase': 115.63536,
#   'min_lat': 53.880894,
#   'min_lon': 96.432976},
#  'CM_1844017429_1_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (64, 2),
#   'max_real_amplitude': 0.21910907,
#   'max_mean': 2.031381720597178,
#   'max_sigma': 0.08372392756774372,
#   'max_amplitude': 0.2160347197690267,
#   'max_incidence': 71.27134,
#   'max_emission': 62.16745,
#   'max_phase': 116.60826,
#   'max_lat': 84.36906,
#   'max_lon': 249.36835,
#   'min_real_amplitude': 0.10358989,
#   'min_mean': 2.0281028271131785,
#   'min_sigma': 0.07063087182997238,
#   'min_amplitude': 0.10623832113357673,
#   'min_incidence': 60.18913,
#   'min_emission': 46.172318,
#   'min_phase': 116.33456,
#   'min_lat': 61.486732,
#   'min_lon': 58.799717},
#  'CM_1844025417_1_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (30, 22),
#   'max_real_amplitude': 0.26595384,
#   'max_mean': 2.030939069846705,
#   'max_sigma': 0.08784298286542967,
#   'max_amplitude': 0.26050749773725895,
#   'max_incidence': 86.9655,
#   'max_emission': 87.29053,
#   'max_phase': 115.63741,
#   'max_lat': 89.65679,
#   'max_lon': 359.5471,
#   'min_real_amplitude': 0.04808597,
#   'min_mean': 2.0273529796964556,
#   'min_sigma': 0.06543748217807806,
#   'min_amplitude': 0.0483975239338146,
#   'min_incidence': 33.2568,
#   'min_emission': 28.096247,
#   'min_phase': 115.04184,
#   'min_lat': 50.22304,
#   'min_lon': 0.020561522},
#  'CM_1844016360_6_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (64, 2),
#   'max_real_amplitude': 0.049534492,
#   'max_mean': 2.08,
#   'max_sigma': 0.125,
#   'max_amplitude': 0.1,
#   'max_incidence': 93.924805,
#   'max_emission': 37.084377,
#   'max_phase': 116.18631,
#   'max_lat': 61.323845,
#   'max_lon': 199.41508,
#   'min_real_amplitude': -3.4028227e+38,
#   'min_mean': 2.0253943951527416,
#   'min_sigma': 0.08912299413050692,
#   'min_amplitude': 0.020106325322061365,
#   'min_incidence': 86.57085,
#   'min_emission': 23.098938,
#   'min_phase': 115.90926,
#   'min_lat': 54.087036,
#   'min_lon': 108.392845},
#  'CM_1844018158_1_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (64, 2),
#   'max_real_amplitude': 0.10906846,
#   'max_mean': 2.031133406272935,
#   'max_sigma': 0.09071411706207423,
#   'max_amplitude': 0.10997742395082678,
#   'max_incidence': 86.22885,
#   'max_emission': 47.1533,
#   'max_phase': 116.063095,
#   'max_lat': 69.15899,
#   'max_lon': 216.76378,
#   'min_real_amplitude': 0.041681357,
#   'min_mean': 2.0279661893050185,
#   'min_sigma': 0.08214574167670537,
#   'min_amplitude': 0.04177711115642262,
#   'min_incidence': 77.05628,
#   'min_emission': 30.588543,
#   'min_phase': 115.79542,
#   'min_lat': 56.707474,
#   'min_lon': 90.63659},
#  'CM_1844026361_1_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (30, 22),
#   'max_real_amplitude': 0.26197606,
#   'max_mean': 2.0309443110867553,
#   'max_sigma': 0.09345496515392171,
#   'max_amplitude': 0.2567607511755512,
#   'max_incidence': 87.496666,
#   'max_emission': 89.14899,
#   'max_phase': 115.51551,
#   'max_lat': 89.25945,
#   'max_lon': 359.63895,
#   'min_real_amplitude': 0.04686548,
#   'min_mean': 2.0255264487003837,
#   'min_sigma': 0.06470000995089081,
#   'min_amplitude': 0.047093008539999245,
#   'min_incidence': 34.39617,
#   'min_emission': 27.580057,
#   'min_phase': 114.966125,
#   'min_lat': 47.14226,
#   'min_lon': 0.08322895},
#  'CM_1844016627_1_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (64, 2),
#   'max_real_amplitude': 0.26940253,
#   'max_mean': 2.0291037567178414,
#   'max_sigma': 0.08691009855469199,
#   'max_amplitude': 0.2697427914881378,
#   'max_incidence': 50.01981,
#   'max_emission': 88.16151,
#   'max_phase': 117.18191,
#   'max_lat': 75.6046,
#   'max_lon': 359.66547,
#   'min_real_amplitude': 0.22665773,
#   'min_mean': 2.027931569747382,
#   'min_sigma': 0.06898009768728655,
#   'min_amplitude': 0.22427099160677785,
#   'min_incidence': 34.09724,
#   'min_emission': 68.026245,
#   'min_phase': 116.95094,
#   'min_lat': 50.88577,
#   'min_lon': 1.0632576},
#  'CM_1844017575_1_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (64, 2),
#   'max_real_amplitude': 0.19611456,
#   'max_mean': 2.031733110430903,
#   'max_sigma': 0.08388940362951096,
#   'max_amplitude': 0.1953778959753751,
#   'max_incidence': 74.3901,
#   'max_emission': 58.661064,
#   'max_phase': 116.49925,
#   'max_lat': 81.139694,
#   'max_lon': 241.50143,
#   'min_real_amplitude': 0.08965761,
#   'min_mean': 2.0275413689735684,
#   'min_sigma': 0.07264048553765563,
#   'min_amplitude': 0.09262768738648205,
#   'min_incidence': 63.911053,
#   'min_emission': 42.88623,
#   'min_phase': 116.225586,
#   'min_lat': 61.511772,
#   'min_lon': 66.781784},
#  'CM_1844016408_1_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (64, 2),
#   'max_real_amplitude': 0.25419176,
#   'max_mean': 2.029319544072024,
#   'max_sigma': 0.08563307409830577,
#   'max_amplitude': 0.2597430906478374,
#   'max_incidence': 40.238293,
#   'max_emission': 88.74741,
#   'max_phase': 117.2921,
#   'max_lat': 65.76229,
#   'max_lon': 353.5498,
#   'min_real_amplitude': 0.24556416,
#   'min_mean': 2.0285227356187554,
#   'min_sigma': 0.07978407775729121,
#   'min_amplitude': 0.24775903987334666,
#   'min_incidence': 30.209755,
#   'min_emission': 78.01762,
#   'min_phase': 117.16463,
#   'min_lat': 53.620335,
#   'min_lon': 312.3489},
#  'CM_1844028630_1_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (26, 32),
#   'max_real_amplitude': 0.27196774,
#   'max_mean': 2.0341028589008308,
#   'max_sigma': 0.11380379929339099,
#   'max_amplitude': 0.2665519192800542,
#   'max_incidence': 107.43671,
#   'max_emission': 89.71261,
#   'max_phase': 115.35455,
#   'max_lat': 88.72219,
#   'max_lon': 359.76672,
#   'min_real_amplitude': 0.0023381347,
#   'min_mean': 2.010920819226592,
#   'min_sigma': 0.06653749181133325,
#   'min_amplitude': 0.002176941162998026,
#   'min_incidence': 33.383045,
#   'min_emission': 20.01035,
#   'min_phase': 114.445465,
#   'min_lat': 27.6197,
#   'min_lon': 0.35847673},
#  'CM_1844029562_1_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (26, 32),
#   'max_real_amplitude': 0.2762154,
#   'max_mean': 2.0550306651660417,
#   'max_sigma': 0.12969284246753054,
#   'max_amplitude': 0.27124210906215296,
#   'max_incidence': 110.07101,
#   'max_emission': 86.812004,
#   'max_phase': 115.271736,
#   'max_lat': 85.88723,
#   'max_lon': 359.96152,
#   'min_real_amplitude': 0.0012512386,
#   'min_mean': 2.0112187015126897,
#   'min_sigma': 0.05726443624264005,
#   'min_amplitude': 0.0010363349244039018,
#   'min_incidence': 38.039955,
#   'min_emission': 18.32347,
#   'min_phase': 114.36743,
#   'min_lat': 17.376078,
#   'min_lon': 0.08731257},
#  'CM_1844017502_1_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (64, 2),
#   'max_real_amplitude': 0.20870782,
#   'max_mean': 2.0317824869111876,
#   'max_sigma': 0.08364181117617317,
#   'max_amplitude': 0.20735976375766121,
#   'max_incidence': 72.79938,
#   'max_emission': 60.463398,
#   'max_phase': 116.55492,
#   'max_lat': 82.76725,
#   'max_lon': 245.52536,
#   'min_real_amplitude': 0.09587666,
#   'min_mean': 2.0282364860112825,
#   'min_sigma': 0.07103286983820377,
#   'min_amplitude': 0.09890551735943684,
#   'min_incidence': 62.00992,
#   'min_emission': 44.541294,
#   'min_phase': 116.27934,
#   'min_lat': 61.525833,
#   'min_lon': 62.976685},
#  'CM_1844036384_1_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (64, 48),
#   'max_real_amplitude': 0.2649922,
#   'max_mean': 2.037969426489688,
#   'max_sigma': 0.17670792443840638,
#   'max_amplitude': 0.2601163452363708,
#   'max_incidence': 97.57859,
#   'max_emission': 88.871864,
#   'max_phase': 114.98622,
#   'max_lat': 88.9915,
#   'max_lon': 359.60422,
#   'min_real_amplitude': 0.0069243936,
#   'min_mean': 1.8990840410263354,
#   'min_sigma': 0.06277972007592345,
#   'min_amplitude': 0.006609491813521256,
#   'min_incidence': 27.595764,
#   'min_emission': 17.246622,
#   'min_phase': 114.33937,
#   'min_lat': 16.777252,
#   'min_lon': 0.5467582},
#  'CM_1844018523_6_ir.cub': {'view': '2016159T173805_2016160T065708',
#   'dimensions': (64, 2),
#   'max_real_amplitude': 0.062025156,
#   'max_mean': 2.08,
#   'max_sigma': 0.125,
#   'max_amplitude': 0.1,
#   'max_incidence': 93.32877,
#   'max_emission': 41.71713,
#   'max_phase': 115.796394,
#   'max_lat': 61.945007,
#   'max_lon': 206.88893,
#   'min_real_amplitude': -3.4028227e+38,
#   'min_mean': 2.0267171793001286,
#   'min_sigma': 0.08984744071146739,
#   'min_amplitude': 0.020023521873966273,
#   'min_incidence': 84.34814,
#   'min_emission': 23.156755,
#   'min_phase': 115.53665,
#   'min_lat': 51.824654,
#   'min_lon': 100.326416},
#  'CM_1844015704_1_ir.cub': {'view': '2016159T102606_2016159T173652',
#   'dimensions': (64, 2),
#   'max_real_amplitude': 0.1149759,
#   'max_mean': 2.0311057606780403,
#   'max_sigma': 0.08697844373261093,
#   'max_amplitude': 0.11523041451629383,
#   'max_incidence': 83.53065,
#   'max_emission': 45.536285,
#   'max_phase': 116.70155,
#   'max_lat': 71.82024,
#   'max_lon': 213.75546,
#   'min_real_amplitude': 0.056027688,
#   'min_mean': 2.027250233659755,
#   'min_sigma': 0.07794697623951101,
#   'min_amplitude': 0.05713443761208535,
#   'min_incidence': 76.0254,
#   'min_emission': 34.054367,
#   'min_phase': 116.412125,
#   'min_lat': 62.04353,
#   'min_lon': 94.45445},
#  'CM_1844013444_1_ir.cub': {'view': '2016159T102606_2016159T173652',
#   'dimensions': (64, 2),
#   'max_real_amplitude': 0.289794,
#   'max_mean': 2.0292156852771326,
#   'max_sigma': 0.08498338164105788,
#   'max_amplitude': 0.29476696944696973,
#   'max_incidence': 39.197575,
#   'max_emission': 89.54645,
#   'max_phase': 118.47527,
#   'max_lat': 64.641426,
#   'max_lon': 350.70355,
#   'min_real_amplitude': 0.27680615,
#   'min_mean': 2.0285452741389802,
#   'min_sigma': 0.08073968429635724,
#   'min_amplitude': 0.2813979084195253,
#   'min_incidence': 30.51497,
#   'min_emission': 80.40022,
#   'min_phase': 118.33676,
#   'min_lat': 55.242653,
#   'min_lon': 317.37274},
#  'CM_1843991547_1_ir.cub': {'view': '2016159T102606_2016159T173652',
#   'dimensions': (64, 2),
#   'max_real_amplitude': 0.130136,
#   'max_mean': 2.026749780719064,
#   'max_sigma': 0.0719615090752575,
#   'max_amplitude': 0.1210154514628304,
#   'max_incidence': 36.817574,
#   'max_emission': 87.340454,
#   'max_phase': 65.333115,
#   'max_lat': 45.037285,
#   'max_lon': 359.75443,
#   'min_real_amplitude': 0.093230605,
#   'min_mean': 2.0241062306238353,
#   'min_sigma': 0.05615625360270455,
#   'min_amplitude': 0.08656519843164555,
#   'min_incidence': 4.119787,
#   'min_emission': 67.23765,
#   'min_phase': 64.98652,
#   'min_lat': 28.840122,
#   'min_lon': 0.18002085},
#  'CM_1844015923_1_ir.cub': {'view': '2016159T102606_2016159T173652',
#   'dimensions': (64, 2),
#   'max_real_amplitude': 0.089121476,
#   'max_mean': 2.030792341128046,
#   'max_sigma': 0.09118184247605407,
#   'max_amplitude': 0.09086576748182451,
#   'max_incidence': 86.98492,
#   'max_emission': 42.49266,
#   'max_phase': 116.527725,
#   'max_lat': 68.34778,
#   'max_lon': 208.02231,
#   'min_real_amplitude': 0.041370977,
#   'min_mean': 2.0278027013571918,
#   'min_sigma': 0.08308691489381499,
#   'min_amplitude': 0.041876400404563675,
#   'min_incidence': 79.596664,
#   'min_emission': 30.441439,
#   'min_phase': 116.24258,
#   'min_lat': 59.612255,
#   'min_lon': 99.6892},
#  'CM_1844014319_1_ir.cub': {'view': '2016159T102606_2016159T173652',
#   'dimensions': (64, 2),
#   'max_real_amplitude': 0.3589155,
#   'max_mean': 2.029572307916587,
#   'max_sigma': 0.08006286157744781,
#   'max_amplitude': 0.34440461467992695,
#   'max_incidence': 60.57868,
#   'max_emission': 70.08445,
#   'max_phase': 117.8313,
#   'max_lat': 86.138466,
#   'max_lon': 356.21466,
#   'min_real_amplitude': 0.17436859,
#   'min_mean': 2.0271310752009275,
#   'min_sigma': 0.057577866125856365,
#   'min_amplitude': 0.1742105136011973,
#   'min_incidence': 50.255825,
#   'min_emission': 58.145424,
#   'min_phase': 117.52627,
#   'min_lat': 64.74652,
#   'min_lon': 2.0607867},
#  'CM_1843991617_1_ir.cub': {'view': '2016159T102606_2016159T173652',
#   'dimensions': (64, 2),
#   'max_real_amplitude': 0.12907742,
#   'max_mean': 2.026852186412699,
#   'max_sigma': 0.07204910308008321,
#   'max_amplitude': 0.12019877547766689,
#   'max_incidence': 36.99684,
#   'max_emission': 87.92047,
#   'max_phase': 65.37051,
#   'max_lat': 45.601357,
#   'max_lon': 359.692,
#   'min_real_amplitude': 0.09701673,
#   'min_mean': 2.0244009440199067,
#   'min_sigma': 0.058614199220572365,
#   'min_amplitude': 0.09000507086155461,
#   'min_incidence': 6.1126885,
# ...
#   'min_mean': 2.016096155882633,
#   'min_sigma': 0.06615459063625331,
#   'min_amplitude': 0.006599973056966769,
#   'min_incidence': 35.007572,
#   'min_emission': 21.896542,
#   'min_phase': 120.62612,
#   'min_lat': 39.98251,
#   'min_lon': 0.14860426},
#  'CM_1841286444_1_ir.cub': {'view': '2016127T223449_2016130T200342',
#   'dimensions': (46, 32),
#   'max_real_amplitude': 0.3049625,
#   'max_mean': 58.808091668768704,
#   'max_sigma': 18.328056856433932,
#   'max_amplitude': 9.87482048841251e+33,
#   'max_incidence': 125.812416,
#   'max_emission': 85.63078,
#   'max_phase': 120.79319,
#   'max_lat': 89.14717,
#   'max_lon': 355.33664,
#   'min_real_amplitude': 0.00031496756,
#   'min_mean': -27.230289265454495,
#   'min_sigma': -2.3697556849744545,
#   'min_amplitude': -0.008155196030472189,
#   'min_incidence': 36.919693,
#   'min_emission': 1.4190454,
#   'min_phase': 120.01879,
#   'min_lat': 10.400822,
#   'min_lon': 1.7939452},
#  'CM_1841284507_1_ir.cub': {'view': '2016127T223449_2016130T200342',
#   'dimensions': (46, 30),
#   'max_real_amplitude': 0.30802837,
#   'max_mean': 8.939045795068674,
#   'max_sigma': 2.7492030256781668,
#   'max_amplitude': 4.2834818667274036e+88,
#   'max_incidence': 122.12371,
#   'max_emission': 88.46115,
#   'max_phase': 120.86703,
#   'max_lat': 88.28536,
#   'max_lon': 358.7472,
#   'min_real_amplitude': 0.00031525968,
#   'min_mean': -38.57739010477851,
#   'min_sigma': -1.9061916257519946,
#   'min_amplitude': -0.004081542943272923,
#   'min_incidence': 35.64103,
#   'min_emission': 0.67863303,
#   'min_phase': 120.09737,
#   'min_lat': 16.587425,
#   'min_lon': 0.4655823},
#  'CM_1841269234_1_ir.cub': {'view': '2016127T223449_2016130T200342',
#   'dimensions': (64, 64),
#   'max_real_amplitude': 0.31646627,
#   'max_mean': 69.50669494412752,
#   'max_sigma': 35.49938652802979,
#   'max_amplitude': 3.994605891538725e+60,
#   'max_incidence': 130.45914,
#   'max_emission': 88.7683,
#   'max_phase': 121.933266,
#   'max_lat': 88.969635,
#   'max_lon': 359.8172,
#   'min_real_amplitude': 0.00021242553,
#   'min_mean': -44.53787938862904,
#   'min_sigma': -5.508767536196571,
#   'min_amplitude': -0.008202765197691352,
#   'min_incidence': 36.47601,
#   'min_emission': 0.5992107,
#   'min_phase': 120.348946,
#   'min_lat': 9.967679,
#   'min_lon': 1.4441544},
#  'CM_1841276017_1_ir.cub': {'view': '2016127T223449_2016130T200342',
#   'dimensions': (64, 44),
#   'max_real_amplitude': 0.31583333,
#   'max_mean': 17.94002992971368,
#   'max_sigma': 3.5802375469920737,
#   'max_amplitude': 1.85018934165192e+46,
#   'max_incidence': 119.71958,
#   'max_emission': 88.74492,
#   'max_phase': 121.28776,
#   'max_lat': 88.41738,
#   'max_lon': 359.60217,
#   'min_real_amplitude': 0.00033522508,
#   'min_mean': -21.25357822001866,
#   'min_sigma': -0.03350932194896514,
#   'min_amplitude': -0.00048547865399275407,
#   'min_incidence': 35.012604,
#   'min_emission': 0.75563866,
#   'min_phase': 120.31069,
#   'min_lat': 11.498045,
#   'min_lon': 2.603449},
#  'CM_1841279980_1_ir.cub': {'view': '2016127T223449_2016130T200342',
#   'dimensions': (60, 40),
#   'max_real_amplitude': 0.3645476,
#   'max_mean': 35.889593858877966,
#   'max_sigma': 10.442486174324301,
#   'max_amplitude': 1.0485159596080307e+61,
#   'max_incidence': 127.097015,
#   'max_emission': 89.077644,
#   'max_phase': 121.059135,
#   'max_lat': 88.32094,
#   'max_lon': 358.1424,
#   'min_real_amplitude': 0.00028920162,
#   'min_mean': -38.69346034646827,
#   'min_sigma': -6.994744343755958,
#   'min_amplitude': -0.06931838417524046,
#   'min_incidence': 36.128384,
#   'min_emission': 0.85839427,
#   'min_phase': 120.11267,
#   'min_lat': -1.3037078,
#   'min_lon': 1.7200471},
#  'CM_1841283690_1_ir.cub': {'view': '2016127T223449_2016130T200342',
#   'dimensions': (46, 32),
#   'max_real_amplitude': 0.31009847,
#   'max_mean': 29.315855920456745,
#   'max_sigma': 18.403465129117414,
#   'max_amplitude': 7.309763988678453e+49,
#   'max_incidence': 126.83097,
#   'max_emission': 88.70716,
#   'max_phase': 120.90661,
#   'max_lat': 88.28219,
#   'max_lon': 358.89517,
#   'min_real_amplitude': 0.00027806812,
#   'min_mean': -40.02988500870838,
#   'min_sigma': -2.893248581066871,
#   'min_amplitude': -1.590514484304541e+16,
#   'min_incidence': 37.027596,
#   'min_emission': 0.44802833,
#   'min_phase': 120.051445,
#   'min_lat': 11.332896,
#   'min_lon': 1.6608523},
#  'CM_1841283964_1_ir.cub': {'view': '2016127T223449_2016130T200342',
#   'dimensions': (46, 32),
#   'max_real_amplitude': 0.30905688,
#   'max_mean': 11.989889370800343,
#   'max_sigma': 4.171765889471488,
#   'max_amplitude': 2.730810282964956e+47,
#   'max_incidence': 126.50282,
#   'max_emission': 88.70787,
#   'max_phase': 120.87667,
#   'max_lat': 89.11848,
#   'max_lon': 357.19098,
#   'min_real_amplitude': 0.00030659136,
#   'min_mean': -38.619906286074524,
#   'min_sigma': -1.786221053700059,
#   'min_amplitude': -0.013445696328238818,
#   'min_incidence': 37.9439,
#   'min_emission': 0.46906632,
#   'min_phase': 120.047295,
#   'min_lat': 8.537897,
#   'min_lon': 1.868183},
#  'CM_1841278414_1_ir.cub': {'view': '2016127T223449_2016130T200342',
#   'dimensions': (42, 52),
#   'max_real_amplitude': 0.36283103,
#   'max_mean': 2.031982459724691,
#   'max_sigma': 0.11311927716704707,
#   'max_amplitude': 0.3552211762650953,
#   'max_incidence': 98.07579,
#   'max_emission': 89.515686,
#   'max_phase': 121.151596,
#   'max_lat': 89.31097,
#   'max_lon': 359.765,
#   'min_real_amplitude': 0.008003646,
#   'min_mean': 2.0218106676947225,
#   'min_sigma': 0.06298658564416916,
#   'min_amplitude': 0.007708416182942452,
#   'min_incidence': 35.865753,
#   'min_emission': 22.623178,
#   'min_phase': 120.58221,
#   'min_lat': 38.036106,
#   'min_lon': 0.79663634},
#  'CM_1841281273_1_ir.cub': {'view': '2016127T223449_2016130T200342',
#   'dimensions': (46, 32),
#   'max_real_amplitude': 0.33641347,
#   'max_mean': 70.00298685139818,
#   'max_sigma': 4.553417019864807,
#   'max_amplitude': 1.0066309840286824e+64,
#   'max_incidence': 123.42356,
#   'max_emission': 88.825485,
#   'max_phase': 121.0022,
#   'max_lat': 89.052086,
#   'max_lon': 356.93936,
#   'min_real_amplitude': 0.00010800253,
#   'min_mean': -29.61671548312035,
#   'min_sigma': -4.3613149944021705,
#   'min_amplitude': -2.695344927623883e+56,
#   'min_incidence': 36.20248,
#   'min_emission': 1.1071968,
#   'min_phase': 120.145,
#   'min_lat': 16.32501,
#   'min_lon': 0.06696883},
#  'CM_1841275013_1_ir.cub': {'view': '2016127T223449_2016130T200342',
#   'dimensions': (64, 44),
#   'max_real_amplitude': 0.31430992,
#   'max_mean': 67.95157098970166,
#   'max_sigma': 26.059861519682347,
#   'max_amplitude': 2.108003166994257e+62,
#   'max_incidence': 119.83136,
#   'max_emission': 87.324,
#   'max_phase': 121.397,
#   'max_lat': 89.252396,
#   'max_lon': 358.33624,
#   'min_real_amplitude': 0.00034436042,
#   'min_mean': -32.93852363765273,
#   'min_sigma': -0.03237050440416179,
#   'min_amplitude': -0.007001796424972568,
#   'min_incidence': 35.23479,
#   'min_emission': 0.8218028,
#   'min_phase': 120.38219,
#   'min_lat': 12.793681,
#   'min_lon': 0.09892426},
#  'CM_1841272098_1_ir.cub': {'view': '2016127T223449_2016130T200342',
#   'dimensions': (50, 54),
#   'max_real_amplitude': 0.3260199,
#   'max_mean': 2.0325732367717992,
#   'max_sigma': 0.1259659625672442,
#   'max_amplitude': 0.33859217031311106,
#   'max_incidence': 97.59646,
#   'max_emission': 87.915115,
#   'max_phase': 121.68672,
#   'max_lat': 89.54049,
#   'max_lon': 359.82764,
#   'min_real_amplitude': 0.011904164,
#   'min_mean': 2.0196741617723006,
#   'min_sigma': 0.07087519837484306,
#   'min_amplitude': 0.011704238957810689,
#   'min_incidence': 36.157013,
#   'min_emission': 23.462992,
#   'min_phase': 120.99065,
#   'min_lat': 41.4217,
#   'min_lon': 0.90834504},
#  'CM_1841268447_1_ir.cub': {'view': '2016127T223449_2016130T200342',
#   'dimensions': (52, 42),
#   'max_real_amplitude': 0.31649205,
#   'max_mean': 74.27070690062257,
#   'max_sigma': 10.706731966744318,
#   'max_amplitude': 21178239.272586986,
#   'max_incidence': 108.58058,
#   'max_emission': 89.13991,
#   'max_phase': 122.14845,
#   'max_lat': 89.42033,
#   'max_lon': 359.90942,
#   'min_real_amplitude': 0.0016875031,
#   'min_mean': 1.7092956611011425,
#   'min_sigma': 0.0707974200606531,
#   'min_amplitude': 0.0013000094223689503,
#   'min_incidence': 34.96626,
#   'min_emission': 12.514038,
#   'min_phase': 121.05179,
#   'min_lat': 35.654182,
#   'min_lon': 0.71793836},
#  'CM_1841281547_1_ir.cub': {'view': '2016127T223449_2016130T200342',
#   'dimensions': (46, 32),
#   'max_real_amplitude': 0.37406763,
#   'max_mean': 44.57198217898985,
#   'max_sigma': 17.502329740143605,
#   'max_amplitude': 1.7659309565772003e+49,
#   'max_incidence': 123.39848,
#   'max_emission': 89.74572,
#   'max_phase': 120.99549,
#   'max_lat': 88.63443,
#   'max_lon': 359.8052,
#   'min_real_amplitude': 0.00032065713,
#   'min_mean': -41.52396863370156,
#   'min_sigma': -3.035539462058716,
#   'min_amplitude': -0.01103399740482505,
#   'min_incidence': 32.634655,
#   'min_emission': 0.92859846,
#   'min_phase': 120.14005,
#   'min_lat': 16.058416,
#   'min_lon': 0.41456932},
#  'CM_1841282090_1_ir.cub': {'view': '2016127T223449_2016130T200342',
#   'dimensions': (46, 30),
#   'max_real_amplitude': 0.33821577,
#   'max_mean': 2.278530469339821,
#   'max_sigma': 8.664227829073804,
#   'max_amplitude': 1.265945772879407e+27,
#   'max_incidence': 119.15733,
#   'max_emission': 88.67517,
#   'max_phase': 120.95707,
#   'max_lat': 88.83963,
#   'max_lon': 357.52017,
#   'min_real_amplitude': 0.00030254538,
#   'min_mean': -39.94668602264686,
#   'min_sigma': -0.03762086812094678,
#   'min_amplitude': -0.0053080360808609485,
#   'min_incidence': 35.38222,
#   'min_emission': 1.1011542,
#   'min_phase': 120.18652,
#   'min_lat': 18.841976,
#   'min_lon': 1.4414384},
#  'CM_1838463713_1_ir.cub': {'view': '2016095T024544_2016095T123005',
#   'dimensions': (24, 16),
#   'max_real_amplitude': 0.026895117,
#   'max_mean': 2.207800563047822,
#   'max_sigma': 2.0009519074176523,
#   'max_amplitude': 5.767194338047854e+27,
#   'max_incidence': 131.07027,
#   'max_emission': 87.24108,
#   'max_phase': 44.574364,
#   'max_lat': -57.213398,
#   'max_lon': 359.34982,
#   'min_real_amplitude': 0.0005557728,
#   'min_mean': -21.52321162051473,
#   'min_sigma': 0.03843052565627127,
#   'min_amplitude': 0.0003285710672548551,
#   'min_incidence': 89.32142,
#   'min_emission': 44.76515,
#   'min_phase': 44.29835,
#   'min_lat': -88.38756,
#   'min_lon': 0.29901707},
#  'CM_1838464553_1_ir.cub': {'view': '2016095T024544_2016095T123005',
#   'dimensions': (44, 12),
#   'max_real_amplitude': 0.014398965,
#   'max_mean': 2.1628476021133243,
#   'max_sigma': 6.065862135841067,
#   'max_amplitude': 8.168610320425772e+21,
#   'max_incidence': 131.97255,
#   'max_emission': 89.4929,
#   'max_phase': 44.477417,
#   'max_lat': -41.690067,
#   'max_lon': 359.88065,
#   'min_real_amplitude': 0.0005006517,
#   'min_mean': -30.946388407440026,
#   'min_sigma': -0.021717370665805372,
#   'min_amplitude': 0.00020149288417805957,
#   'min_incidence': 100.92051,
#   'min_emission': 56.505672,
#   'min_phase': 44.324142,
#   'min_lat': -88.39946,
#   'min_lon': 0.0076043205},
#  'CM_1838462876_1_ir.cub': {'view': '2016095T024544_2016095T123005',
#   'dimensions': (24, 16),
#   'max_real_amplitude': 0.026902016,
#   'max_mean': 2.050209374218044,
#   'max_sigma': 0.14618517169338885,
#   'max_amplitude': 0.02686292777850126,
#   'max_incidence': 129.813,
#   'max_emission': 88.84837,
#   'max_phase': 44.554886,
#   'max_lat': -56.6034,
#   'max_lon': 359.19424,
#   'min_real_amplitude': 0.0005263291,
#   'min_mean': 1.9786733219950337,
#   'min_sigma': 0.019013226184597207,
#   'min_amplitude': 0.0003198453227041615,
#   'min_incidence': 88.67519,
#   'min_emission': 44.137955,
#   'min_phase': 44.28117,
#   'min_lat': -88.88773,
#   'min_lon': 0.42739078},
#  'CM_1838466218_1_ir.cub': {'view': '2016095T024544_2016095T123005',
#   'dimensions': (64, 12),
#   'max_real_amplitude': 0.11792784,
#   'max_mean': 2.0279892264327755,
#   'max_sigma': 0.15175552032074277,
#   'max_amplitude': 0.09699033451294493,
#   'max_incidence': 108.90686,
#   'max_emission': 89.84556,
#   'max_phase': 45.158703,
#   'max_lat': 2.0284252,
#   'max_lon': 359.9808,
#   'min_real_amplitude': 0.01650689,
#   'min_mean': 1.8491340295543457,
#   'min_sigma': 0.04766797584365747,
#   'min_amplitude': 0.01649793863512728,
#   'min_incidence': 56.265594,
#   'min_emission': 11.126822,
#   'min_phase': 44.82165,
#   'min_lat': -54.38059,
#   'min_lon': 0.20038171},
#  'CM_1838459038_1_ir.cub': {'view': '2016095T024544_2016095T123005',
#   'dimensions': (64, 42),
#   'max_real_amplitude': 0.14571035,
#   'max_mean': 2.0312041086898267,
#   'max_sigma': 0.11415317566468919,
#   'max_amplitude': 0.14092935277058977,
#   'max_incidence': 107.69197,
#   'max_emission': 87.747314,
#   'max_phase': 45.744102,
#   'max_lat': 67.392265,
#   'max_lon': 359.98883,
#   'min_real_amplitude': 0.013267593,
#   'min_mean': 2.0165191838889203,
#   'min_sigma': 0.04423326824521818,
#   'min_amplitude': 0.013134923598378577,
#   'min_incidence': 1.183356,
#   'min_emission': 0.4323231,
#   'min_phase': 44.49821,
#   'min_lat': -34.73847,
#   'min_lon': 0.17628027},
#  'CM_1838467058_1_ir.cub': {'view': '2016095T024544_2016095T123005',
#   'dimensions': (64, 12),
#   'max_real_amplitude': 0.096395545,
#   'max_mean': 2.030810931671935,
#   'max_sigma': 0.1044928615095215,
#   'max_amplitude': 0.09585953533944228,
#   'max_incidence': 85.010925,
#   'max_emission': 72.517555,
#   'max_phase': 45.5274,
#   'max_lat': 15.711429,
#   'max_lon': 359.99533,
#   'min_real_amplitude': 0.040072504,
#   'min_mean': 2.0184321141452055,
#   'min_sigma': 0.043940351334761055,
#   'min_amplitude': 0.036866224899019806,
#   'min_incidence': 37.979973,
#   'min_emission': 0.62327033,
#   'min_phase': 45.18924,
#   'min_lat': -34.31529,
#   'min_lon': 0.028103936},
#  'CM_1838467891_1_ir.cub': {'view': '2016095T024544_2016095T123005',
#   'dimensions': (64, 12),
#   'max_real_amplitude': 0.13420616,
#   'max_mean': 2.02702661431352,
#   'max_sigma': 0.0873878813099596,
#   'max_amplitude': 0.11277156068172939,
#   'max_incidence': 67.42659,
#   'max_emission': 82.964134,
#   'max_phase': 45.89976,
#   'max_lat': 35.343475,
#   'max_lon': 359.9116,
#   'min_real_amplitude': 0.043339364,
#   'min_mean': 2.021216998362009,
#   'min_sigma': 0.04372154419772163,
#   'min_amplitude': 0.039709307499715775,
#   'min_incidence': 20.294764,
#   'min_emission': 7.456867,
#   'min_phase': 45.56084,
#   'min_lat': -16.7098,
#   'min_lon': 0.18924236},
#  'CM_1838459520_1_ir.cub': {'view': '2016095T024544_2016095T123005',
#   'dimensions': (64, 42),
#   'max_real_amplitude': 0.14543703,
#   'max_mean': 2.0344491007269374,
#   'max_sigma': 0.11149685767265193,
#   'max_amplitude': 0.14057340406986582,
#   'max_incidence': 110.935776,
#   'max_emission': 88.70411,
#   'max_phase': 45.853386,
#   'max_lat': 65.82459,
#   'max_lon': 359.9511,
#   'min_real_amplitude': 0.014011505,
#   'min_mean': 2.0211533839442906,
#   'min_sigma': 0.04428970527215985,
#   'min_amplitude': 0.014258139017235069,
#   'min_incidence': 1.5833067,
#   'min_emission': 1.098696,
#   'min_phase': 44.528233,
#   'min_lat': -32.909855,
#   'min_lon': 0.05866243},
#  'CM_1838465386_1_ir.cub': {'view': '2016095T024544_2016095T123005',
#   'dimensions': (64, 12),
#   'max_real_amplitude': 0.08760827,
#   'max_mean': 2.045499847218675,
#   'max_sigma': 0.12414476721624375,
#   'max_amplitude': 0.04518967458569957,
#   'max_incidence': 120.04278,
#   'max_emission': 88.21879,
#   'max_phase': 44.848053,
#   'max_lat': -12.859677,
#   'max_lon': 359.77524,
#   'min_real_amplitude': 0.0034488747,
#   'min_mean': 2.0177178672584706,
#   'min_sigma': 0.0668286022110643,
#   'min_amplitude': 0.003040027905650748,
#   'min_incidence': 73.10207,
#   'min_emission': 28.270342,
#   'min_phase': 44.51434,
#   'min_lat': -76.853004,
#   'min_lon': 0.026225498},
#  'CM_1838455660_1_ir.cub': {'view': '2016095T024544_2016095T123005',
#   'dimensions': (64, 42),
#   'max_real_amplitude': 0.14628188,
#   'max_mean': 2.0358008168489325,
#   'max_sigma': 0.11070491027889688,
#   'max_amplitude': 0.14188368739436086,
#   'max_incidence': 111.73417,
#   'max_emission': 88.50781,
#   'max_phase': 45.59279,
#   'max_lat': 64.3663,
#   'max_lon': 359.9361,
#   'min_real_amplitude': 0.009958572,
#   'min_mean': 2.0224773292679283,
#   'min_sigma': 0.04436703108946686,
#   'min_amplitude': 0.009804555383419365,
#   'min_incidence': 0.8800475,
#   'min_emission': 1.2654234,
#   'min_phase': 44.35857,
#   'min_lat': -39.03675,
#   'min_lon': 0.002460007}}

# %%
class Window(Frame):
    def __init__(self, master = None):
        Frame.__init__(self, master)
        self.master = master
        self.init_window()
    def printtext(e):
        def p():
            print(e.get())
        return p
    def init_window(self):
        self.master.title('GUI')
        
        self.pack(fill=BOTH,expand=1)
        
        #quitButton = Button(self,text='QUIT',command=self.client_exit)
        
        #quitButton.place(x=0,y=0)
        
        menu = Menu(self.master)
        self.master.config(menu=menu)
        
        file = Menu(menu)
        file.add_command(label='Save')
        file.add_command(label='Exit',command=self.client_exit)
        menu.add_cascade(label='File',menu=file)
        
        edit=Menu(menu)
        edit.add_command(label='Show Image',command = self.showImg)
        edit.add_command(label='Show Text',command=self.showText)
        menu.add_cascade(label='Edit',menu=edit)
        
        e=Entry(self)
        e.pack()
        e.focus_set()
        b=Button(self,text='ok')
        b.pack(side='bottom')
        
    
    def showImg(self):
        load=Image.open('2005_3d.png')
        render = ImageTk.PhotoImage(load)
        
        img=Label(self,image=render)
        img.image=render
        img.place(x=0,y=0)
        
    def showText(self):
        text=Label(self,text='Hello World')
        text.pack()
        
    def client_exit(self):
        self.master.destroy()
        
root = Tk()
root.geometry('400x300')
app = Window(root)

root.mainloop()

# %%
import tkinter
class App():
    def __init__(self):
        self.root = tkinter.Tk()
        button = tkinter.Button(self.root, text = 'root quit', command=self.quit)
        button.pack()
        self.root.mainloop()

    def quit(self):
        self.root.destroy()

app = App()
