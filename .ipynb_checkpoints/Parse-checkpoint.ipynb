# %%
from IPython.core.display import HTML
import numpy as np
import matplotlib
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from pylab import *
import pysis
import os
import scipy.optimize as sco
import time
import ast
from tkinter import *
from PIL import Image, ImageTk
# %matplotlib qt

file = open('cube_data.txt','a')
file.write('test')
file.close()

# %%
def gaussian(x,mean,sigma,A):
    
    return A*np.exp( -((x-mean)**2.) / (2.*sigma**2.) )

def powerlaw(x,a, k, c):
    
    return a*x**k + c

vims_wave = np.loadtxt('/home/alanyu/Dropbox (MIT)/VIMS_UROP/vims_wave.txt')

# %%
def write_cubes(master_directory,file_name):
    viewing_geometries = os.listdir(master_directory)
    file = open(file_name,'w')
    for folder in viewing_geometries:
        print(f'Working on folder {folder}')
        for cube in os.listdir(folder):
            if cube[0:2] != 'CM' or 'nav' in cube or 'BKGD' in cube:
                continue
            file.write(f'{master_directory}/{folder}/{cube}\n')
    return file_name

# %%
def analyze_cube(cube,nav,l,w):
    """
    Given cube data (cube) and navigation information (nav) with dimensions x and y, returns:
    
    1) max/min 2 micron amplitude
    2) max/min sigma
    3) max/min mean 
    4) max/min incidence
    5) max/min emission
    6) max/min phase
    7) max/min lat
    8) max/min lon
    """
    
    count=0
    band_channels = [29,30,31,32,47,48,49,50,51,52,53,54,55,84,85,86,87,88,89,90] + [i for i in range(160,181)] 
    
    info = np.full((37,l,w),None)
    #0: key (0 = good, 1 = off disk, 2 = low resolution, 3 = bad powerlaw, 4 = dark, 5 = bad incidence/emission), 6 = completely failed 
    #1-6: best fit (1-3: gaussian mean,sigma,amp; 4-6: plaw amp,exp,const)
    #7-21: raw data channel 60:85
    #22-26: phase,emission,incidence, lat, lon
    

    info[7:32]=cube[60:85]
    info[32:35] = nav[1:4]
    info[35:37] = nav[6:8]

    for i in range(l):
        for j in range(w):
            
            if nav[6,i,j] < -90:  
                count+=1
                info[0,i,j] = 1
                continue
            elif nav[8,i,j]>100000:
                info[0,i,j] = 2
            elif cube[69,i,j]<=0.02:
                info[0,i,j] = 4
            elif nav[2,i,j]<70 or nav[3,i,j]>90:
                info[0,i,j] = 5
            
            
            

            try:
                #Fit power law
                p_fit, p_cov = sco.curve_fit(powerlaw, vims_wave[band_channels], cube[band_channels, i,j], p0 = (.005,-2,0), maxfev = 10000)
                p = powerlaw(vims_wave, *p_fit)

                #Subtract power law
                new_data = cube[:,i,j] - p

                #Fit gaussian
                fit,cov = sco.curve_fit(gaussian, vims_wave[64:85],new_data[64:85], \
                                    p0=(2.08,.125,.1), maxfev=100000)

                info[1,i,j] = fit[0]
                info[2,i,j] = fit[1]
                info[3,i,j] = fit[2]
                info[4,i,j] = p_fit[0]
                info[5,i,j] = p_fit[1]
                info[6,i,j] = p_fit[2]
                info[0,i,j] = 0


            except:
                #If powerlaw fit fails, directly fit gaussian
                info[0,i,j] = 3
                try:
                    fit,cov = sco.curve_fit(gaussian, vims_wave[64:85],cube[64:85,i,j], p0=(2.08,.125,.1), maxfev=1000000)
                    info[1,i,j] = fit[0]
                    info[2,i,j] = fit[1]
                    info[3,i,j] = fit[2]
                except:
                    info[0,i,j]=6
                    break


    return info

# %%
def create_cube_parser(cube_list,destination='cube_info'):
    '''
    Parameters:
    
    master_directory (str): Path to folder with all viewing geometries.
    
    Creates text file with information about each cube (assuming max resolution < 100km): 
    
    1) folder 
    2) name 
    3) max/min 2 micron amplitude
    4) max/min sigma
    5) max/min mean
    6) dimensions
    7) max/min incidence
    8) max/min emission
    9) max/min phase
    10) max/min lat
    11) max/min lon
    
    '''
    count = 0

    skipped=set()
    file = open(cube_list,'r')
    
    while True:
        
        
        cube_path = file.readline().strip()
        
        if not cube_path:
            break
            
        nav = pysis.CubeFile(f'{cube_path[:-4]}_nav.cub').data


        print(f'Working on: {cube_path}')
            
            
        folder = cube_path.split('/')[-2]
        name = cube_path.split('/')[-1]
        
        data = pysis.CubeFile(cube_path).data

        lbl = pysis.CubeFile(cube_path).label
        length=lbl['IsisCube']['Instrument']['SwathLength']
        width=lbl['IsisCube']['Instrument']['SwathWidth']
        t0=time.time()
        info = analyze_cube(data,nav,length,width)
        t1 = time.time()
        print(t1-t0)
        np.save(os.path.join(destination, f'{folder}-{name}-{length}x{width}.npy'),info)
        print(time.time()-t1)
          
    file.close()  

    return skipped

# %%
def create_database(master_directory,destination='cube_info',file_name='cube_list.txt'):
    create_cube_parser(write_cubes(master_directory,file_name),destination)

# %%
#on test folder (one viewing geometry, 11 cubes): 35.3 s ± 1.95 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

create_database('/home/alanyu/Dropbox (MIT)/VIMS_UROP/data')
# Out:
# Working on folder 2009189T194600_2009189T235739
# Working on folder 2016127T223449_2016130T200342
# Working on folder 2005359T100445_2005360T101919
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625786407_1_ir.cub
# copy: 0.0006384849548339844
# 1.0144944190979004
# 0.012772083282470703
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625776676_1_ir.cub
# copy: 0.00020933151245117188
# 0.45747828483581543
# 0.006234645843505859
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625777485_1_ir.cub
# copy: 0.00014019012451171875
# 0.7490215301513672
# 0.005589485168457031
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625777418_1_ir.cub
# copy: 0.00012969970703125
# 0.4903872013092041
# 0.006131649017333984
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625777687_1_ir.cub
# copy: 0.00011563301086425781
# 0.41817188262939453
# 0.005526304244995117
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625780003_1_ir.cub
# copy: 0.0003428459167480469
# 1.3031561374664307
# 0.014960765838623047
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625777215_1_ir.cub
# copy: 0.00011420249938964844
# 0.4149000644683838
# 0.0065593719482421875
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625777620_1_ir.cub
# copy: 0.00012803077697753906
# 0.4507787227630615
# 0.0060083866119384766
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625778429_1_ir.cub
# copy: 0.00013780593872070312
# 0.2984335422515869
# 0.0045833587646484375
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625778564_12_ir.cub
# copy: 0.00011682510375976562
# 0.0720372200012207
# 0.0033555030822753906
# /home/alanyu/anaconda3/lib/python3.8/site-packages/scipy/optimize/minpack.py:828: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625788353_1_ir.cub
# copy: 0.0003426074981689453
# 1.217515230178833
# 0.014786243438720703
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625776406_1_ir.cub
# copy: 0.0003592967987060547
# 0.5881133079528809
# 0.012123823165893555
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625785908_1_ir.cub
# copy: 0.0008649826049804688
# 1.168046236038208
# 0.014383077621459961
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625783874_1_ir.cub
# copy: 0.0004706382751464844
# 1.1819438934326172
# 0.014066457748413086
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625778092_1_ir.cub
# copy: 0.0001380443572998047
# 0.33777856826782227
# 0.005608797073364258
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625778227_1_ir.cub
# copy: 0.00016379356384277344
# 0.31374478340148926
# 0.0045986175537109375
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625776946_1_ir.cub
# copy: 0.0001285076141357422
# 0.4383842945098877
# 0.006290435791015625
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625777553_1_ir.cub
# copy: 0.00012350082397460938
# 0.40892529487609863
# 0.006075382232666016
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625785412_1_ir.cub
# copy: 0.00032210350036621094
# 1.154637336730957
# 0.01423335075378418
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625777081_1_ir.cub
# copy: 0.00012254714965820312
# 0.4106166362762451
# 0.006518125534057617
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625782922_1_ir.cub
# copy: 0.0006983280181884766
# 1.2015626430511475
# 0.016789913177490234
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625776541_1_ir.cub
# copy: 0.0001468658447265625
# 0.4299299716949463
# 0.006010293960571289
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625776811_1_ir.cub
# copy: 0.00012159347534179688
# 0.4368317127227783
# 0.005941867828369141
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625776069_1_ir.cub
# copy: 0.00014543533325195312
# 0.45763444900512695
# 0.01435089111328125
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625780494_1_ir.cub
# copy: 0.00032401084899902344
# 1.1815478801727295
# 0.013653993606567383
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625784937_1_ir.cub
# copy: 0.0005192756652832031
# 1.337522029876709
# 0.02257823944091797
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625777957_1_ir.cub
# copy: 0.0001323223114013672
# 0.3532590866088867
# 0.005265951156616211
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625778362_1_ir.cub
# copy: 0.00014090538024902344
# 0.24794912338256836
# 0.0042645931243896484
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625782424_1_ir.cub
# copy: 0.00032448768615722656
# 1.1358776092529297
# 0.014487981796264648
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625790319_1_ir.cub
# copy: 0.0003123283386230469
# 1.01194167137146
# 0.014871835708618164
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625778025_1_ir.cub
# copy: 0.00013399124145507812
# 0.3254740238189697
# 0.0055348873138427734
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625777822_1_ir.cub
# copy: 0.0001430511474609375
# 0.40872621536254883
# 0.006293058395385742
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625777283_1_ir.cub
# copy: 0.00014257431030273438
# 0.5385749340057373
# 0.006722688674926758
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625777350_1_ir.cub
# copy: 0.0001957416534423828
# 0.40199780464172363
# 0.006001472473144531
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625779034_1_ir.cub
# copy: 0.0003504753112792969
# 1.0833051204681396
# 0.013651609420776367
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625788845_1_ir.cub
# copy: 0.00043272972106933594
# 1.0640363693237305
# 0.018923044204711914
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625781453_1_ir.cub
# copy: 0.00039649009704589844
# 1.1807842254638672
# 0.02185821533203125
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625776271_1_ir.cub
# copy: 0.0001385211944580078
# 0.43618011474609375
# 0.006361961364746094
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625790808_1_ir.cub
# copy: 0.00037550926208496094
# 0.8878216743469238
# 0.01341700553894043
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625784427_1_ir.cub
# copy: 0.0003845691680908203
# 1.0724616050720215
# 0.014444828033447266
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625787874_1_ir.cub
# copy: 0.0010178089141845703
# 1.2448525428771973
# 0.017851591110229492
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625776878_1_ir.cub
# copy: 0.00013756752014160156
# 0.43603944778442383
# 0.0063190460205078125
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625776136_1_ir.cub
# copy: 0.00013756752014160156
# 0.46345019340515137
# 0.005594968795776367
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625778294_1_ir.cub
# copy: 0.00015306472778320312
# 0.29860877990722656
# 0.004431009292602539
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625789310_1_ir.cub
# copy: 0.00036215782165527344
# 1.2152657508850098
# 0.01598834991455078
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625780989_1_ir.cub
# copy: 0.00038313865661621094
# 1.2024281024932861
# 0.015208959579467773
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625776204_1_ir.cub
# copy: 0.00012946128845214844
# 0.45081281661987305
# 0.006529331207275391
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625787354_1_ir.cub
# copy: 0.00037384033203125
# 0.9545331001281738
# 0.01301264762878418
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625778160_1_ir.cub
# copy: 0.0001430511474609375
# 0.3429267406463623
# 0.004664421081542969
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625776339_1_ir.cub
# copy: 0.00014352798461914062
# 0.4231572151184082
# 0.006758928298950195
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625783398_1_ir.cub
# copy: 0.00035572052001953125
# 1.137122631072998
# 0.014731884002685547
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625789806_1_ir.cub
# copy: 0.00036525726318359375
# 0.9507739543914795
# 0.011841535568237305
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625776474_1_ir.cub
# copy: 0.000232696533203125
# 0.44762492179870605
# 0.006045818328857422
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625777148_1_ir.cub
# copy: 0.00025200843811035156
# 0.43297266960144043
# 0.005858182907104492
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625781918_1_ir.cub
# copy: 0.0003666877746582031
# 1.3891549110412598
# 0.024660110473632812
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625776743_1_ir.cub
# copy: 0.0001392364501953125
# 0.42678117752075195
# 0.006590366363525391
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625777013_1_ir.cub
# copy: 0.00014352798461914062
# 0.6622107028961182
# 0.006162166595458984
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625778497_1_ir.cub
# copy: 0.00015974044799804688
# 0.26880955696105957
# 0.0031614303588867188
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625776001_1_ir.cub
# copy: 0.00015354156494140625
# 0.44649386405944824
# 0.005978822708129883
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625776608_1_ir.cub
# copy: 0.00014925003051757812
# 0.4292640686035156
# 0.0075342655181884766
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625786879_1_ir.cub
# copy: 0.0003237724304199219
# 1.4374892711639404
# 0.01432657241821289
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625777755_1_ir.cub
# copy: 0.0001277923583984375
# 0.4714488983154297
# 0.00545954704284668
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625779530_1_ir.cub
# copy: 0.00036072731018066406
# 1.109877347946167
# 0.014823198318481445
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2009189T194600_2009189T235739/CM_1625777890_1_ir.cub
# copy: 0.00013971328735351562
# 0.37647461891174316
# 0.005374908447265625
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2016127T223449_2016130T200342/CM_1841292710_1_ir.cub
# copy: 0.0011339187622070312
# 5.865797758102417
# 0.014190673828125
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2016127T223449_2016130T200342/CM_1841351567_1_ir.cub
# copy: 0.0004372596740722656
# 1.3342926502227783
# 0.0052258968353271484
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2016127T223449_2016130T200342/CM_1841281547_1_ir.cub
# copy: 0.0005366802215576172
# 3.2320849895477295
# 0.016402482986450195
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2016127T223449_2016130T200342/CM_1841283690_1_ir.cub
# copy: 0.0006918907165527344
# 4.555097818374634
# 0.017154693603515625
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2016127T223449_2016130T200342/CM_1841376895_1_ir.cub
# copy: 0.0006499290466308594
# 1.289640188217163
# 0.0032973289489746094
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2016127T223449_2016130T200342/CM_1841278414_1_ir.cub
# copy: 0.0007500648498535156
# 1.4940316677093506
# 0.022365331649780273
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2016127T223449_2016130T200342/CM_1841282090_1_ir.cub
# copy: 0.0006160736083984375
# 2.339254856109619
# 0.015570402145385742
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2016127T223449_2016130T200342/CM_1841387657_8_ir.cub
# copy: 0.00017905235290527344
# 0.8516035079956055
# 0.003158092498779297
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2016127T223449_2016130T200342/CM_1841281273_1_ir.cub
# copy: 0.0006067752838134766
# 3.856245756149292
# 0.01719975471496582
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2016127T223449_2016130T200342/CM_1841368069_1_ir.cub
# copy: 0.00023555755615234375
# 1.4522228240966797
# 0.004039287567138672
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2016127T223449_2016130T200342/CM_1841279980_1_ir.cub
# copy: 0.0007333755493164062
# 9.076419353485107
# 0.0246279239654541
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2016127T223449_2016130T200342/CM_1841284507_1_ir.cub
# copy: 0.0005517005920410156
# 2.762073516845703
# 0.03731822967529297
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2016127T223449_2016130T200342/CM_1841275013_1_ir.cub
# copy: 0.001313924789428711
# 6.988921880722046
# 0.046259164810180664
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2016127T223449_2016130T200342/CM_1841351414_1_ir.cub
# copy: 0.00026106834411621094
# 4.286559820175171
# 0.005090236663818359
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2016127T223449_2016130T200342/CM_1841283964_1_ir.cub
# copy: 0.0009169578552246094
# 3.5711092948913574
# 0.01855182647705078
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2016127T223449_2016130T200342/CM_1841272581_1_ir.cub
# copy: 0.0016036033630371094
# 2.295264482498169
# 0.035956621170043945
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2016127T223449_2016130T200342/CM_1841278020_1_ir.cub
# copy: 0.0008683204650878906
# 1.8455560207366943
# 0.02553415298461914
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2016127T223449_2016130T200342/CM_1841269234_1_ir.cub
# copy: 0.0017778873443603516
# 15.20621657371521
# 0.04497694969177246
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2016127T223449_2016130T200342/CM_1841346809_1_ir.cub
# copy: 0.00029921531677246094
# 2.3042473793029785
# 0.011360406875610352
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2016127T223449_2016130T200342/CM_1841290630_1_ir.cub
# copy: 0.0004687309265136719
# 6.480579137802124
# 0.025684356689453125
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2016127T223449_2016130T200342/CM_1841387557_1_ir.cub
# copy: 0.00017690658569335938
# 2.0251734256744385
# 0.004467487335205078
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2016127T223449_2016130T200342/CM_1841288944_9_ir.cub
# copy: 0.0007228851318359375
# 2.8235740661621094
# 0.02022242546081543
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2016127T223449_2016130T200342/CM_1841367934_1_ir.cub
# copy: 0.00023937225341796875
# 2.40122389793396
# 0.0062694549560546875
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2016127T223449_2016130T200342/CM_1841286170_1_ir.cub
# copy: 0.0005514621734619141
# 4.404658555984497
# 0.017542362213134766
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2016127T223449_2016130T200342/CM_1841346547_1_ir.cub
# copy: 0.0003294944763183594
# 2.3570117950439453
# 0.008188486099243164
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2016127T223449_2016130T200342/CM_1841355994_1_ir.cub
# copy: 0.0001308917999267578
# 0.8101546764373779
# 0.004845857620239258
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2016127T223449_2016130T200342/CM_1841268447_1_ir.cub
# copy: 0.0007572174072265625
# 3.080524206161499
# 0.03788304328918457
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2016127T223449_2016130T200342/CM_1841286987_1_ir.cub
# copy: 0.000518798828125
# 2.314779043197632
# 0.01720595359802246
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2016127T223449_2016130T200342/CM_1841286444_1_ir.cub
# copy: 0.0005235671997070312
# 2.7365520000457764
# 0.01911616325378418
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2016127T223449_2016130T200342/CM_1841276017_1_ir.cub
# copy: 0.0016541481018066406
# 7.101031064987183
# 0.03805851936340332
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2016127T223449_2016130T200342/CM_1841295610_5_ir.cub
# copy: 0.0006444454193115234
# 1.9134583473205566
# 0.024044275283813477
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2016127T223449_2016130T200342/CM_1841356068_1_ir.cub
# copy: 0.000125885009765625
# 0.7135958671569824
# 0.005316734313964844
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2016127T223449_2016130T200342/CM_1841272098_1_ir.cub
# copy: 0.0009660720825195312
# 2.5105628967285156
# 0.033806800842285156
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2016127T223449_2016130T200342/CM_1841292972_1_ir.cub
# copy: 0.0005815029144287109
# 3.9947457313537598
# 0.016367435455322266
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2016127T223449_2016130T200342/CM_1841290892_1_ir.cub
# copy: 0.0005762577056884766
# 5.569599866867065
# 0.017948627471923828
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2016127T223449_2016130T200342/CM_1841376779_1_ir.cub
# copy: 0.00020933151245117188
# 1.5504646301269531
# 0.004868030548095703
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2016127T223449_2016130T200342/CM_1841288670_1_ir.cub
# copy: 0.0005304813385009766
# 9.49599575996399
# 0.018982648849487305
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2016127T223449_2016130T200342/CM_1841274509_1_ir.cub
# copy: 0.0010013580322265625
# 6.3754448890686035
# 0.03831124305725098
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2005359T100445_2005360T101919/CM_1514277149_1_ir.cub
# copy: 0.002016782760620117
# 0.011469602584838867
# 0.0075490474700927734
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2005359T100445_2005360T101919/CM_1514280779_1_ir.cub
# copy: 0.0016016960144042969
# 0.010268211364746094
# 0.008084535598754883
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2005359T100445_2005360T101919/CM_1514282576_1_ir.cub
# copy: 0.001928567886352539
# 1.8836619853973389
# 0.030452251434326172
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2005359T100445_2005360T101919/CM_1514280052_1_ir.cub
# copy: 0.0014908313751220703
# 1.7586233615875244
# 0.027783632278442383
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2005359T100445_2005360T101919/CM_1514278619_1_ir.cub
# copy: 0.0018150806427001953
# 1.7765166759490967
# 0.02721714973449707
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2005359T100445_2005360T101919/CM_1514280412_1_ir.cub
# copy: 0.001416921615600586
# 1.7374329566955566
# 0.02829289436340332
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2005359T100445_2005360T101919/CM_1514284191_1_ir.cub
# copy: 0.0017209053039550781
# 2.9755499362945557
# 0.04323458671569824
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2005359T100445_2005360T101919/CM_1514277541_1_ir.cub
# copy: 0.0013265609741210938
# 1.586167812347412
# 0.031795501708984375
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2005359T100445_2005360T101919/CM_1514281143_1_ir.cub
# copy: 0.0015413761138916016
# 1.8074896335601807
# 0.028766870498657227
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2005359T100445_2005360T101919/CM_1514282941_1_ir.cub
# copy: 0.0013823509216308594
# 1.873142957687378
# 0.029081344604492188
# Working on: /home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2005359T100445_2005360T101919/CM_1514277901_1_ir.cub
# copy: 0.0013403892517089844
# 1.5963811874389648
# 0.027024030685424805

# %%
nav = pysis.CubeFile('/home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2016127T223449_2016130T200342/CM_1841286170_1_ir_nav.cub').data
data = pysis.CubeFile('/home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2016127T223449_2016130T200342/CM_1841286170_1_ir.cub').data
lbl = pysis.CubeFile('/home/alanyu/Dropbox (MIT)/VIMS_UROP/data/2016127T223449_2016130T200342/CM_1841286170_1_ir.cub').label
analyze_cube(data,nav,lbl['IsisCube']['Instrument']['SwathLength'],lbl['IsisCube']['Instrument']['SwathWidth'])

# %%
write_cubes('/home/alanyu/Dropbox (MIT)/VIMS_UROP/data')

# %%
create_cube_parser('/home/alanyu/Dropbox (MIT)/VIMS_UROP/data')

# %%
def read_database(file_name):
    data = {}
    
    file = open(file_name,'r')
    while True:
        try:
            temp = ast.literal_eval(file.readline())
            name = temp['name']
            del(temp['name'])
            data.update({name:temp})
        except Exception as e:
            #print(e)
            break
            
    file.close()
    
    return data

# %%
def search(database):
    parameters = input('Enter parameters as tuples separated by whitespace. Use None to specify no filter for that parameter. \nOrdering: Real Amplitude, Mean, Sigma, Gaussian Amplitude, Incidence, Emission, Phase, Latitude, Longitude.')
    parameters = [eval(x) for x in parameters]#['None', 'None', 'None','None','None','None','None','None', '(180,360)']]
    
    assert len(parameters) == 10, 'Incorrect number of parameters specified'
    code = {0:'real_amplitude',1:'mean',2:'sigma',3:'amplitude',4:'incidence',5:'emission',6:'phase',7:'lat',8:'lon'}
    out = {}
    for cube in database:
        for i in range(len(parameters)):
            if parameters[i] is not None and (database[cube][f'min_{code[i]}']<parameters[i][0] or \
                                              database[cube][f'max_{code[i]}']>parameters[i][1]):
                break
        else:
             out.update({cube:database[cube]})
                
    return out

# %%
# %timeit create_cube_parser('/home/alanyu/Dropbox (MIT)/VIMS_UROP/test')
#With fitting
#one directory: 2005359T100445_2005360T101919
#19.2 s ± 1.64 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

#No fitting, but with loops
#16.9 s ± 566 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

#control: just looping through and loading files, no analysis
#15.8 s ± 380 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
d

# %%
class Window(Frame):
    def __init__(self, master = None):
        Frame.__init__(self, master)
        self.master = master
        self.init_window()
    def printtext(e):
        def p():
            print(e.get())
        return p
    def init_window(self):
        self.master.title('GUI')
        
        self.pack(fill=BOTH,expand=1)
        
        #quitButton = Button(self,text='QUIT',command=self.client_exit)
        
        #quitButton.place(x=0,y=0)
        
        menu = Menu(self.master)
        self.master.config(menu=menu)
        
        file = Menu(menu)
        file.add_command(label='Save')
        file.add_command(label='Exit',command=self.client_exit)
        menu.add_cascade(label='File',menu=file)
        
        edit=Menu(menu)
        edit.add_command(label='Show Image',command = self.showImg)
        edit.add_command(label='Show Text',command=self.showText)
        menu.add_cascade(label='Edit',menu=edit)
        
        e=Entry(self)
        e.pack()
        e.focus_set()
        b=Button(self,text='ok')
        b.pack(side='bottom')
        
    
    def showImg(self):
        load=Image.open('2005_3d.png')
        render = ImageTk.PhotoImage(load)
        
        img=Label(self,image=render)
        img.image=render
        img.place(x=0,y=0)
        
    def showText(self):
        text=Label(self,text='Hello World')
        text.pack()
        
    def client_exit(self):
        self.master.destroy()
        
root = Tk()
root.geometry('400x300')
app = Window(root)

root.mainloop()

# %%
import tkinter
class App():
    def __init__(self):
        self.root = tkinter.Tk()
        button = tkinter.Button(self.root, text = 'root quit', command=self.quit)
        button.pack()
        self.root.mainloop()

    def quit(self):
        self.root.destroy()

app = App()

# %%
# %timeit test = np.load('/home/alanyu/Dropbox (MIT)/VIMS_UROP/cube_info/2005359T100445_2005360T101919-CM_1514280052_1_ir.cub-64x64.npy',allow_pickle=True)
test[20]
# Out:
# 7.81 ms ± 214 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# array([[-0.0009496157290413976, 0.00018700241344049573,
#         0.00018519342120271176, ..., -0.0006614071317017078,
#         -0.0006621116772294044, -0.000663038925267756],
#        [0.00018211669521406293, 0.00018036890833172947,
#         0.00017863961693365127, ..., 0.00012762020924128592,
#         0.000915833399631083, -0.0006611858843825758],
#        [0.00017566338647156954, 0.00017399003263562918,
#         0.0001723362656775862, ..., 0.00012380917905829847,
#         0.00012391257041599602, 0.00012405408779159188],
#        ...,
#        [-6.334969657473266e-05, -0.0010361031163483858,
#         -6.2333740061149e-05, ..., 0.029725924134254456,
#         0.023611851036548615, 0.01445066835731268],
#        [-6.727128493366763e-05, -6.67211934342049e-05,
#         -6.618737825192511e-05, ..., 0.025243433192372322,
#         0.019100036472082138, 0.011433631181716919],
#        [-7.122118404367939e-05, -7.063517841743305e-05,
#         -7.006782107055187e-05, ..., 0.02303570695221424,
#         0.01532457023859024, 0.007628164254128933]], dtype=object)

# %%
# Out:
# 480 ms ± 28.2 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
