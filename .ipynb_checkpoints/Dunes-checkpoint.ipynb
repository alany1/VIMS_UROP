# %%
from IPython.core.display import HTML
import numpy as np
import matplotlib
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
from pylab import *
import pysis
import os
import scipy.optimize as sco
import time
import ast
from tkinter import *
from astropy.time import Time
# %matplotlib qt
from IPython.core.display import HTML 

HTML("<style>.container { width:96% !important; }</style>")
# Out:
# /home/alanyu/anaconda3/lib/python3.8/site-packages/pysis/env.py:33: RuntimeWarning: Could not find isis. Is `ISISROOT` set?
#   warnings.warn('Could not find isis. Is `ISISROOT` set?', RuntimeWarning)
# <style>.container { width:96% !important; }</style>

# %% [markdown]
# <h2>Query</h2>
#
# Small: SELECT * FROM public.vims_trial WHERE latitude<0 AND latitude>-15 AND longitude>110
# AND longitude<130 AND incidence>25 AND incidence<30 AND phase>15 AND phase<20 AND emission > 20 AND emission < 25;
#
# Larger: SELECT * FROM public.vims_trial WHERE latitude<0 AND latitude>-15 AND longitude>110
# AND longitude<130 AND incidence>25 AND incidence<35 AND phase>15 AND phase<25 AND emission > 20 AND emission < 30;
#
# Largest: SELECT * FROM public.vims_trial WHERE latitude<0 AND latitude>-15 AND longitude>110
# AND longitude<130 AND incidence>25 AND incidence<45 AND phase>15 AND phase<35 AND emission > 20 AND emission < 40;

# %%
def parse_csv(path_to_csv,channel=69):
    """
    path_to_csv: path to file
    channel: spectra of interest, default is 69.
    
    Returns dictionary containing desired data. Only works for * query.
    """
    data = []
    
    with open(path_to_csv,'r') as f:
        
        head = f.readline().replace('"','').strip().split(',')
        while True:
            try:
                entry = f.readline()
            except:
                break
            if entry == '':
                break
                
            entry=entry.replace('"','').split('{')
            info = entry[0][:-1].split(',')
            
            spectra = list(map(float,entry[1][:-2].split(',')))

            entry_dict = dict()
            for i,col in enumerate(head[:-1]):
                if col not in ['name','sequenceid','observationid','starttime']:
                    entry_dict[col]=float(info[i])
                else:
                    entry_dict[col]=info[i]
            entry_dict['channel']=spectra[channel-1]
            data.append(entry_dict)
    return data

# %%
parse_csv('dunes_1.csv')
# Out:
# [{'name': 'V1560456861_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_HIGHRES901_PRIME',
#   'latitude': -4.0592310382497,
#   'longitude': 128.90000401741,
#   'phase': 19.553628675075,
#   'incidence': 29.229187870707,
#   'emission': 24.83857373681,
#   'distance': 41272.345856067,
#   'lineres': 73562.603763312,
#   'sampres': 19720.669877666,
#   'scposx': -35524.334330819,
#   'scposy': 20550.661418083,
#   'scposz': 4370.1851327259,
#   'sunposx': -1244210569.8881,
#   'sunposy': 518800092.54163,
#   'sunposz': -283802438.22523,
#   'ettime': 235035807.8635,
#   'starttime': '2007-06-13 19:40:09.398',
#   'exposureduration': 80.0,
#   'channel': 0.0565425},
#  {'name': 'V1560456861_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_HIGHRES901_PRIME',
#   'latitude': -3.6225149688942,
#   'longitude': 128.85719397701,
#   'phase': 19.525373677334,
#   'incidence': 29.401837849358,
#   'emission': 24.682808139091,
#   'distance': 41272.820360123,
#   'lineres': 73360.26875416,
#   'sampres': 19694.461749641,
#   'scposx': -35524.740280904,
#   'scposy': 20550.911159964,
#   'scposz': 4370.1920951592,
#   'sunposx': -1244210377.7335,
#   'sunposy': 518800554.1524,
#   'sunposz': -283802437.91233,
#   'ettime': 235035807.94488,
#   'starttime': '2007-06-13 19:40:09.398',
#   'exposureduration': 80.0,
#   'channel': 0.0563215},
#  {'name': 'V1560456861_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_HIGHRES901_PRIME',
#   'latitude': -3.1865105136338,
#   'longitude': 128.81290468292,
#   'phase': 19.497118909546,
#   'incidence': 29.580711038325,
#   'emission': 24.536239203845,
#   'distance': 41273.294864371,
#   'lineres': 73159.933067284,
#   'sampres': 19670.014960936,
#   'scposx': -35525.146230937,
#   'scposy': 20551.160902219,
#   'scposz': 4370.1990575908,
#   'sunposx': -1244210185.5788,
#   'sunposy': 518801015.76327,
#   'sunposz': -283802437.59943,
#   'ettime': 235035808.02626,
#   'starttime': '2007-06-13 19:40:09.398',
#   'exposureduration': 80.0,
#   'channel': 0.054716},
#  {'name': 'V1560456861_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_HIGHRES901_PRIME',
#   'latitude': -2.751184025226,
#   'longitude': 128.7671349378,
#   'phase': 19.468864373887,
#   'incidence': 29.765683464844,
#   'emission': 24.398986321845,
#   'distance': 41273.769368636,
#   'lineres': 72961.540548485,
#   'sampres': 19647.311562001,
#   'scposx': -35525.552180769,
#   'scposy': 20551.410644757,
#   'scposz': 4370.2060200181,
#   'sunposx': -1244209993.4238,
#   'sunposy': 518801477.37407,
#   'sunposz': -283802437.28653,
#   'ettime': 235035808.10764,
#   'starttime': '2007-06-13 19:40:09.398',
#   'exposureduration': 80.0,
#   'channel': 0.0552209},
#  {'name': 'V1560456861_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_HIGHRES901_PRIME',
#   'latitude': -2.3165022904514,
#   'longitude': 128.71988266879,
#   'phase': 19.440610072548,
#   'incidence': 29.956632868652,
#   'emission': 24.271164395568,
#   'distance': 41274.243872746,
#   'lineres': 72765.037221381,
#   'sampres': 19626.335294775,
#   'scposx': -35525.958130251,
#   'scposy': 20551.660387488,
#   'scposz': 4370.2129824385,
#   'sunposx': -1244209801.2688,
#   'sunposy': 518801938.98462,
#   'sunposz': -283802436.97363,
#   'ettime': 235035808.18902,
#   'starttime': '2007-06-13 19:40:09.398',
#   'exposureduration': 80.0,
#   'channel': 0.0550397},
#  {'name': 'V1560463085_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_FIRNADMAP901',
#   'latitude': -10.814747852117,
#   'longitude': 129.2894068254,
#   'phase': 17.314396745412,
#   'incidence': 25.972616096948,
#   'emission': 24.775895534096,
#   'distance': 76980.930344876,
#   'lineres': 42051.715172586,
#   'sampres': 19535.219916617,
#   'scposx': -65507.702420017,
#   'scposy': 40136.382641403,
#   'scposz': 4886.2407713921,
#   'sunposx': -1229280279.6623,
#   'sunposy': 553304000.95992,
#   'sunposz': -283778909.26482,
#   'ettime': 235041927.01535,
#   'starttime': '2007-06-13 21:23:53.425',
#   'exposureduration': 480.0,
#   'channel': 0.0568514},
#  {'name': 'V1560463260_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_FIRNADMAP901',
#   'latitude': -8.9734392133473,
#   'longitude': 128.14699389352,
#   'phase': 17.204418354546,
#   'incidence': 27.264322900368,
#   'emission': 24.627872403003,
#   'distance': 77976.595225763,
#   'lineres': 42749.99307658,
#   'sampres': 19661.564945938,
#   'scposx': -66328.103778492,
#   'scposy': 40705.249599466,
#   'scposz': 4900.4803027202,
#   'sunposx': -1228850518.1132,
#   'sunposy': 554259402.66332,
#   'sunposz': -283778253.60785,
#   'ettime': 235042097.52071,
#   'starttime': '2007-06-13 21:26:47.62',
#   'exposureduration': 480.0,
#   'channel': 0.0628706},
#  {'name': 'V1560463260_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_FIRNADMAP901',
#   'latitude': -8.9009153429723,
#   'longitude': 129.11360512381,
#   'phase': 17.213883729638,
#   'incidence': 26.330694497294,
#   'emission': 23.748760053123,
#   'distance': 77992.473752033,
#   'lineres': 40341.494817172,
#   'sampres': 19563.244534413,
#   'scposx': -66341.180490557,
#   'scposy': 40714.331636818,
#   'scposz': 4900.7073415947,
#   'sunposx': -1228843658.5488,
#   'sunposy': 554274636.08858,
#   'sunposz': -283778243.15182,
#   'ettime': 235042100.23982,
#   'starttime': '2007-06-13 21:26:47.62',
#   'exposureduration': 480.0,
#   'channel': 0.0653086},
#  {'name': 'V1560463260_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_FIRNADMAP901',
#   'latitude': -8.8595085229543,
#   'longitude': 129.95889071386,
#   'phase': 17.222852203086,
#   'incidence': 25.511445331761,
#   'emission': 22.999923516391,
#   'distance': 78008.352287806,
#   'lineres': 37603.46883659,
#   'sampres': 19428.443188842,
#   'scposx': -66354.256997889,
#   'scposy': 40723.413991565,
#   'scposz': 4900.9343790951,
#   'sunposx': -1228836798.7957,
#   'sunposy': 554289869.42878,
#   'sunposz': -283778232.6958,
#   'ettime': 235042102.95893,
#   'starttime': '2007-06-13 21:26:47.62',
#   'exposureduration': 480.0,
#   'channel': 0.058701},
#  {'name': 'V1560463260_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_FIRNADMAP901',
#   'latitude': -8.5365954805904,
#   'longitude': 128.18528662554,
#   'phase': 17.19106585663,
#   'incidence': 27.29500726313,
#   'emission': 24.364960929971,
#   'distance': 77979.446587765,
#   'lineres': 43161.43832047,
#   'sampres': 19686.137061279,
#   'scposx': -66330.452024663,
#   'scposy': 40706.880469414,
#   'scposz': 4900.5210729891,
#   'sunposx': -1228849286.331,
#   'sunposy': 554262138.18923,
#   'sunposz': -283778251.73022,
#   'ettime': 235042098.00899,
#   'starttime': '2007-06-13 21:26:47.62',
#   'exposureduration': 480.0,
#   'channel': 0.05879},
#  {'name': 'V1560463260_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_FIRNADMAP901',
#   'latitude': -8.4691855662908,
#   'longitude': 129.13124665798,
#   'phase': 17.200451984336,
#   'incidence': 26.382895961492,
#   'emission': 23.499189257694,
#   'distance': 77995.325115772,
#   'lineres': 39373.976061304,
#   'sampres': 19524.961520971,
#   'scposx': -66343.528699989,
#   'scposy': 40715.96256378,
#   'scposz': 4900.7481116173,
#   'sunposx': -1228842426.7328,
#   'sunposy': 554277371.59925,
#   'sunposz': -283778241.2742,
#   'ettime': 235042100.7281,
#   'starttime': '2007-06-13 21:26:47.62',
#   'exposureduration': 480.0,
#   'channel': 0.0618454},
#  {'name': 'V1560463260_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_FIRNADMAP901',
#   'latitude': -8.4283835780855,
#   'longitude': 129.97327541333,
#   'phase': 17.20941811923,
#   'incidence': 25.568486160401,
#   'emission': 22.746278335893,
#   'distance': 78011.203653283,
#   'lineres': 38193.745155915,
#   'sampres': 19413.353009438,
#   'scposx': -66356.605170581,
#   'scposy': 40725.04497554,
#   'scposz': 4900.9751488714,
#   'sunposx': -1228835566.9457,
#   'sunposy': 554292604.9242,
#   'sunposz': -283778230.81817,
#   'ettime': 235042103.44721,
#   'starttime': '2007-06-13 21:26:47.62',
#   'exposureduration': 480.0,
#   'channel': 0.0597707},
#  {'name': 'V1560463260_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_FIRNADMAP901',
#   'latitude': -8.1717747598095,
#   'longitude': 127.27879768958,
#   'phase': 17.168548047534,
#   'incidence': 28.240976238384,
#   'emission': 24.988773335985,
#   'distance': 77966.41943001,
#   'lineres': 39039.222829613,
#   'sampres': 19578.500445598,
#   'scposx': -66319.723421057,
#   'scposy': 40699.429515716,
#   'scposz': 4900.33480346,
#   'sunposx': -1228854913.9861,
#   'sunposy': 554249640.23274,
#   'sunposz': -283778260.30862,
#   'ettime': 235042095.77817,
#   'starttime': '2007-06-13 21:26:47.62',
#   'exposureduration': 480.0,
#   'channel': 0.0585565},
#  {'name': 'V1560463260_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_FIRNADMAP901',
#   'latitude': -8.1005316406676,
#   'longitude': 128.22216621848,
#   'phase': 17.177715352312,
#   'incidence': 27.333307372625,
#   'emission': 24.108911573204,
#   'distance': 77982.297950078,
#   'lineres': 43139.331875764,
#   'sampres': 19646.876949462,
#   'scposx': -66332.800264236,
#   'scposy': 40708.5113496,
#   'scposz': 4900.5618432138,
#   'sunposx': -1228848054.5428,
#   'sunposy': 554264873.71241,
#   'sunposz': -283778249.8526,
#   'ettime': 235042098.49727,
#   'starttime': '2007-06-13 21:26:47.62',
#   'exposureduration': 480.0,
#   'channel': 0.0594561},
#  {'name': 'V1560463260_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_FIRNADMAP901',
#   'latitude': -8.0387415738855,
#   'longitude': 129.14555878336,
#   'phase': 17.187012117406,
#   'incidence': 26.444524478005,
#   'emission': 23.258733655449,
#   'distance': 77998.176479823,
#   'lineres': 38409.56949961,
#   'sampres': 19488.286359984,
#   'scposx': -66345.876902824,
#   'scposy': 40717.59350098,
#   'scposz': 4900.7888815956,
#   'sunposx': -1228841194.9106,
#   'sunposy': 554280107.10718,
#   'sunposz': -283778239.39657,
#   'ettime': 235042101.21638,
#   'starttime': '2007-06-13 21:26:47.62',
#   'exposureduration': 480.0,
#   'channel': 0.0610694},
#  {'name': 'V1560463260_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_FIRNADMAP901',
#   'latitude': -7.9980022583455,
#   'longitude': 129.98646506687,
#   'phase': 17.195985574332,
#   'incidence': 25.633172454227,
#   'emission': 22.499688615515,
#   'distance': 78014.055019073,
#   'lineres': 38951.620576751,
#   'sampres': 19377.877858914,
#   'scposx': -66358.953336677,
#   'scposy': 40726.675969753,
#   'scposz': 4901.0159186035,
#   'sunposx': -1228834335.0897,
#   'sunposy': 554295340.41689,
#   'sunposz': -283778228.94055,
#   'ettime': 235042103.93549,
#   'starttime': '2007-06-13 21:26:47.62',
#   'exposureduration': 480.0,
#   'channel': 0.0614945},
#  {'name': 'V1560463434_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_FIRNADMAP901',
#   'latitude': -6.2363902914708,
#   'longitude': 127.08868207773,
#   'phase': 17.070033473555,
#   'incidence': 28.773120941313,
#   'emission': 24.214516731876,
#   'distance': 78978.001139305,
#   'lineres': 42210.276901694,
#   'sampres': 19818.173916619,
#   'scposx': -67152.392570273,
#   'scposy': 41278.633902253,
#   'scposz': 4914.7959481309,
#   'sunposx': -1228417546.9597,
#   'sunposy': 555219939.70606,
#   'sunposz': -283777594.19329,
#   'ettime': 235042269.00265,
#   'starttime': '2007-06-13 21:29:41.818',
#   'exposureduration': 480.0,
#   'channel': 0.0589497},
#  {'name': 'V1560463434_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_FIRNADMAP901',
#   'latitude': -6.1196828709492,
#   'longitude': 128.01781594864,
#   'phase': 17.077589716061,
#   'incidence': 27.902272357208,
#   'emission': 23.297352663458,
#   'distance': 78993.880279879,
#   'lineres': 41286.964202548,
#   'sampres': 19599.840336895,
#   'scposx': -67165.456382793,
#   'scposy': 41287.735956861,
#   'scposz': 4915.0229012108,
#   'sunposx': -1228410675.5007,
#   'sunposy': 555235167.77237,
#   'sunposz': -283777583.73722,
#   'ettime': 235042271.72176,
#   'starttime': '2007-06-13 21:29:41.818',
#   'exposureduration': 480.0,
#   'channel': 0.0609253},
#  {'name': 'V1560463434_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_FIRNADMAP901',
#   'latitude': -6.0956265208645,
#   'longitude': 128.92516710873,
#   'phase': 17.087834427185,
#   'incidence': 27.032358608665,
#   'emission': 22.445501253182,
#   'distance': 79009.759430257,
#   'lineres': 40245.242491092,
#   'sampres': 19125.31679512,
#   'scposx': -67178.51999082,
#   'scposy': 41296.838328778,
#   'scposz': 4915.2498529422,
#   'sunposx': -1228403803.8529,
#   'sunposy': 555250395.75363,
#   'sunposz': -283777573.28116,
#   'ettime': 235042274.44087,
#   'starttime': '2007-06-13 21:29:41.818',
#   'exposureduration': 480.0,
#   'channel': 0.0630105},
#  {'name': 'V1560463434_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_FIRNADMAP901',
#   'latitude': -6.061032739869,
#   'longitude': 129.81505826897,
#   'phase': 17.097604324995,
#   'incidence': 26.183527646798,
#   'emission': 21.611410016667,
#   'distance': 79025.638590268,
#   'lineres': 39301.195862141,
#   'sampres': 19564.246038093,
#   'scposx': -67191.583394211,
#   'scposy': 41305.941017902,
#   'scposz': 4915.4768033231,
#   'sunposx': -1228396932.0164,
#   'sunposy': 555265623.64968,
#   'sunposz': -283777562.8251,
#   'ettime': 235042277.15998,
#   'starttime': '2007-06-13 21:29:41.818',
#   'exposureduration': 480.0,
#   'channel': 0.0720985},
#  {'name': 'V1560463434_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_FIRNADMAP901',
#   'latitude': -5.8712411558899,
#   'longitude': 126.16044943655,
#   'phase': 17.047465691705,
#   'incidence': 29.756623945602,
#   'emission': 24.940079342495,
#   'distance': 78964.973479252,
#   'lineres': 43274.009977856,
#   'sampres': 19582.980036523,
#   'scposx': -67141.674519869,
#   'scposy': 41271.166572607,
#   'scposz': 4914.6097488079,
#   'sunposx': -1228423184.3456,
#   'sunposy': 555207446.13376,
#   'sunposz': -283777602.77172,
#   'ettime': 235042266.77182,
#   'starttime': '2007-06-13 21:29:41.818',
#   'exposureduration': 480.0,
#   'channel': 0.0624208},
#  {'name': 'V1560463434_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_FIRNADMAP901',
#   'latitude': -5.7905218656756,
#   'longitude': 127.11107977933,
#   'phase': 17.056339376585,
#   'incidence': 28.857593671922,
#   'emission': 24.008613912472,
#   'distance': 78980.85261161,
#   'lineres': 42033.001456503,
#   'sampres': 19834.185934341,
#   'scposx': -67154.73850002,
#   'scposy': 41280.268366784,
#   'scposz': 4914.8367029917,
#   'sunposx': -1228416313.0416,
#   'sunposy': 555222674.26966,
#   'sunposz': -283777592.31565,
#   'ettime': 235042269.49093,
#   'starttime': '2007-06-13 21:29:41.818',
#   'exposureduration': 480.0,
#   'channel': 0.0597942},
#  {'name': 'V1560463434_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_FIRNADMAP901',
#   'latitude': -5.6740023484314,
#   'longitude': 128.0389383451,
#   'phase': 17.063904762034,
#   'incidence': 27.99196069424,
#   'emission': 23.087409225132,
#   'distance': 78996.731753944,
#   'lineres': 41039.871011566,
#   'sampres': 19570.441148355,
#   'scposx': -67167.802275819,
#   'scposy': 41289.370478372,
#   'scposz': 4915.0636558293,
#   'sunposx': -1228409441.5486,
#   'sunposy': 555237902.3207,
#   'sunposz': -283777581.85959,
#   'ettime': 235042272.21004,
#   'starttime': '2007-06-13 21:29:41.818',
#   'exposureduration': 480.0,
#   'channel': 0.0626055},
#  {'name': 'V1560463434_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_FIRNADMAP901',
#   'latitude': -5.6707085562799,
#   'longitude': 128.94190575478,
#   'phase': 17.074757312023,
#   'incidence': 27.12379036943,
#   'emission': 22.241665421029,
#   'distance': 79012.610906083,
#   'lineres': 40189.856508516,
#   'sampres': 19321.002564042,
#   'scposx': -67180.865847124,
#   'scposy': 41298.472907269,
#   'scposz': 4915.2906073187,
#   'sunposx': -1228402569.8669,
#   'sunposy': 555253130.28669,
#   'sunposz': -283777571.40353,
#   'ettime': 235042274.92915,
#   'starttime': '2007-06-13 21:29:41.818',
#   'exposureduration': 480.0,
#   'channel': 0.0639659},
#  {'name': 'V1560463434_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_FIRNADMAP901',
#   'latitude': -5.6163054303197,
#   'longitude': 129.8263267578,
#   'phase': 17.083860366942,
#   'incidence': 26.288619744043,
#   'emission': 21.396862316337,
#   'distance': 79028.490067855,
#   'lineres': 39205.741701826,
#   'sampres': 19759.387045785,
#   'scposx': -67193.929213793,
#   'scposy': 41307.575653373,
#   'scposz': 4915.5175574575,
#   'sunposx': -1228395697.9965,
#   'sunposy': 555268358.16747,
#   'sunposz': -283777560.94747,
#   'ettime': 235042277.64826,
#   'starttime': '2007-06-13 21:29:41.818',
#   'exposureduration': 480.0,
#   'channel': 0.0712665},
#  {'name': 'V1560463434_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_FIRNADMAP901',
#   'latitude': -5.4377482612325,
#   'longitude': 126.18776191971,
#   'phase': 17.034200488819,
#   'incidence': 29.835765228941,
#   'emission': 24.746334175046,
#   'distance': 78967.824950113,
#   'lineres': 43137.921412341,
#   'sampres': 19766.176311596,
#   'scposx': -67144.020479744,
#   'scposy': 41272.800990389,
#   'scposz': 4914.6505038673,
#   'sunposx': -1228421950.4553,
#   'sunposy': 555210180.70988,
#   'sunposz': -283777600.89408,
#   'ettime': 235042267.2601,
#   'starttime': '2007-06-13 21:29:41.818',
#   'exposureduration': 480.0,
#   'channel': 0.0630704},
#  {'name': 'V1560463434_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_FIRNADMAP901',
#   'latitude': -5.345271483408,
#   'longitude': 127.13201220046,
#   'phase': 17.042647158953,
#   'incidence': 28.949351179094,
#   'emission': 23.811033848951,
#   'distance': 78983.704084231,
#   'lineres': 41940.933548227,
#   'sampres': 20017.721867618,
#   'scposx': -67157.084423173,
#   'scposy': 41281.902841546,
#   'scposz': 4914.877457809,
#   'sunposx': -1228415079.1174,
#   'sunposy': 555225408.83052,
#   'sunposz': -283777590.43802,
#   'ettime': 235042269.97921,
#   'starttime': '2007-06-13 21:29:41.818',
#   'exposureduration': 480.0,
#   'channel': 0.0629769},
#  {'name': 'V1560463434_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_FIRNADMAP901',
#   'latitude': -5.2463775561409,
#   'longitude': 128.05576584844,
#   'phase': 17.050727248672,
#   'incidence': 28.087160485171,
#   'emission': 22.895715508548,
#   'distance': 78999.583228326,
#   'lineres': 40819.832266349,
#   'sampres': 19542.59302605,
#   'scposx': -67170.14816225,
#   'scposy': 41291.005010115,
#   'scposz': 4915.1044104045,
#   'sunposx': -1228408207.5905,
#   'sunposy': 555240636.86628,
#   'sunposz': -283777579.98196,
#   'ettime': 235042272.69832,
#   'starttime': '2007-06-13 21:29:41.818',
#   'exposureduration': 480.0,
#   'channel': 0.0640887},
#  {'name': 'V1560463434_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_FIRNADMAP901',
#   'latitude': -5.2463390073146,
#   'longitude': 128.9574447893,
#   'phase': 17.061681889055,
#   'incidence': 27.222054844538,
#   'emission': 22.045678698586,
#   'distance': 79015.462382226,
#   'lineres': 40039.777512422,
#   'sampres': 19514.001817091,
#   'scposx': -67183.211696834,
#   'scposy': 41300.107495992,
#   'scposz': 4915.3313616517,
#   'sunposx': -1228401335.8749,
#   'sunposy': 555255864.817,
#   'sunposz': -283777569.5259,
#   'ettime': 235042275.41743,
#   'starttime': '2007-06-13 21:29:41.818',
#   'exposureduration': 480.0,
#   'channel': 0.0644869},
#  {'name': 'V1560463434_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_FIRNADMAP901',
#   'latitude': -5.1721739293674,
#   'longitude': 129.83635597555,
#   'phase': 17.070118178692,
#   'incidence': 26.401287618169,
#   'emission': 21.191137284431,
#   'distance': 79031.341545759,
#   'lineres': 39165.071323041,
#   'sampres': 19951.922738922,
#   'scposx': -67196.275026782,
#   'scposy': 41309.210299075,
#   'scposz': 4915.5583115485,
#   'sunposx': -1228394463.9706,
#   'sunposy': 555271092.68251,
#   'sunposz': -283777559.06983,
#   'ettime': 235042278.13654,
#   'starttime': '2007-06-13 21:29:41.818',
#   'exposureduration': 480.0,
#   'channel': 0.0682037},
#  {'name': 'V1560463608_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_FIRNADMAP901',
#   'latitude': -3.311550508155,
#   'longitude': 126.7989695762,
#   'phase': 16.942262772035,
#   'incidence': 29.807041895962,
#   'emission': 23.357776952793,
#   'distance': 79995.325804018,
#   'lineres': 40622.286645566,
#   'sampres': 19693.877077639,
#   'scposx': -67988.918946248,
#   'scposy': 41862.402298867,
#   'scposz': 4929.3330968105,
#   'sunposx': -1227976942.4281,
#   'sunposy': 556195361.19396,
#   'sunposz': -283776924.32029,
#   'ettime': 235042443.20369,
#   'starttime': '2007-06-13 21:32:36.038',
#   'exposureduration': 480.0,
#   'channel': 0.0599887},
#  {'name': 'V1560463608_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_FIRNADMAP901',
#   'latitude': -3.2540886250141,
#   'longitude': 127.73527746295,
#   'phase': 16.951742626661,
#   'incidence': 28.938688146265,
#   'emission': 22.421147971252,
#   'distance': 80011.205576849,
#   'lineres': 43229.697733178,
#   'sampres': 19617.66130885,
#   'scposx': -68001.969660593,
#   'scposy': 41871.524676083,
#   'scposz': 4929.5599642167,
#   'sunposx': -1227970058.8898,
#   'sunposy': 556210583.80683,
#   'sunposz': -283776913.86419,
#   'ettime': 235042445.9228,
#   'starttime': '2007-06-13 21:32:36.038',
#   'exposureduration': 480.0,
#   'channel': 0.0585992},
#  {'name': 'V1560463608_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_FIRNADMAP901',
#   'latitude': -3.2036303016698,
#   'longitude': 128.67816393789,
#   'phase': 16.961607211395,
#   'incidence': 28.065451988968,
#   'emission': 21.482897354647,
#   'distance': 80027.085359616,
#   'lineres': 39504.85050218,
#   'sampres': 19669.664360742,
#   'scposx': -68015.020170533,
#   'scposy': 41880.647370416,
#   'scposz': 4929.7868302973,
#   'sunposx': -1227963175.1628,
#   'sunposy': 556225806.33451,
#   'sunposz': -283776903.40809,
#   'ettime': 235042448.64191,
#   'starttime': '2007-06-13 21:32:36.038',
#   'exposureduration': 480.0,
#   'channel': 0.0587859},
#  {'name': 'V1560463608_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_FIRNADMAP901',
#   'latitude': -3.1405298872349,
#   'longitude': 129.50882624315,
#   'phase': 16.969736359393,
#   'incidence': 27.305698463658,
#   'emission': 20.652371759002,
#   'distance': 80042.965152147,
#   'lineres': 38332.10501525,
#   'sampres': 19779.323990977,
#   'scposx': -68028.070475926,
#   'scposy': 41889.770381764,
#   'scposz': 4930.01369505,
#   'sunposx': -1227956291.2472,
#   'sunposy': 556241028.77682,
#   'sunposz': -283776892.95199,
#   'ettime': 235042451.36102,
#   'starttime': '2007-06-13 21:32:36.038',
#   'exposureduration': 480.0,
#   'channel': 0.0606445},
#  {'name': 'V1560463608_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_FIRNADMAP901',
#   'latitude': -2.8719937027147,
#   'longitude': 126.80433974569,
#   'phase': 16.92875097275,
#   'incidence': 29.94255394016,
#   'emission': 23.22057046613,
#   'distance': 79998.17738985,
#   'lineres': 41187.088660076,
#   'sampres': 19673.571046754,
#   'scposx': -67991.262523903,
#   'scposy': 41864.040412814,
#   'scposz': 4929.3738362848,
#   'sunposx': -1227975706.3408,
#   'sunposy': 556198094.77828,
#   'sunposz': -283776922.44266,
#   'ettime': 235042443.69197,
#   'starttime': '2007-06-13 21:32:36.038',
#   'exposureduration': 480.0,
#   'channel': 0.058903},
#  {'name': 'V1560463608_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_FIRNADMAP901',
#   'latitude': -2.8181805548238,
#   'longitude': 127.75313891043,
#   'phase': 16.93851437377,
#   'incidence': 29.065484945305,
#   'emission': 22.268236862273,
#   'distance': 80014.057164465,
#   'lineres': 43217.580596512,
#   'sampres': 19596.965079777,
#   'scposx': -68004.313201543,
#   'scposy': 41873.162846975,
#   'scposz': 4929.600703453,
#   'sunposx': -1227968822.7687,
#   'sunposy': 556213317.37585,
#   'sunposz': -283776911.98656,
#   'ettime': 235042446.41108,
#   'starttime': '2007-06-13 21:32:36.038',
#   'exposureduration': 480.0,
#   'channel': 0.0581192},
#  {'name': 'V1560463608_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_FIRNADMAP901',
#   'latitude': -2.7649684629641,
#   'longitude': 128.67328136672,
#   'phase': 16.948021071548,
#   'incidence': 28.219004110917,
#   'emission': 21.346484848323,
#   'distance': 80029.936949017,
#   'lineres': 38514.349948556,
#   'sampres': 19650.752390723,
#   'scposx': -68017.363674777,
#   'scposy': 41882.285598254,
#   'scposz': 4929.8275692955,
#   'sunposx': -1227961939.0078,
#   'sunposy': 556228539.88823,
#   'sunposz': -283776901.53046,
#   'ettime': 235042449.13019,
#   'starttime': '2007-06-13 21:32:36.038',
#   'exposureduration': 480.0,
#   'channel': 0.0587859},
#  {'name': 'V1560463608_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_FIRNADMAP901',
#   'latitude': -2.70190415252,
#   'longitude': 129.5034793891,
#   'phase': 16.956157739203,
#   'incidence': 27.464063629207,
#   'emission': 20.511974682304,
#   'distance': 80045.816743333,
#   'lineres': 39501.857707711,
#   'sampres': 19760.360623501,
#   'scposx': -68030.413943465,
#   'scposy': 41891.408666548,
#   'scposz': 4930.0544338103,
#   'sunposx': -1227955055.0583,
#   'sunposy': 556243762.31525,
#   'sunposz': -283776891.07436,
#   'ettime': 235042451.8493,
#   'starttime': '2007-06-13 21:32:36.038',
#   'exposureduration': 480.0,
#   'channel': 0.0605256},
#  {'name': 'V1560463608_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_FIRNADMAP901',
#   'latitude': -2.3826649978481,
#   'longitude': 127.76968315101,
#   'phase': 16.925288032179,
#   'incidence': 29.198816056293,
#   'emission': 22.124437009274,
#   'distance': 80016.908752402,
#   'lineres': 42985.922776779,
#   'sampres': 19600.393709168,
#   'scposx': -68006.656735901,
#   'scposy': 41874.801028094,
#   'scposz': 4929.6414426465,
#   'sunposx': -1227967586.6415,
#   'sunposy': 556216050.94212,
#   'sunposz': -283776910.10892,
#   'ettime': 235042446.89936,
#   'starttime': '2007-06-13 21:32:36.038',
#   'exposureduration': 480.0,
#   'channel': 0.0573554},
#  {'name': 'V1560463608_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_FIRNADMAP901',
#   'latitude': -2.3266948100756,
#   'longitude': 128.66715211555,
#   'phase': 16.934436528301,
#   'incidence': 28.379047722311,
#   'emission': 21.219812330435,
#   'distance': 80032.788538738,
#   'lineres': 37743.818537208,
#   'sampres': 19655.952169001,
#   'scposx': -68019.70717243,
#   'scposy': 41883.923836319,
#   'scposz': 4929.8683082511,
#   'sunposx': -1227960702.8467,
#   'sunposy': 556231273.4392,
#   'sunposz': -283776899.65282,
#   'ettime': 235042449.61847,
#   'starttime': '2007-06-13 21:32:36.038',
#   'exposureduration': 480.0,
#   'channel': 0.0585001},
#  {'name': 'V1560463608_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_FIRNADMAP901',
#   'latitude': -2.2634438622479,
#   'longitude': 129.49973812103,
#   'phase': 16.942609820717,
#   'incidence': 27.626469007026,
#   'emission': 20.378766177471,
#   'distance': 80048.668334838,
#   'lineres': 40671.416080332,
#   'sampres': 19742.884602116,
#   'scposx': -68032.757404412,
#   'scposy': 41893.046961557,
#   'scposz': 4930.0951725278,
#   'sunposx': -1227953818.8634,
#   'sunposy': 556246495.85092,
#   'sunposz': -283776889.19672,
#   'ettime': 235042452.33758,
#   'starttime': '2007-06-13 21:32:36.038',
#   'exposureduration': 480.0,
#   'channel': 0.0628372},
#  {'name': 'V1560463782_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_FIRNADMAP901',
#   'latitude': -0.24553224776972,
#   'longitude': 128.34594606302,
#   'phase': 16.83576773023,
#   'incidence': 29.435866329085,
#   'emission': 20.97623732797,
#   'distance': 81044.451712263,
#   'lineres': 42343.351605455,
#   'sampres': 19883.454255966,
#   'scposx': -68850.681092463,
#   'scposy': 42465.757762979,
#   'scposz': 4944.3183616354,
#   'sunposx': -1227521772.9152,
#   'sunposy': 557200866.86629,
#   'sunposz': -283776233.53285,
#   'ettime': 235042622.84289,
#   'starttime': '2007-06-13 21:35:30.236',
#   'exposureduration': 480.0,
#   'channel': 0.0580995},
#  {'name': 'V1560463782_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_FIRNADMAP901',
#   'latitude': -0.18944556674965,
#   'longitude': 129.2520630257,
#   'phase': 16.84504143115,
#   'incidence': 28.635337648586,
#   'emission': 20.047464239082,
#   'distance': 81060.33214578,
#   'lineres': 39180.320100584,
#   'sampres': 19776.036231673,
#   'scposx': -68863.718305207,
#   'scposy': 42474.901084079,
#   'scposz': 4944.5451421732,
#   'sunposx': -1227514876.9248,
#   'sunposy': 557216083.8453,
#   'sunposz': -283776223.07672,
#   'ettime': 235042625.562,
#   'starttime': '2007-06-13 21:35:30.236',
#   'exposureduration': 480.0,
#   'channel': 0.0577017},
#  {'name': 'V1560469931_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_MEDRES001_PRIME',
#   'latitude': -11.229962133798,
#   'longitude': 127.88947618442,
#   'phase': 16.276823534629,
#   'incidence': 25.479668106953,
#   'emission': 23.831693061871,
#   'distance': 118839.72145591,
#   'lineres': 61479.256493642,
#   'sampres': 57843.257163833,
#   'scposx': -99274.71027643,
#   'scposy': 65095.134525253,
#   'scposz': 5480.3974661752,
#   'sunposx': -1210593807.4185,
#   'sunposy': 593138594.08736,
#   'sunposz': -283751368.40199,
#   'ettime': 235049088.55602,
#   'starttime': '2007-06-13 23:17:59.307',
#   'exposureduration': 160.0,
#   'channel': 0.0548837},
#  {'name': 'V1560469931_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_MEDRES001_PRIME',
#   'latitude': -10.58562944027,
#   'longitude': 126.08536338106,
#   'phase': 16.249128534206,
#   'incidence': 27.301433989422,
#   'emission': 24.979436211642,
#   'distance': 118777.25109753,
#   'lineres': 62101.325080247,
#   'sampres': 57715.779182047,
#   'scposx': -99225.427846283,
#   'scposy': 65056.319760752,
#   'scposz': 5479.5169672206,
#   'sunposx': -1210622628.7248,
#   'sunposy': 593079669.43829,
#   'sunposz': -283751409.46166,
#   'ettime': 235049077.87998,
#   'starttime': '2007-06-13 23:17:59.307',
#   'exposureduration': 160.0,
#   'channel': 0.0545001},
#  {'name': 'V1560469931_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_MEDRES001_PRIME',
#   'latitude': -10.049122554622,
#   'longitude': 127.37186384467,
#   'phase': 16.248471489935,
#   'incidence': 26.095700072915,
#   'emission': 23.591223958868,
#   'distance': 118840.67384047,
#   'lineres': 61479.729328662,
#   'sampres': 57735.541388838,
#   'scposx': -99275.461580032,
#   'scposy': 65095.726306797,
#   'scposz': 5480.4108895843,
#   'sunposx': -1210593368.0053,
#   'sunposy': 593139492.40365,
#   'sunposz': -283751367.77602,
#   'ettime': 235049088.71878,
#   'starttime': '2007-06-13 23:17:59.307',
#   'exposureduration': 160.0,
#   'channel': 0.0607264},
#  {'name': 'V1560469931_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_MEDRES001_PRIME',
#   'latitude': -9.4092753267473,
#   'longitude': 125.5644958611,
#   'phase': 16.22077761535,
#   'incidence': 27.945218533953,
#   'emission': 24.828665794496,
#   'distance': 118778.20347864,
#   'lineres': 62107.861292291,
#   'sampres': 57644.864268379,
#   'scposx': -99226.179198262,
#   'scposy': 65056.911470062,
#   'scposz': 5479.5303908471,
#   'sunposx': -1210622189.3552,
#   'sunposy': 593080567.7761,
#   'sunposz': -283751408.83569,
#   'ettime': 235049078.04274,
#   'starttime': '2007-06-13 23:17:59.307',
#   'exposureduration': 160.0,
#   'channel': 0.0544199},
#  {'name': 'V1560469931_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_MEDRES001_PRIME',
#   'latitude': -8.8742525955224,
#   'longitude': 126.84727597256,
#   'phase': 16.220119452618,
#   'incidence': 26.765558247095,
#   'emission': 23.43084202858,
#   'distance': 118841.62622526,
#   'lineres': 61486.416527876,
#   'sampres': 57664.818787776,
#   'scposx': -99276.212883036,
#   'scposy': 65096.318089553,
#   'scposz': 5480.4243129926,
#   'sunposx': -1210592928.5914,
#   'sunposy': 593140390.71978,
#   'sunposz': -283751367.15005,
#   'ettime': 235049088.88154,
#   'starttime': '2007-06-13 23:17:59.307',
#   'exposureduration': 160.0,
#   'channel': 0.0589931},
#  {'name': 'V1560469931_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_MEDRES001_PRIME',
#   'latitude': -8.3414394917178,
#   'longitude': 128.11465243001,
#   'phase': 16.219509506869,
#   'incidence': 25.614321647399,
#   'emission': 22.047248699244,
#   'distance': 118905.04921697,
#   'lineres': 66590.796740089,
#   'sampres': 57683.383886398,
#   'scposx': -99326.243306308,
#   'scposy': 65135.729599897,
#   'scposz': 5481.3182206124,
#   'sunposx': -1210563664.8713,
#   'sunposy': 593200212.21982,
#   'sunposz': -283751325.46441,
#   'ettime': 235049099.72034,
#   'starttime': '2007-06-13 23:17:59.307',
#   'exposureduration': 160.0,
#   'channel': 0.0579771},
#  {'name': 'V1560469931_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_MEDRES001_PRIME',
#   'latitude': -8.2385535206078,
#   'longitude': 125.03538939333,
#   'phase': 16.192426707945,
#   'incidence': 28.639086876849,
#   'emission': 24.755773811253,
#   'distance': 118779.15585963,
#   'lineres': 62121.47619892,
#   'sampres': 57611.289318714,
#   'scposx': -99226.930549368,
#   'scposy': 65057.503180367,
#   'scposz': 5479.5438144678,
#   'sunposx': -1210621749.9851,
#   'sunposy': 593081466.11342,
#   'sunposz': -283751408.20973,
#   'ettime': 235049078.2055,
#   'starttime': '2007-06-13 23:17:59.307',
#   'exposureduration': 160.0,
#   'channel': 0.0579725},
#  {'name': 'V1560469931_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_MEDRES001_PRIME',
#   'latitude': -7.7047506564907,
#   'longitude': 126.31507603144,
#   'phase': 16.191767422951,
#   'incidence': 27.48545287591,
#   'emission': 23.351804324518,
#   'distance': 118842.57860993,
#   'lineres': 61499.302651434,
#   'sampres': 57630.690426602,
#   'scposx': -99276.964185166,
#   'scposy': 65096.909873303,
#   'scposz': 5480.4377363952,
#   'sunposx': -1210592489.1768,
#   'sunposy': 593141289.03541,
#   'sunposz': -283751366.52408,
#   'ettime': 235049089.0443,
#   'starttime': '2007-06-13 23:17:59.307',
#   'exposureduration': 160.0,
#   'channel': 0.0572787},
#  {'name': 'V1560469931_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_MEDRES001_PRIME',
#   'latitude': -7.1730306664251,
#   'longitude': 127.57958595531,
#   'phase': 16.191156444035,
#   'incidence': 26.36192328204,
#   'emission': 21.96131548312,
#   'distance': 118906.00160533,
#   'lineres': 66568.901748184,
#   'sampres': 57649.86071237,
#   'scposx': -99326.994559462,
#   'scposy': 65136.321457088,
#   'scposz': 5481.3316437969,
#   'sunposx': -1210563225.4124,
#   'sunposy': 593201110.51378,
#   'sunposz': -283751324.83844,
#   'ettime': 235049099.8831,
#   'starttime': '2007-06-13 23:17:59.307',
#   'exposureduration': 160.0,
#   'channel': 0.0598824},
#  {'name': 'V1560469931_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_MEDRES001_PRIME',
#   'latitude': -7.0728778840923,
#   'longitude': 124.49739545083,
#   'phase': 16.164075812252,
#   'incidence': 29.379789183984,
#   'emission': 24.761269503967,
#   'distance': 118780.10824068,
#   'lineres': 62142.195268185,
#   'sampres': 57614.860911345,
#   'scposx': -99227.681899739,
#   'scposy': 65058.094891775,
#   'scposz': 5479.5572380853,
#   'sunposx': -1210621310.6142,
#   'sunposy': 593082364.45041,
#   'sunposz': -283751407.58376,
#   'ettime': 235049078.36826,
#   'starttime': '2007-06-13 23:17:59.307',
#   'exposureduration': 160.0,
#   'channel': 0.0690923},
#  {'name': 'V1560469931_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_MEDRES001_PRIME',
#   'latitude': -6.5400381239389,
#   'longitude': 125.77460290791,
#   'phase': 16.163415401174,
#   'incidence': 28.2518610064,
#   'emission': 23.354746704665,
#   'distance': 118843.53099466,
#   'lineres': 61518.412853291,
#   'sampres': 57632.963782341,
#   'scposx': -99277.715486562,
#   'scposy': 65097.501658156,
#   'scposz': 5480.4511597945,
#   'sunposx': -1210592049.7616,
#   'sunposy': 593142187.35073,
#   'sunposz': -283751365.89811,
#   'ettime': 235049089.20706,
#   'starttime': '2007-06-13 23:17:59.307',
#   'exposureduration': 160.0,
#   'channel': 0.0605101},
#  {'name': 'V1560469931_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_MEDRES001_PRIME',
#   'latitude': -6.5154219248461,
#   'longitude': 128.90913000373,
#   'phase': 16.188717446376,
#   'incidence': 25.224408721943,
#   'emission': 20.4530295069,
#   'distance': 118969.42484577,
#   'lineres': 56573.858250413,
#   'sampres': 57776.822344309,
#   'scposx': -99377.021672029,
#   'scposy': 65175.737931342,
#   'scposz': 5482.2255366768,
#   'sunposx': -1210533958.692,
#   'sunposy': 593260930.5482,
#   'sunposz': -283751283.1528,
#   'ettime': 235049110.7219,
#   'starttime': '2007-06-13 23:17:59.307',
#   'exposureduration': 160.0,
#   'channel': 0.0608516},
#  {'name': 'V1560469931_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_MEDRES001_PRIME',
#   'latitude': -6.0091592170514,
#   'longitude': 127.03683066096,
#   'phase': 16.162803385558,
#   'incidence': 27.155577201076,
#   'emission': 21.961462203945,
#   'distance': 118906.95399374,
#   'lineres': 66553.003000073,
#   'sampres': 57652.033685411,
#   'scposx': -99327.74581188,
#   'scposy': 65136.913315382,
#   'scposz': 5481.3450669781,
#   'sunposx': -1210562785.9528,
#   'sunposy': 593202008.80742,
#   'sunposz': -283751324.21247,
#   'ettime': 235049100.04586,
#   'starttime': '2007-06-13 23:17:59.307',
#   'exposureduration': 160.0,
#   'channel': 0.0591718},
#  {'name': 'V1560469931_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_MEDRES001_PRIME',
#   'latitude': -5.3795565229917,
#   'longitude': 125.22516659498,
#   'phase': 16.135063387497,
#   'incidence': 29.061553068049,
#   'emission': 23.439649408547,
#   'distance': 118844.48337962,
#   'lineres': 61543.812938185,
#   'sampres': 57671.649690781,
#   'scposx': -99278.466787359,
#   'scposy': 65098.09344422,
#   'scposz': 5480.4645831929,
#   'sunposx': -1210591610.3456,
#   'sunposy': 593143085.66588,
#   'sunposz': -283751365.27214,
#   'ettime': 235049089.36982,
#   'starttime': '2007-06-13 23:17:59.307',
#   'exposureduration': 160.0,
#   'channel': 0.0614535},
#  {'name': 'V1560469931_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_MEDRES001_PRIME',
#   'latitude': -5.3526738350939,
#   'longitude': 128.36359117678,
#   'phase': 16.160363369683,
#   'incidence': 26.052562542933,
#   'emission': 20.455992583197,
#   'distance': 118970.37723786,
#   'lineres': 56463.929510601,
#   'sampres': 57686.84439729,
#   'scposx': -99377.77287547,
#   'scposy': 65176.329863072,
#   'scposz': 5482.23895964,
#   'sunposx': -1210533519.188,
#   'sunposy': 593261828.82016,
#   'sunposz': -283751282.52683,
#   'ettime': 235049110.88466,
#   'starttime': '2007-06-13 23:17:59.307',
#   'exposureduration': 160.0,
#   'channel': 0.062769},
#  {'name': 'V1560469931_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_MEDRES001_PRIME',
#   'latitude': -4.8492724193598,
#   'longitude': 126.48568783347,
#   'phase': 16.134450331627,
#   'incidence': 27.991820863358,
#   'emission': 22.047691626984,
#   'distance': 118907.90638237,
#   'lineres': 66543.048799678,
#   'sampres': 57689.91282004,
#   'scposx': -99328.497063701,
#   'scposy': 65137.505174887,
#   'scposz': 5481.3584901585,
#   'sunposx': -1210562346.4925,
#   'sunposy': 593202907.10089,
#   'sunposz': -283751323.5865,
#   'ettime': 235049100.20862,
#   'starttime': '2007-06-13 23:17:59.307',
#   'exposureduration': 160.0,
#   'channel': 0.0594619},
#  {'name': 'V1560469931_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_MEDRES001_PRIME',
#   'latitude': -4.2227649139053,
#   'longitude': 124.66604358775,
#   'phase': 16.106711382099,
#   'incidence': 29.911606346053,
#   'emission': 23.605838251457,
#   'distance': 118845.43576446,
#   'lineres': 61575.610139273,
#   'sampres': 57746.962559301,
#   'scposx': -99279.218087283,
#   'scposy': 65098.685231278,
#   'scposz': 5480.4780065856,
#   'sunposx': -1210591170.9291,
#   'sunposy': 593143983.98054,
#   'sunposz': -283751364.64617,
#   'ettime': 235049089.53258,
#   'starttime': '2007-06-13 23:17:59.307',
#   'exposureduration': 160.0,
#   'channel': 0.0584738},
#  {'name': 'V1560469931_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_MEDRES001_PRIME',
#   'latitude': -4.1936088635336,
#   'longitude': 127.81021629014,
#   'phase': 16.132009294058,
#   'incidence': 26.922095661511,
#   'emission': 20.550199088527,
#   'distance': 118971.32963018,
#   'lineres': 56432.259744983,
#   'sampres': 57711.97611936,
#   'scposx': -99378.524078312,
#   'scposy': 65176.921796014,
#   'scposz': 5482.2523826024,
#   'sunposx': -1210533079.6833,
#   'sunposy': 593262727.09195,
#   'sunposz': -283751281.90086,
#   'ettime': 235049111.04742,
#   'starttime': '2007-06-13 23:17:59.307',
#   'exposureduration': 160.0,
#   'channel': 0.0581378},
#  {'name': 'V1560469931_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_MEDRES001_PRIME',
#   'latitude': -3.688770567738,
#   'longitude': 125.92792723123,
#   'phase': 16.106037113097,
#   'incidence': 28.866440234348,
#   'emission': 22.215585237207,
#   'distance': 118908.8587709,
#   'lineres': 66539.025206577,
#   'sampres': 57763.703767261,
#   'scposx': -99329.248314648,
#   'scposy': 65138.097035386,
#   'scposz': 5481.3719133332,
#   'sunposx': -1210561907.0315,
#   'sunposy': 593203805.39387,
#   'sunposz': -283751322.96053,
#   'ettime': 235049100.37138,
#   'starttime': '2007-06-13 23:17:59.307',
#   'exposureduration': 160.0,
#   'channel': 0.0591112},
#  {'name': 'V1560469931_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_MEDRES001_PRIME',
#   'latitude': -3.0376962807711,
#   'longitude': 127.2482678195,
#   'phase': 16.103655219642,
#   'incidence': 27.829740654131,
#   'emission': 20.734629964222,
#   'distance': 118972.28202239,
#   'lineres': 56414.384693441,
#   'sampres': 57786.069177551,
#   'scposx': -99379.275280282,
#   'scposy': 65177.51372995,
#   'scposz': 5482.2658055591,
#   'sunposx': -1210532640.178,
#   'sunposy': 593263625.36325,
#   'sunposz': -283751281.27489,
#   'ettime': 235049111.21018,
#   'starttime': '2007-06-13 23:17:59.307',
#   'exposureduration': 160.0,
#   'channel': 0.0568063},
#  {'name': 'V1560469931_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_MEDRES001_PRIME',
#   'latitude': -2.5301098249674,
#   'longitude': 125.36090899771,
#   'phase': 16.077607549151,
#   'incidence': 29.777835436113,
#   'emission': 22.466717207717,
#   'distance': 118909.81115947,
#   'lineres': 66540.956110776,
#   'sampres': 57873.81094753,
#   'scposx': -99329.99956486,
#   'scposy': 65138.688896988,
#   'scposz': 5481.3853365046,
#   'sunposx': -1210561467.5699,
#   'sunposy': 593204703.68653,
#   'sunposz': -283751322.33456,
#   'ettime': 235049100.53414,
#   'starttime': '2007-06-13 23:17:59.307',
#   'exposureduration': 160.0,
#   'channel': 0.0577925},
#  {'name': 'V1560469931_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_MEDRES001_PRIME',
#   'latitude': -1.8844181882054,
#   'longitude': 126.67697467589,
#   'phase': 16.075301146546,
#   'incidence': 28.772637197916,
#   'emission': 21.007343333603,
#   'distance': 118973.23441465,
#   'lineres': 56400.825334327,
#   'sampres': 57895.861894009,
#   'scposx': -99380.026481516,
#   'scposy': 65178.105664989,
#   'scposz': 5482.2792285125,
#   'sunposx': -1210532200.672,
#   'sunposy': 593264523.63423,
#   'sunposz': -283751280.64892,
#   'ettime': 235049111.37294,
#   'starttime': '2007-06-13 23:17:59.307',
#   'exposureduration': 160.0,
#   'channel': 0.0558187},
#  {'name': 'V1560469931_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_MEDRES001_PRIME',
#   'latitude': -0.73326739826831,
#   'longitude': 126.09552674715,
#   'phase': 16.046947074855,
#   'incidence': 29.748310585398,
#   'emission': 21.365599124297,
#   'distance': 118974.18680714,
#   'lineres': 56391.572573621,
#   'sampres': 58041.951132853,
#   'scposx': -99380.777682152,
#   'scposy': 65178.697601239,
#   'scposz': 5482.2926514651,
#   'sunposx': -1210531761.1653,
#   'sunposy': 593265421.90504,
#   'sunposz': -283751280.02295,
#   'ettime': 235049111.5357,
#   'starttime': '2007-06-13 23:17:59.307',
#   'exposureduration': 160.0,
#   'channel': 0.0555024},
#  {'name': 'V1560469931_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_MEDRES001_PRIME',
#   'latitude': -0.13794905528404,
#   'longitude': 127.19458013887,
#   'phase': 16.043868776988,
#   'incidence': 28.983779860998,
#   'emission': 20.161041997463,
#   'distance': 119037.61031154,
#   'lineres': 60064.523667463,
#   'sampres': 58059.922292022,
#   'scposx': -99430.801288282,
#   'scposy': 65218.11933307,
#   'scposz': 5483.1865287429,
#   'sunposx': -1210502491.2668,
#   'sunposy': 593325240.38729,
#   'sunposz': -283751238.33731,
#   'ettime': 235049122.3745,
#   'starttime': '2007-06-13 23:17:59.307',
#   'exposureduration': 160.0,
#   'channel': 0.0555084},
#  {'name': 'V1560470761_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_MEDRES001_PRIME',
#   'latitude': -10.940757786906,
#   'longitude': 127.62206653101,
#   'phase': 16.193689965986,
#   'incidence': 25.550672963156,
#   'emission': 23.650015694774,
#   'distance': 123714.85011464,
#   'lineres': 59441.758499392,
#   'sampres': 60290.638386479,
#   'scposx': -103110.31641554,
#   'scposy': 68138.350080296,
#   'scposz': 5549.0572090414,
#   'sunposx': -1208336134.3382,
#   'sunposy': 597731988.28457,
#   'sunposz': -283748164.60128,
#   'ettime': 235049921.57715,
#   'starttime': '2007-06-13 23:31:49.302',
#   'exposureduration': 160.0,
#   'channel': 0.0488101},
#  {'name': 'V1560470761_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_MEDRES001_PRIME',
#   'latitude': -10.320777420911,
#   'longitude': 125.71083245734,
#   'phase': 16.166581405279,
#   'incidence': 27.48133507815,
#   'emission': 24.924296566006,
#   'distance': 123652.36082128,
#   'lineres': 70786.896986826,
#   'sampres': 60108.303209894,
#   'scposx': -103061.28114044,
#   'scposy': 68099.165850271,
#   'scposz': 5548.177796626,
#   'sunposx': -1208365178.9894,
#   'sunposy': 597673173.34797,
#   'sunposz': -283748205.66173,
#   'ettime': 235049910.90111,
#   'starttime': '2007-06-13 23:31:49.302',
#   'exposureduration': 160.0,
#   'channel': 0.0475632},
#  {'name': 'V1560470761_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_MEDRES001_PRIME',
#   'latitude': -9.7131336437243,
#   'longitude': 127.07898416915,
#   'phase': 16.165337437986,
#   'incidence': 26.209574303447,
#   'emission': 23.42524815753,
#   'distance': 123715.80278794,
#   'lineres': 59143.481639826,
#   'sampres': 60188.710722152,
#   'scposx': -103111.06395112,
#   'scposy': 68138.947494308,
#   'scposz': 5549.0706158912,
#   'sunposx': -1208335691.52,
#   'sunposy': 597732884.92817,
#   'sunposz': -283748163.97529,
#   'ettime': 235049921.73991,
#   'starttime': '2007-06-13 23:31:49.302',
#   'exposureduration': 160.0,
#   'channel': 0.0531949},
#  {'name': 'V1560470761_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_MEDRES001_PRIME',
#   'latitude': -9.0922549681332,
#   'longitude': 125.16766200001,
#   'phase': 16.138155304972,
#   'incidence': 28.164261187043,
#   'emission': 24.788840814176,
#   'distance': 123653.313491,
#   'lineres': 70752.628889944,
#   'sampres': 60044.495670127,
#   'scposx': -103062.02872452,
#   'scposy': 68099.763192367,
#   'scposz': 5548.1912036883,
#   'sunposx': -1208364736.2148,
#   'sunposy': 597674070.01325,
#   'sunposz': -283748205.03575,
#   'ettime': 235049911.06387,
#   'starttime': '2007-06-13 23:31:49.302',
#   'exposureduration': 160.0,
#   'channel': 0.0493191},
#  {'name': 'V1560470761_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_MEDRES001_PRIME',
#   'latitude': -9.0822973750334,
#   'longitude': 128.27040875041,
#   'phase': 16.162293496144,
#   'incidence': 25.12946366528,
#   'emission': 22.064458768315,
#   'distance': 123779.24500917,
#   'lineres': 63301.431985115,
#   'sampres': 60165.894207095,
#   'scposx': -103160.84349277,
#   'scposy': 68178.734007939,
#   'scposz': 5549.9634210034,
#   'sunposx': -1208306201.1001,
#   'sunposy': 597792595.05338,
#   'sunposz': -283748122.28886,
#   'ettime': 235049932.57871,
#   'starttime': '2007-06-13 23:31:49.302',
#   'exposureduration': 160.0,
#   'channel': 0.0553314},
#  {'name': 'V1560470761_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_046TI_MEDRES001_PRIME',
#   'latitude': -8.4917381870736,
#   'longitude': 126.52820041149,
#   'phase': 16.136984914096,
# ...
#   'channel': 0.0566814},
#  {'name': 'V1561835371_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_047TI_HIRESNAC001_PRIME',
#   'latitude': -8.9298633393474,
#   'longitude': 128.08769499473,
#   'phase': 15.102387766058,
#   'incidence': 29.218331827497,
#   'emission': 24.999097666957,
#   'distance': 35335.08405546,
#   'lineres': 16613.607991713,
#   'sampres': 16361.903521472,
#   'scposx': -30333.857044412,
#   'scposy': 18111.51585891,
#   'scposz': 631.09057039146,
#   'sunposx': -1248515714.7411,
#   'sunposy': 512862559.99702,
#   'sunposz': -278412451.53438,
#   'ettime': 236414372.67122,
#   'starttime': '2007-06-29 18:35:10.67',
#   'exposureduration': 80.0,
#   'channel': 0.0578337},
#  {'name': 'V1561835371_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_047TI_HIRESNAC001_PRIME',
#   'latitude': -8.9211823599697,
#   'longitude': 129.46145183995,
#   'phase': 15.134967352923,
#   'incidence': 27.871524782557,
#   'emission': 23.687870491495,
#   'distance': 35428.975569854,
#   'lineres': 16468.279948832,
#   'sampres': 16363.113259581,
#   'scposx': -30419.599704775,
#   'scposy': 18151.093384092,
#   'scposz': 630.93002192117,
#   'sunposx': -1248478116.8623,
#   'sunposy': 512954233.13852,
#   'sunposz': -278412389.28799,
#   'ettime': 236414388.77734,
#   'starttime': '2007-06-29 18:35:10.67',
#   'exposureduration': 80.0,
#   'channel': 0.0579198},
#  {'name': 'V1561835371_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_047TI_HIRESNAC001_PRIME',
#   'latitude': -8.7940718386181,
#   'longitude': 128.91816782036,
#   'phase': 15.112038695495,
#   'incidence': 28.422310757369,
#   'emission': 24.14583268841,
#   'distance': 35397.836212197,
#   'lineres': 17889.813834817,
#   'sampres': 16387.574021392,
#   'scposx': -30391.163996386,
#   'scposy': 18137.966246553,
#   'scposz': 630.98327172002,
#   'sunposx': -1248490586.9105,
#   'sunposy': 512923830.13017,
#   'sunposz': -278412409.93195,
#   'ettime': 236414383.43576,
#   'starttime': '2007-06-29 18:35:10.67',
#   'exposureduration': 80.0,
#   'channel': 0.0590484},
#  {'name': 'V1561835371_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_047TI_HIRESNAC001_PRIME',
#   'latitude': -8.7370565849285,
#   'longitude': 129.77137520967,
#   'phase': 15.12824394263,
#   'incidence': 27.593569246745,
#   'emission': 23.309645245262,
#   'distance': 35460.589667656,
#   'lineres': 16406.996485975,
#   'sampres': 16383.272618422,
#   'scposx': -30448.467858516,
#   'scposy': 18164.421823277,
#   'scposz': 630.87595675823,
#   'sunposx': -1248465456.0731,
#   'sunposy': 512985099.03234,
#   'sunposz': -278412368.32952,
#   'ettime': 236414394.2003,
#   'starttime': '2007-06-29 18:35:10.67',
#   'exposureduration': 80.0,
#   'channel': 0.0531864},
#  {'name': 'V1561835371_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_047TI_HIRESNAC001_PRIME',
#   'latitude': -8.7308377451567,
#   'longitude': 128.40588164957,
#   'phase': 15.09469304402,
#   'incidence': 28.933810131576,
#   'emission': 24.607663279955,
#   'distance': 35366.697174459,
#   'lineres': 17280.352564846,
#   'sampres': 16398.904730601,
#   'scposx': -30362.727527291,
#   'scposy': 18124.840386799,
#   'scposz': 631.03651750741,
#   'sunposx': -1248503056.2183,
#   'sunposy': 512893426.81883,
#   'sunposz': -278412430.57591,
#   'ettime': 236414378.09418,
#   'starttime': '2007-06-29 18:35:10.67',
#   'exposureduration': 80.0,
#   'channel': 0.0554881},
#  {'name': 'V1561835371_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_047TI_HIRESNAC001_PRIME',
#   'latitude': -8.6132647761926,
#   'longitude': 129.26459947936,
#   'phase': 15.106711624818,
#   'incidence': 28.108747494179,
#   'emission': 23.734646815495,
#   'distance': 35429.44998651,
#   'lineres': 16448.653149643,
#   'sampres': 16370.657253819,
#   'scposx': -30420.032922456,
#   'scposy': 18151.293388475,
#   'scposz': 630.92921061912,
#   'sunposx': -1248477926.8729,
#   'sunposy': 512954696.33194,
#   'sunposz': -278412388.97348,
#   'ettime': 236414388.85872,
#   'starttime': '2007-06-29 18:35:10.67',
#   'exposureduration': 80.0,
#   'channel': 0.0590662},
#  {'name': 'V1561835371_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_047TI_HIRESNAC001_PRIME',
#   'latitude': -8.4851370287469,
#   'longitude': 128.7206766477,
#   'phase': 15.083679790652,
#   'incidence': 28.661194195761,
#   'emission': 24.198978522559,
#   'distance': 35398.310623988,
#   'lineres': 17889.898422112,
#   'sampres': 16395.241910687,
#   'scposx': -30391.597225657,
#   'scposy': 18138.166231469,
#   'scposz': 630.98246047902,
#   'sunposx': -1248490396.9324,
#   'sunposy': 512924293.3282,
#   'sunposz': -278412409.61744,
#   'ettime': 236414383.51714,
#   'starttime': '2007-06-29 18:35:10.67',
#   'exposureduration': 80.0,
#   'channel': 0.0515899},
#  {'name': 'V1561835371_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_047TI_HIRESNAC001_PRIME',
#   'latitude': -8.4284413537277,
#   'longitude': 129.57415174764,
#   'phase': 15.099938929112,
#   'incidence': 27.833206182979,
#   'emission': 23.356897423848,
#   'distance': 35461.064089236,
#   'lineres': 16429.218093545,
#   'sampres': 16390.794764251,
#   'scposx': -30448.901064436,
#   'scposy': 18164.621847427,
#   'scposz': 630.87514539437,
#   'sunposx': -1248465266.0723,
#   'sunposy': 512985562.22107,
#   'sunposz': -278412368.015,
#   'ettime': 236414394.28168,
#   'starttime': '2007-06-29 18:35:10.67',
#   'exposureduration': 80.0,
#   'channel': 0.0559443},
#  {'name': 'V1561835371_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_047TI_HIRESNAC001_PRIME',
#   'latitude': -8.4233986843533,
#   'longitude': 128.20834200998,
#   'phase': 15.066429017589,
#   'incidence': 29.172800020021,
#   'emission': 24.666261443831,
#   'distance': 35367.171581199,
#   'lineres': 17311.688936622,
#   'sampres': 16407.608823979,
#   'scposx': -30363.160767997,
#   'scposy': 18125.040352177,
#   'scposz': 631.03570632788,
#   'sunposx': -1248502866.2516,
#   'sunposy': 512893890.02132,
#   'sunposz': -278412430.26139,
#   'ettime': 236414378.17556,
#   'starttime': '2007-06-29 18:35:10.67',
#   'exposureduration': 80.0,
#   'channel': 0.0527657},
#  {'name': 'V1561835371_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_047TI_HIRESNAC001_PRIME',
#   'latitude': -8.3056493344215,
#   'longitude': 129.0671218736,
#   'phase': 15.078456425383,
#   'incidence': 28.34930621812,
#   'emission': 23.78853603887,
#   'distance': 35429.92440324,
#   'lineres': 16430.882250123,
#   'sampres': 16390.08432552,
#   'scposx': -30420.466139961,
#   'scposy': 18151.493393155,
#   'scposz': 630.92839931615,
#   'sunposx': -1248477736.8834,
#   'sunposy': 512955159.52529,
#   'sunposz': -278412388.65896,
#   'ettime': 236414388.9401,
#   'starttime': '2007-06-29 18:35:10.67',
#   'exposureduration': 80.0,
#   'channel': 0.0539491},
#  {'name': 'V1561835371_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_047TI_HIRESNAC001_PRIME',
#   'latitude': -8.2333152675242,
#   'longitude': 129.89564446289,
#   'phase': 15.092917646493,
#   'incidence': 27.549126079259,
#   'emission': 22.962892416133,
#   'distance': 35492.678519575,
#   'lineres': 16632.988679714,
#   'sampres': 16414.831892626,
#   'scposx': -30477.768422775,
#   'scposy': 18177.951623646,
#   'scposz': 630.82107605563,
#   'sunposx': -1248452604.5086,
#   'sunposy': 513016427.79771,
#   'sunposz': -278412347.05653,
#   'ettime': 236414399.70464,
#   'starttime': '2007-06-29 18:35:10.67',
#   'exposureduration': 80.0,
#   'channel': 0.0544039},
#  {'name': 'V1561835371_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_047TI_HIRESNAC001_PRIME',
#   'latitude': -8.1765001743318,
#   'longitude': 128.5225222433,
#   'phase': 15.055321422142,
#   'incidence': 28.903395010318,
#   'emission': 24.25915432373,
#   'distance': 35398.785035681,
#   'lineres': 17890.656045037,
#   'sampres': 16403.89374568,
#   'scposx': -30392.030454592,
#   'scposy': 18138.366216608,
#   'scposz': 630.98164923738,
#   'sunposx': -1248490206.9543,
#   'sunposy': 512924756.526,
#   'sunposz': -278412409.30292,
#   'ettime': 236414383.59852,
#   'starttime': '2007-06-29 18:35:10.67',
#   'exposureduration': 80.0,
#   'channel': 0.0519968},
#  {'name': 'V1561835371_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_047TI_HIRESNAC001_PRIME',
#   'latitude': -8.1201232665111,
#   'longitude': 129.37630998614,
#   'phase': 15.071634424216,
#   'incidence': 28.076175378944,
#   'emission': 23.411382935655,
#   'distance': 35461.538510889,
#   'lineres': 16448.629206159,
#   'sampres': 16410.19816754,
#   'scposx': -30449.334270178,
#   'scposy': 18164.821871873,
#   'scposz': 630.87433402958,
#   'sunposx': -1248465076.0713,
#   'sunposy': 512986025.40973,
#   'sunposz': -278412367.70049,
#   'ettime': 236414394.36306,
#   'starttime': '2007-06-29 18:35:10.67',
#   'exposureduration': 80.0,
#   'channel': 0.0547566},
#  {'name': 'V1561835371_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_047TI_HIRESNAC001_PRIME',
#   'latitude': -8.1162507275348,
#   'longitude': 128.01011477179,
#   'phase': 15.038165550078,
#   'incidence': 29.415049004204,
#   'emission': 24.731716909874,
#   'distance': 35367.645988186,
#   'lineres': 17343.089931067,
#   'sampres': 16417.307892809,
#   'scposx': -30363.594008685,
#   'scposy': 18125.240317924,
#   'scposz': 631.03489514713,
#   'sunposx': -1248502676.2846,
#   'sunposy': 512894353.2239,
#   'sunposz': -278412429.94688,
#   'ettime': 236414378.25694,
#   'starttime': '2007-06-29 18:35:10.67',
#   'exposureduration': 80.0,
#   'channel': 0.0539349},
#  {'name': 'V1561835371_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_047TI_HIRESNAC001_PRIME',
#   'latitude': -7.9983232365999,
#   'longitude': 128.86899719925,
#   'phase': 15.05020175762,
#   'incidence': 28.593137575016,
#   'emission': 23.849502232537,
#   'distance': 35430.39881987,
#   'lineres': 16414.822959456,
#   'sampres': 16398.716470393,
#   'scposx': -30420.89935713,
#   'scposy': 18151.693398058,
#   'scposz': 630.92758801255,
#   'sunposx': -1248477546.8938,
#   'sunposy': 512955622.7184,
#   'sunposz': -278412388.34445,
#   'ettime': 236414389.02148,
#   'starttime': '2007-06-29 18:35:10.67',
#   'exposureduration': 80.0,
#   'channel': 0.053564},
#  {'name': 'V1561835371_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_047TI_HIRESNAC001_PRIME',
#   'latitude': -7.9248193050486,
#   'longitude': 129.69768690378,
#   'phase': 15.064608577013,
#   'incidence': 27.79432046573,
#   'emission': 23.018059554051,
#   'distance': 35493.152946137,
#   'lineres': 16630.523372381,
#   'sampres': 16422.448808394,
#   'scposx': -30478.20161676,
#   'scposy': 18178.151667861,
#   'scposz': 630.82026462919,
#   'sunposx': -1248452414.4962,
#   'sunposy': 513016890.98168,
#   'sunposz': -278412346.74202,
#   'ettime': 236414399.78602,
#   'starttime': '2007-06-29 18:35:10.67',
#   'exposureduration': 80.0,
#   'channel': 0.0547923},
#  {'name': 'V1561835371_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_047TI_HIRESNAC001_PRIME',
#   'latitude': -7.8693051631593,
#   'longitude': 128.32437602038,
#   'phase': 15.027067995645,
#   'incidence': 29.147977856198,
#   'emission': 24.326109820919,
#   'distance': 35399.259447621,
#   'lineres': 17892.087670517,
#   'sampres': 16413.533832982,
#   'scposx': -30392.46368351,
#   'scposy': 18138.566202117,
#   'scposz': 630.98083799451,
#   'sunposx': -1248490016.9759,
#   'sunposy': 512925219.7239,
#   'sunposz': -278412408.98841,
#   'ettime': 236414383.6799,
#   'starttime': '2007-06-29 18:35:10.67',
#   'exposureduration': 80.0,
#   'channel': 0.0539421},
#  {'name': 'V1561835371_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_047TI_HIRESNAC001_PRIME',
#   'latitude': -7.8120894779381,
#   'longitude': 129.17782796909,
#   'phase': 15.043330430855,
#   'incidence': 28.322412065882,
#   'emission': 23.473063829162,
#   'distance': 35462.012932443,
#   'lineres': 16465.484949339,
#   'sampres': 16418.804797341,
#   'scposx': -30449.767475586,
#   'scposy': 18165.021896543,
#   'scposz': 630.87352266417,
#   'sunposx': -1248464886.0703,
#   'sunposy': 512986488.59815,
#   'sunposz': -278412367.38597,
#   'ettime': 236414394.44444,
#   'starttime': '2007-06-29 18:35:10.67',
#   'exposureduration': 80.0,
#   'channel': 0.0543662},
#  {'name': 'V1561835371_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_047TI_HIRESNAC001_PRIME',
#   'latitude': -7.8093811632098,
#   'longitude': 127.81117775072,
#   'phase': 15.009902644679,
#   'incidence': 29.660499928389,
#   'emission': 24.803990357524,
#   'distance': 35368.120395249,
#   'lineres': 17370.269962175,
#   'sampres': 16421.839252484,
#   'scposx': -30364.027249197,
#   'scposy': 18125.440283968,
#   'scposz': 631.03408396544,
#   'sunposx': -1248502486.3175,
#   'sunposy': 512894816.42642,
#   'sunposz': -278412429.63236,
#   'ettime': 236414378.33832,
#   'starttime': '2007-06-29 18:35:10.67',
#   'exposureduration': 80.0,
#   'channel': 0.0543282},
#  {'name': 'V1561835371_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_047TI_HIRESNAC001_PRIME',
#   'latitude': -7.6912737769562,
#   'longitude': 128.67020342057,
#   'phase': 15.021947624514,
#   'incidence': 28.840180470007,
#   'emission': 23.917505121324,
#   'distance': 35430.873236748,
#   'lineres': 16398.805095415,
#   'sampres': 16408.330201603,
#   'scposx': -30421.332574282,
#   'scposy': 18151.893403331,
#   'scposz': 630.92677670772,
#   'sunposx': -1248477356.9039,
#   'sunposy': 512956085.91161,
#   'sunposz': -278412388.02993,
#   'ettime': 236414389.10286,
#   'starttime': '2007-06-29 18:35:10.67',
#   'exposureduration': 80.0,
#   'channel': 0.0524184},
#  {'name': 'V1561835371_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_047TI_HIRESNAC001_PRIME',
#   'latitude': -7.6166012868834,
#   'longitude': 129.49909810346,
#   'phase': 15.036299999257,
#   'incidence': 28.042763757084,
#   'emission': 23.080525149751,
#   'distance': 35493.6273726,
#   'lineres': 16628.100387751,
#   'sampres': 16431.038136175,
#   'scposx': -30478.63481041,
#   'scposy': 18178.3517123,
#   'scposz': 630.81945320212,
#   'sunposx': -1248452224.4837,
#   'sunposy': 513017354.16541,
#   'sunposz': -278412346.4275,
#   'ettime': 236414399.8674,
#   'starttime': '2007-06-29 18:35:10.67',
#   'exposureduration': 80.0,
#   'channel': 0.0536254},
#  {'name': 'V1561835371_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_047TI_HIRESNAC001_PRIME',
#   'latitude': -7.5043272329898,
#   'longitude': 128.97868352965,
#   'phase': 15.015026951875,
#   'incidence': 28.571853854078,
#   'emission': 23.54189754649,
#   'distance': 35462.487354244,
#   'lineres': 16482.567030962,
#   'sampres': 16428.391149317,
#   'scposx': -30450.200680976,
#   'scposy': 18165.221921582,
#   'scposz': 630.87271129754,
#   'sunposx': -1248464696.069,
#   'sunposy': 512986951.78667,
#   'sunposz': -278412367.07146,
#   'ettime': 236414394.52582,
#   'starttime': '2007-06-29 18:35:10.67',
#   'exposureduration': 80.0,
#   'channel': 0.0524441},
#  {'name': 'V1561835371_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_047TI_HIRESNAC001_PRIME',
#   'latitude': -7.4000904897904,
#   'longitude': 129.81872710491,
#   'phase': 15.027820926542,
#   'incidence': 27.770439405757,
#   'emission': 22.680812068481,
#   'distance': 35525.242139548,
#   'lineres': 18566.68248137,
#   'sampres': 16435.395799094,
#   'scposx': -30507.501362054,
#   'scposy': 18191.682845565,
#   'scposz': 630.76537963625,
#   'sunposx': -1248439562.1339,
#   'sunposy': 513048219.42032,
#   'sunposz': -278412325.46903,
#   'ettime': 236414405.29036,
#   'starttime': '2007-06-29 18:35:10.67',
#   'exposureduration': 80.0,
#   'channel': 0.0536702},
#  {'name': 'V1561835371_1.ir_rc20final.cub',
#   'sequenceid': 'S31',
#   'observationid': 'VIMS_047TI_HIRESNAC001_PRIME',
#   'latitude': -7.3086484744257,
#   'longitude': 129.29985586195,
#   'phase': 15.007991915959,
#   'incidence': 28.294392559348,
#   'emission': 23.150244248049,
#   'distance': 35494.101799309,
#   'lineres': 16625.71976488,
#   'sampres': 16440.604082255,
#   'scposx': -30479.068004042,
#   'scposy': 18178.551757108,
#   'scposz': 630.81864177382,
#   'sunposx': -1248452034.4709,
#   'sunposy': 513017817.34924,
#   'sunposz': -278412346.11299,
#   'ettime': 236414399.94878,
#   'starttime': '2007-06-29 18:35:10.67',
#   'exposureduration': 80.0,
#   'channel': 0.0532506}]

# %%
def plot_spectra(data):
    """
    Expects data of the format returned from parse_csv.
    
    Plots spectra vs time.
    """
    
    #When plotting by ettime or Time.jd, the observations are too spaced out, can't see anything. Here just plotted the time strings.
    
    time=[]
    spectra=[]
    for entry in data:
        #time.append(entry['ettime'])
        time.append(entry['starttime'])
        spectra.append(entry['channel'])
    #plt.scatter(Time(time),spectra)
    plt.scatter(time,spectra)
    plt.xticks(rotation="45", fontsize='7')
    plt.xlabel("Time")
    plt.ylabel("Channel")
    plt.title("Spectra vs. Time within Bounding Box")

# %%
plot_spectra(parse_csv('dunes_larger.csv'))
